# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
import numpy as np
import requests
from bs4 import BeautifulSoup
import re
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
# %matplotlib inline

# %% [markdown]
# ### CSV FILE: cleaning

# %%
ds = pd.read_csv("USvideos.csv")

# %%
ds.head(20)
# Out:
#        video_id trending_date  \
# 0   2kyS6SvSYSE      17.14.11
# 1   1ZAPwfrtAFY      17.14.11
# 2   5qpjK5DgCt4      17.14.11
# 3   puqaWrEC7tY      17.14.11
# 4   d380meD0W0M      17.14.11
# 5   gHZ1Qz0KiKM      17.14.11
# 6   39idVpFF7NQ      17.14.11
# 7   nc99ccSXST0      17.14.11
# 8   jr9QtXwC9vc      17.14.11
# 9   TUmyygCMMGA      17.14.11
# 10  9wRQljFNDW8      17.14.11
# 11  VifQlJit6A0      17.14.11
# 12  5E4ZBSInqUU      17.14.11
# 13  GgVmn66oK_A      17.14.11
# 14  TaTleo4cOs8      17.14.11
# 15  kgaO45SyaO4      17.14.11
# 16  ZAQs-ctOqXQ      17.14.11
# 17  YVfyYrEmzgM      17.14.11
# 18  eNSN6qet1kE      17.14.11
# 19  B5HORANmzHw      17.14.11
#
#                                                 title          channel_title  \
# 0                  WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1   The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2   Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                    Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                            I Dare You: GOING BALD!?               nigahiga
# 5                               2 Weeks with iPhone X               iJustine
# 6           Roy Moore & Jeff Sessions Cold Open - SNL    Saturday Night Live
# 7                 5 Ice Cream Gadgets put to the Test     CrazyRussianHacker
# 8   The Greatest Showman | Official Trailer 2 [HD]...       20th Century Fox
# 9   Why the rise of the robots won’t mean the end ...                    Vox
# 10  Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...                    NFL
# 11  (SPOILERS) 'Shiva Saves the Day' Talked About ...                    amc
# 12         Marshmello - Blocks (Official Music Video)             marshmello
# 13             Which Countries Are About To Collapse?          NowThis World
# 14                           SHOPPING FOR NEW FISH!!!        The king of DIY
# 15                                   The New SpotMini         BostonDynamics
# 16   One Change That Would Make Pacific Rim a Classic                Cracked
# 17  How does your body know you're full? - Hilary ...                 TED-Ed
# 18                         HomeMade Electric Airplane            PeterSripol
# 19           Founding An Inbreeding-Free Space Colony                SciShow
#
#     category_id              publish_time  \
# 0            22  2017-11-13T17:13:01.000Z
# 1            24  2017-11-13T07:30:00.000Z
# 2            23  2017-11-12T19:05:24.000Z
# 3            24  2017-11-13T11:00:04.000Z
# 4            24  2017-11-12T18:01:41.000Z
# 5            28  2017-11-13T19:07:23.000Z
# 6            24  2017-11-12T05:37:17.000Z
# 7            28  2017-11-12T21:50:37.000Z
# 8             1  2017-11-13T14:00:23.000Z
# 9            25  2017-11-13T13:45:16.000Z
# 10           17  2017-11-13T02:05:26.000Z
# 11           24  2017-11-13T03:00:00.000Z
# 12           10  2017-11-13T17:00:00.000Z
# 13           25  2017-11-12T14:00:00.000Z
# 14           15  2017-11-12T18:30:01.000Z
# 15           28  2017-11-13T20:09:58.000Z
# 16           23  2017-11-12T17:00:05.000Z
# 17           27  2017-11-13T16:00:07.000Z
# 18           28  2017-11-13T15:30:17.000Z
# 19           27  2017-11-12T22:00:01.000Z
#
#                                                  tags    views   likes  \
# 0                                     SHANtell martin   748374   57527
# 1   last week tonight trump presidency|"last week ...  2418783   97185
# 2   racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3   rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4   ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
# 5   ijustine|"week with iPhone X"|"iphone x"|"appl...   119180    9763
# 6   SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...  2103417   15993
# 7   5 Ice Cream Gadgets|"Ice Cream"|"Cream Sandwic...   817732   23663
# 8   Trailer|"Hugh Jackman"|"Michelle Williams"|"Za...   826059    3543
# 9   vox.com|"vox"|"explain"|"shift change"|"future...   256426   12654
# 10  NFL|"Football"|"offense"|"defense"|"afc"|"nfc"...    81377     655
# 11  The Walking Dead|"shiva"|"tiger"|"king ezekiel...   104578    1576
# 12  marshmello|"blocks"|"marshmello blocks"|"block...   687582  114188
# 13  nowthis|"nowthis world"|"world news"|"nowthis ...   544770    7848
# 14  shopping for new fish|"new fish"|"aquarium fis...   207532    7473
# 15  Robots|"Boston Dynamics"|"SpotMini"|"Legged Lo...    75752    9419
# 16  pacific rim|"pacific rim 2"|"pacific rim seque...   295639    8011
# 17  TED|"TED-Ed"|"TED Education"|"TED Ed"|"Hilary ...    78044    5398
# 18  ultralight|"airplane"|"homemade"|"DIY"|"hoverb...    97007   11963
# 19  SciShow|"science"|"Hank"|"Green"|"education"|"...   223871    8421
#
#     dislikes  comment_count                                  thumbnail_link  \
# 0       2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1       6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2       5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3        666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4       1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 5        511           1434  https://i.ytimg.com/vi/gHZ1Qz0KiKM/default.jpg
# 6       2445           1970  https://i.ytimg.com/vi/39idVpFF7NQ/default.jpg
# 7        778           3432  https://i.ytimg.com/vi/nc99ccSXST0/default.jpg
# 8        119            340  https://i.ytimg.com/vi/jr9QtXwC9vc/default.jpg
# 9       1363           2368  https://i.ytimg.com/vi/TUmyygCMMGA/default.jpg
# 10        25            177  https://i.ytimg.com/vi/9wRQljFNDW8/default.jpg
# 11       303           1279  https://i.ytimg.com/vi/VifQlJit6A0/default.jpg
# 12      1333           8371  https://i.ytimg.com/vi/5E4ZBSInqUU/default.jpg
# 13      1171           3981  https://i.ytimg.com/vi/GgVmn66oK_A/default.jpg
# 14       246           2120  https://i.ytimg.com/vi/TaTleo4cOs8/default.jpg
# 15        52           1230  https://i.ytimg.com/vi/kgaO45SyaO4/default.jpg
# 16       638           1256  https://i.ytimg.com/vi/ZAQs-ctOqXQ/default.jpg
# 17        53            385  https://i.ytimg.com/vi/YVfyYrEmzgM/default.jpg
# 18        36           2211  https://i.ytimg.com/vi/eNSN6qet1kE/default.jpg
# 19       191           1214  https://i.ytimg.com/vi/B5HORANmzHw/default.jpg
#
#     comments_disabled  ratings_disabled  video_error_or_removed  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
# 5               False             False                   False
# 6               False             False                   False
# 7               False             False                   False
# 8               False             False                   False
# 9               False             False                   False
# 10              False             False                   False
# 11              False             False                   False
# 12              False             False                   False
# 13              False             False                   False
# 14              False             False                   False
# 15              False             False                   False
# 16              False             False                   False
# 17              False             False                   False
# 18              False             False                   False
# 19              False             False                   False
#
#                                           description
# 0   SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1   One year after the presidential election, John...
# 2   WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3   Today we find out if Link is a Nickelback amat...
# 4   I know it's been a while since we did this sho...
# 5   Using the iPhone for the past two weeks -- her...
# 6   Embattled Alabama Senate candidate Roy Moore (...
# 7   Ice Cream Pint Combination Lock - http://amzn....
# 8   Inspired by the imagination of P.T. Barnum, Th...
# 9   For now, at least, we have better things to wo...
# 10  New England Patriots returner Dion Lewis blast...
# 11  Shiva arrives just in time as King Ezekiel att...
# 12  WATCH SILENCE MUSIC VIDEO ▶ https://youtu.be/T...
# 13  The world at large is improving, but some coun...
# 14  Today we go shopping for new fish for some of ...
# 15             For more information . . . stay tuned.
# 16  Pacific Rim was so good, we can’t believe they...
# 17  Check out our Patreon page: https://www.patreo...
# 18  aaaannnd now to fly out of ground effect! The ...
# 19  Thanks to 23AndMe for supporting SciShow. Thes...

# %%
ds.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
# checking for  null values
ds.trending_date.isnull().sum()
# Out:
# 0

# %%
# date to datetime
ds["trending_date"] = pd.to_datetime(ds["trending_date"], format = '%y.%d.%m')

# %% [markdown]
# ### Import Names of Categories and Merge with the Main Dataframe

# %%
with open('US_category_id.json', 'r') as f:
      categories = json.load(f)

# %%
categories_n = {}
for category in categories['items']:
    categories_n [category['id']] = category['snippet']['title']

# %%
type(categories_n)
# Out:
# dict

# %%
# import dictionary into a dataframe
categories = pd.DataFrame.from_dict(categories_n, orient = 'index', columns = [['category_name']]).reset_index()
categories

categories.columns = ['category_id','category_name']

categories['category_id'] = categories['category_id'].astype('int')

# %%
# merging with previous dataframe on category id
ds= pd.merge(ds, categories, on = 'category_id', how = 'left')
ds.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description   category_name
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...  People & Blogs
# 1  One year after the presidential election, John...   Entertainment
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...          Comedy
# 3  Today we find out if Link is a Nickelback amat...   Entertainment
# 4  I know it's been a while since we did this sho...   Entertainment

# %% [markdown]
# ### Wikipedia Data

# %% [markdown]
# #### 2017

# %%
url = 'https://en.wikipedia.org/wiki/List_of_mass_shootings_in_the_United_States'

html = requests.get(url).content

soup = BeautifulSoup(html, 'lxml')

table_2017 = soup.find_all('table', attrs = {'class':'wikitable sortable'})[3]

rows_2017 = table_2017.find_all('tr')

date_2017 = []
loc_2017 = []
dead_2017 = []
injured_2017 = []
total_2017 = []
description_2017 = []

for row in rows_2017[1:]:
    date_2017.append(row.find_all('td')[0].text)
    loc_2017.append(row.find_all('td')[1].text)
    dead_2017.append(row.find_all('td')[2].text)
    injured_2017.append(row.find_all('td')[3].text)
    total_2017.append(row.find_all('td')[4].text)
    description_2017.append(row.find_all('td')[5].text)

# %%
date_2017 = [element.replace('\n','') for element in date_2017]
loc_2017 = [element.replace('\n','') for element in loc_2017]
dead_2017 = [element.replace('\n','').replace('[n 1]','').replace('[n 5]','') for element in dead_2017]
injured_2017 = [element.replace('\n','').replace('[n 1]','') for element in injured_2017]
total_2017 = [element.replace('\n','') for element in total_2017]
description_2017 = [element.replace('\n','') for element in description_2017]

# %%
date_2017 = [element.replace('December', '12,') if 'December' in element else element for element in date_2017]
date_2017 = [element.replace('November', '11,') if 'November' in element else element for element in date_2017]
date_2017 = [element.replace('October', '10,') if 'October' in element else element for element in date_2017]
date_2017 = [element.replace('September', '09,') if 'September' in element else element for element in date_2017]
date_2017 = [element.replace('August', '08,') if 'August' in element else element for element in date_2017]
date_2017 = [element.replace('July', '07,') if 'July' in element else element for element in date_2017]
date_2017 = [element.replace('June', '06,') if 'June' in element else element for element in date_2017]
date_2017 = [element.replace('May', '05,') if 'May' in element else element for element in date_2017]
date_2017 = [element.replace('April', '04,') if 'April' in element else element for element in date_2017]
date_2017 = [element.replace('March', '03,') if 'March' in element else element for element in date_2017]
date_2017 = [element.replace('February', '02,') if 'February' in element else element for element in date_2017]
date_2017 = [element.replace('January', '01,') if 'January' in element else element for element in date_2017]
date_2017[17] = '04, 13, 2017'

# %%
import datetime as dt

date_2017_format = []
for element in date_2017:
    date_time_obj = dt.datetime.strptime(element, '%m, %d, %Y')
    date_2017_format.append(date_time_obj.date())

# %%
header_2017 = ['Date','Location','Dead','Injured','Total','Description']

# %%
df_2017 = pd.DataFrame(list(zip(date_2017_format,loc_2017,dead_2017,injured_2017,total_2017,description_2017)),columns = header_2017)

df_2017
# Out:
#           Date                             Location Dead Injured Total  \
# 0   2017-12-31            Highlands Ranch, Colorado    2       6     8
# 1   2017-12-07                    Aztec, New Mexico    3       0     3
# 2   2017-11-13            Tehama County, California    6      12    18
# 3   2017-11-05            Sutherland Springs, Texas   27      20    47
# 4   2017-10-01                    Las Vegas, Nevada   59     422   481
# 5   2017-09-24                   Antioch, Tennessee    1       8     9
# 6   2017-09-10                         Plano, Texas    9       1    10
# 7   2017-08-28                   Clovis, New Mexico    2       4     6
# 8   2017-07-01                Little Rock, Arkansas    0      28    28
# 9   2017-06-30              New York City, New York    2       6     8
# 10  2017-06-14            San Francisco, California    4       5     9
# 11  2017-06-14                 Alexandria, Virginia    1       6     7
# 12  2017-06-08         Eaton Township, Pennsylvania    4       0     4
# 13  2017-06-06                          Sandy, Utah    3       2     5
# 14  2017-06-05                     Orlando, Florida    6       0     6
# 15  2017-05-27          Lincoln County, Mississippi    8       1     9
# 16  2017-05-12                   Kirkersville, Ohio    4       0     4
# 17  2017-04-13                   Fresno, California    4       0     4
# 18  2017-04-10           San Bernardino, California    3       1     4
# 19  2017-03-26                     Cincinnati, Ohio    2      16    18
# 20  2017-03-22  Schofield and Rothschild, Wisconsin    5       0     5
# 21  2017-01-06              Broward County, Florida    5       6    11
#
#                                           Description
# 0   Copper Canyon Apartment Homes shooting: After ...
# 1   Aztec High School shooting: A man walked into ...
# 2   Rancho Tehama Reserve shootings: A man killed ...
# 3   Sutherland Springs church shooting: A gunman a...
# 4   2017 Las Vegas shooting: A man in a high floor...
# 5   Burnette Chapel shooting: A man killed a woman...
# 6   2017 Plano shooting: A man entered his ex-wife...
# 7   Clovis library shooting: A sixteen-year-old ki...
# 8   Little Rock nightclub shooting: Twenty-eight p...
# 9   Bronx-Lebanon Hospital attack: A former hospit...
# 10  San Francisco UPS shooting: A gunman entered h...
# 11  2017 Congressional baseball shooting: A gunman...
# 12  Eaton Township Weis Markets shooting: An emplo...
# 13  Sandy, Utah attack: A man rammed a vehicle con...
# 14  Orlando factory shooting: A former employee en...
# 15  2017 Mississippi shootings: A man killed eight...
# 16  Kirkersville shooting: After taking two people...
# 17  2017 Fresno shootings: A man killed a security...
# 18  North Park Elementary School shooting: A man e...
# 19  Cincinnati nightclub shooting: Two men were ki...
# 20  2017 Schofield/Rothschild shootings: A man dem...
# 21  Fort Lauderdale airport shooting: A man killed...

# %% [markdown]
# #### 2018

# %%
table_2018 = soup.find_all('table', attrs = {'class':'wikitable sortable'})[2]

rows_2018 = table_2018.find_all('tr')

date_2018 = []
loc_2018 = []
dead_2018 = []
injured_2018 = []
total_2018 = []
description_2018 = []

for row in rows_2018[1:]:
    date_2018.append(row.find_all('td')[0].text)
    loc_2018.append(row.find_all('td')[1].text)
    dead_2018.append(row.find_all('td')[2].text)
    injured_2018.append(row.find_all('td')[3].text)
    total_2018.append(row.find_all('td')[4].text)
    description_2018.append(row.find_all('td')[5].text)

date_2018 = [element.replace('\n','') for element in date_2018]
loc_2018 = [element.replace('\n','') for element in loc_2018]
dead_2018 = [element.replace('\n','').replace('[n 1]','').replace('[n 5]','') for element in dead_2018]
injured_2018 = [element.replace('\n','').replace('[n 1]','').replace('[n 2]', '').replace('[n 3]', '').replace('[n 4]', '') for element in injured_2018]
total_2018 = [element.replace('\n','') for element in total_2018]
description_2018 = [element.replace('\n','') for element in description_2018]

date_2018 = [element.replace('December', '12,') if 'December' in element else element for element in date_2018]
date_2018 = [element.replace('November', '11,') if 'November' in element else element for element in date_2018]
date_2018 = [element.replace('October', '10,') if 'October' in element else element for element in date_2018]
date_2018 = [element.replace('September', '09,') if 'September' in element else element for element in date_2018]
date_2018 = [element.replace('August', '08,') if 'August' in element else element for element in date_2018]
date_2018 = [element.replace('July', '07,') if 'July' in element else element for element in date_2018]
date_2018 = [element.replace('June', '06,') if 'June' in element else element for element in date_2018]
date_2018 = [element.replace('May', '05,') if 'May' in element else element for element in date_2018]
date_2018 = [element.replace('April', '04,') if 'April' in element else element for element in date_2018]
date_2018 = [element.replace('March', '03,') if 'March' in element else element for element in date_2018]
date_2018 = [element.replace('February', '02,') if 'February' in element else element for element in date_2018]
date_2018 = [element.replace('January', '01,') if 'January' in element else element for element in date_2018]
date_2018[11] = '06, 4, 2018'

import datetime as dt

date_2018_format = []
for element in date_2018:
    date_time_obj = dt.datetime.strptime(element, '%m, %d, %Y')
    date_2018_format.append(date_time_obj.date())

header_2018 = ['Date','Location','Dead','Injured','Total','Description']

df_2018 = pd.DataFrame(list(zip(date_2018_format,loc_2018,dead_2018,injured_2018,total_2018,description_2018)),columns = header_2018)

# %% [markdown]
# #### 2017 and 2018 together

# %%
df_wikipedia = pd.concat([df_2017,df_2018])
df_wikipedia.reset_index()
# Out:
#     index        Date                             Location Dead Injured Total  \
# 0       0  2017-12-31            Highlands Ranch, Colorado    2       6     8
# 1       1  2017-12-07                    Aztec, New Mexico    3       0     3
# 2       2  2017-11-13            Tehama County, California    6      12    18
# 3       3  2017-11-05            Sutherland Springs, Texas   27      20    47
# 4       4  2017-10-01                    Las Vegas, Nevada   59     422   481
# 5       5  2017-09-24                   Antioch, Tennessee    1       8     9
# 6       6  2017-09-10                         Plano, Texas    9       1    10
# 7       7  2017-08-28                   Clovis, New Mexico    2       4     6
# 8       8  2017-07-01                Little Rock, Arkansas    0      28    28
# 9       9  2017-06-30              New York City, New York    2       6     8
# 10     10  2017-06-14            San Francisco, California    4       5     9
# 11     11  2017-06-14                 Alexandria, Virginia    1       6     7
# 12     12  2017-06-08         Eaton Township, Pennsylvania    4       0     4
# 13     13  2017-06-06                          Sandy, Utah    3       2     5
# 14     14  2017-06-05                     Orlando, Florida    6       0     6
# 15     15  2017-05-27          Lincoln County, Mississippi    8       1     9
# 16     16  2017-05-12                   Kirkersville, Ohio    4       0     4
# 17     17  2017-04-13                   Fresno, California    4       0     4
# 18     18  2017-04-10           San Bernardino, California    3       1     4
# 19     19  2017-03-26                     Cincinnati, Ohio    2      16    18
# 20     20  2017-03-22  Schofield and Rothschild, Wisconsin    5       0     5
# 21     21  2017-01-06              Broward County, Florida    5       6    11
# 22      0  2018-11-19                    Chicago, Illinois    4       0     4
# 23      1  2018-11-11                    Robbins, Illinois    1       4     5
# 24      2  2018-11-07            Thousand Oaks, California   13     12+   25+
# 25      3  2018-11-02                 Tallahassee, Florida    3       5     8
# 26      4  2018-10-27             Pittsburgh, Pennsylvania   11       7    18
# 27      5  2018-10-03             Florence, South Carolina    2      10    12
# 28      6  2018-09-20                   Aberdeen, Maryland    4       3     7
# 29      7  2018-09-06                     Cincinnati, Ohio    4       2     6
# 30      8  2018-08-26                Jacksonville, Florida    3      11    14
# 31      9  2018-06-28                  Annapolis, Maryland    5       2     7
# 32     10  2018-06-17                  Trenton, New Jersey    1      22    23
# 33     11  2018-06-04                  Scottsdale, Arizona    7       0     7
# 34     12  2018-05-18                      Santa Fe, Texas   10      14    24
# 35     13  2018-04-22                 Nashville, Tennessee    4       2     6
# 36     14  2018-04-03                San Bruno, California    1       4     5
# 37     15  2018-03-09               Yountville, California    5       0     5
# 38     16  2018-02-14                    Parkland, Florida   17      17    34
# 39     17  2018-01-28               Melcroft, Pennsylvania    5       1     6
# 40     18  2018-01-23                     Benton, Kentucky    2      16    18
#
#                                           Description
# 0   Copper Canyon Apartment Homes shooting: After ...
# 1   Aztec High School shooting: A man walked into ...
# 2   Rancho Tehama Reserve shootings: A man killed ...
# 3   Sutherland Springs church shooting: A gunman a...
# 4   2017 Las Vegas shooting: A man in a high floor...
# 5   Burnette Chapel shooting: A man killed a woman...
# 6   2017 Plano shooting: A man entered his ex-wife...
# 7   Clovis library shooting: A sixteen-year-old ki...
# 8   Little Rock nightclub shooting: Twenty-eight p...
# 9   Bronx-Lebanon Hospital attack: A former hospit...
# 10  San Francisco UPS shooting: A gunman entered h...
# 11  2017 Congressional baseball shooting: A gunman...
# 12  Eaton Township Weis Markets shooting: An emplo...
# 13  Sandy, Utah attack: A man rammed a vehicle con...
# 14  Orlando factory shooting: A former employee en...
# 15  2017 Mississippi shootings: A man killed eight...
# 16  Kirkersville shooting: After taking two people...
# 17  2017 Fresno shootings: A man killed a security...
# 18  North Park Elementary School shooting: A man e...
# 19  Cincinnati nightclub shooting: Two men were ki...
# 20  2017 Schofield/Rothschild shootings: A man dem...
# 21  Fort Lauderdale airport shooting: A man killed...
# 22  Mercy Hospital shooting: A gunman opened fire ...
# 23  Shooting of Jemel Roberson: A man re-entered a...
# 24  Thousand Oaks shooting: A man entered a bar ho...
# 25  2018 Tallahassee attack: A man entered a yoga ...
# 26  Pittsburgh synagogue shooting: A man opened fi...
# 27  Florence shooting: Officers were shot at durin...
# 28  Aberdeen shooting: An employee of the Rite Aid...
# 29  Fifth Third Center shooting: A gunman entered ...
# 30  Jacksonville Landing shooting: A gunman killed...
# 31  Capital Gazette shooting: A gunman entered the...
# 32  Art All Night shooting: Several gunmen wounded...
# 33  2018 Scottsdale spree shootings: Over the cour...
# 34  Santa Fe High School shooting: A student at Sa...
# 35  Nashville Waffle House shooting: A gunman ente...
# 36  YouTube headquarters shooting: A woman approac...
# 37  Yountville shooting: A man entered the Veteran...
# 38  Stoneman Douglas High School shooting: A forme...
# 39  Melcroft shooting: A man shot and killed four ...
# 40  Marshall County High School shooting: A fiftee...

# %%
df_wikipedia.head()
# Out:
#          Date                   Location Dead Injured Total  \
# 0  2017-12-31  Highlands Ranch, Colorado    2       6     8
# 1  2017-12-07          Aztec, New Mexico    3       0     3
# 2  2017-11-13  Tehama County, California    6      12    18
# 3  2017-11-05  Sutherland Springs, Texas   27      20    47
# 4  2017-10-01          Las Vegas, Nevada   59     422   481
#
#                                          Description
# 0  Copper Canyon Apartment Homes shooting: After ...
# 1  Aztec High School shooting: A man walked into ...
# 2  Rancho Tehama Reserve shootings: A man killed ...
# 3  Sutherland Springs church shooting: A gunman a...
# 4  2017 Las Vegas shooting: A man in a high floor...

# %% [markdown]
# ### Only mass shooting dates  --- TO CHANGE

# %%
mass_shooting_dates = df_wikipedia["Date"]

# %%
mass_shooting_dates1 = ["2018-05-18", "2018-04-22", "2018-04-03", "2018-03-09", "2018-02-14", "2018-01-28", "2018-01-23","2017-12-31","2017-12-07"]

# %%
df_wikipedia["Date"]
# Out:
# 0     2017-12-31
# 1     2017-12-07
# 2     2017-11-13
# 3     2017-11-05
# 4     2017-10-01
# 5     2017-09-24
# 6     2017-09-10
# 7     2017-08-28
# 8     2017-07-01
# 9     2017-06-30
# 10    2017-06-14
# 11    2017-06-14
# 12    2017-06-08
# 13    2017-06-06
# 14    2017-06-05
# 15    2017-05-27
# 16    2017-05-12
# 17    2017-04-13
# 18    2017-04-10
# 19    2017-03-26
# 20    2017-03-22
# 21    2017-01-06
# 0     2018-11-19
# 1     2018-11-11
# 2     2018-11-07
# 3     2018-11-02
# 4     2018-10-27
# 5     2018-10-03
# 6     2018-09-20
# 7     2018-09-06
# 8     2018-08-26
# 9     2018-06-28
# 10    2018-06-17
# 11    2018-06-04
# 12    2018-05-18
# 13    2018-04-22
# 14    2018-04-03
# 15    2018-03-09
# 16    2018-02-14
# 17    2018-01-28
# 18    2018-01-23
# Name: Date, dtype: object

# %%
mass_shooting_dates
# Out:
# 0     2017-12-31
# 1     2017-12-07
# 2     2017-11-13
# 3     2017-11-05
# 4     2017-10-01
# 5     2017-09-24
# 6     2017-09-10
# 7     2017-08-28
# 8     2017-07-01
# 9     2017-06-30
# 10    2017-06-14
# 11    2017-06-14
# 12    2017-06-08
# 13    2017-06-06
# 14    2017-06-05
# 15    2017-05-27
# 16    2017-05-12
# 17    2017-04-13
# 18    2017-04-10
# 19    2017-03-26
# 20    2017-03-22
# 21    2017-01-06
# 0     2018-11-19
# 1     2018-11-11
# 2     2018-11-07
# 3     2018-11-02
# 4     2018-10-27
# 5     2018-10-03
# 6     2018-09-20
# 7     2018-09-06
# 8     2018-08-26
# 9     2018-06-28
# 10    2018-06-17
# 11    2018-06-04
# 12    2018-05-18
# 13    2018-04-22
# 14    2018-04-03
# 15    2018-03-09
# 16    2018-02-14
# 17    2018-01-28
# 18    2018-01-23
# Name: Date, dtype: object

# %%
mshoot_ds = ds[ds["trending_date"].isin(mass_shooting_dates)]

# %%
mshoot_ds.shape
# Out:
# (1999, 17)

# %%
mshoot_ds.shape
# Out:
# (1999, 17)

# %% [markdown]
# ## Overall Calculations

# %% [markdown]
# ### Shooting Days

# %%
# group by date and count types of categories
share_daily_mh = mshoot_ds.groupby(['trending_date', 'category_id'], as_index=False).agg({'category_name':'count'})
share_daily_mh.columns = ['trending_date', 'category_id','tot_per_cat']
share_daily_mh.head()
# Out:
#   trending_date  category_id  tot_per_cat
# 0    2017-12-07            1           10
# 1    2017-12-07            2            2
# 2    2017-12-07           10           33
# 3    2017-12-07           15            3
# 4    2017-12-07           17           15

# %%
#get average of trending category per date
share_daily_masss = share_daily_mh.groupby(['category_id'], as_index=False).agg({'tot_per_cat':'mean'})
share_daily_masss=share_daily_masss.rename(columns = {"tot_per_cat":"avg_per_cat_sd"})
share_daily_masss.head()
# Out:
#    category_id  avg_per_cat_sd
# 0            1            11.8
# 1            2             2.5
# 2           10            30.4
# 3           15             5.0
# 4           17            11.1

# %% [markdown]
# ### Non Shooting Days

# %%
non_shooting_days=ds[~ds['trending_date'].isin(mass_shooting_dates)]
non_shooting_days.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description   category_name
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...  People & Blogs
# 1  One year after the presidential election, John...   Entertainment
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...          Comedy
# 3  Today we find out if Link is a Nickelback amat...   Entertainment
# 4  I know it's been a while since we did this sho...   Entertainment

# %%
non_shooting_days.shape
# Out:
# (38950, 17)

# %%
#calculating count of video categories on non-shooting-days
share_daily_non_sd = non_shooting_days.groupby(['trending_date', 'category_id'], as_index=False).agg({'category_name':'count'})
share_daily_non_sd.columns = ['trending_date', 'category_id','tot_per_cat']

# %%
share_daily_non_sd.shape
# Out:
# (2721, 3)

# %%
# calculating mean of video cateogories on non-shooting-days
share_daily_non_sd = share_daily_non_sd.groupby(['category_id'], as_index=False).agg({'tot_per_cat':'mean'})
share_daily_non_sd=share_daily_non_sd.rename(columns = {"tot_per_cat":"avg_per_cat_non_sd"})

# %% [markdown]
# ## Merge averages of shooting and non shooting days

# %%
averages= pd.merge(share_daily_non_sd, share_daily_masss, on = 'category_id', how = 'left')

# %%
averages["differences"]=averages["avg_per_cat_sd"]-averages["avg_per_cat_non_sd"]

averages= pd.merge(averages, categories, on = 'category_id', how = 'left')

# %%
averages = averages [['category_id','category_name', 'avg_per_cat_non_sd', 'avg_per_cat_sd', 'differences']]

# %%
averages['relativ_diff in %'] = averages['differences']/averages['avg_per_cat_non_sd']*100
averages
averages.round(decimals=2)
# Out:
#     category_id          category_name  avg_per_cat_non_sd  avg_per_cat_sd  \
# 0             1       Film & Animation               11.42           11.80
# 1             2       Autos & Vehicles                2.87            2.50
# 2            10                  Music               31.63           30.40
# 3            15         Pets & Animals                4.48            5.00
# 4            17                 Sports               10.58           11.10
# 5            19        Travel & Events                2.33            1.89
# 6            20                 Gaming                4.28            4.22
# 7            22         People & Blogs               15.64           16.10
# 8            23                 Comedy               16.87           16.70
# 9            24          Entertainment               48.66           47.50
# 10           25        News & Politics               12.12           12.30
# 11           26          Howto & Style               20.23           20.20
# 12           27              Education                8.05            8.70
# 13           28   Science & Technology               11.70           11.90
# 14           29  Nonprofits & Activism                1.08            1.00
# 15           43                  Shows                1.00            1.00
#
#     differences  relativ_diff in %
# 0          0.38               3.32
# 1         -0.37             -12.77
# 2         -1.23              -3.89
# 3          0.52              11.49
# 4          0.52               4.92
# 5         -0.44             -19.05
# 6         -0.06              -1.36
# 7          0.46               2.97
# 8         -0.17              -1.02
# 9         -1.16              -2.39
# 10         0.18               1.46
# 11        -0.03              -0.13
# 12         0.65               8.13
# 13         0.20               1.69
# 14        -0.08              -7.27
# 15         0.00               0.00

# %% [markdown]
# ### Baseline for daily averages

# %%
share_daily = ds.groupby(['trending_date', 'category_id'], as_index=False).agg({'category_name':'count'})
share_daily.columns = ['trending_date', 'category_id','tot_per_cat']

# %%
total_per_day = ds.groupby(['trending_date'], as_index=False).agg({'category_name':'count'})
total_per_day.columns = ['trending_date', 'total_per_day']
total_per_day.head()
# Out:
#   trending_date  total_per_day
# 0    2017-11-14            200
# 1    2017-11-15            200
# 2    2017-11-16            200
# 3    2017-11-17            200
# 4    2017-11-18            200

# %%
share_daily= pd.merge(share_daily, total_per_day, on = 'trending_date', how = 'left')
share_daily.head()
# Out:
#   trending_date  category_id  tot_per_cat  total_per_day
# 0    2017-11-14            1            8            200
# 1    2017-11-14            2            4            200
# 2    2017-11-14           10           45            200
# 3    2017-11-14           15            5            200
# 4    2017-11-14           17            9            200

# %% [markdown]
# # Visualisation

# %%
averages
# Out:
#     category_id          category_name  avg_per_cat_non_sd  avg_per_cat_sd  \
# 0             1       Film & Animation           11.420513       11.800000
# 1             2       Autos & Vehicles            2.866142        2.500000
# 2            10                  Music           31.630769       30.400000
# 3            15         Pets & Animals            4.484536        5.000000
# 4            17                 Sports           10.579487       11.100000
# 5            19        Travel & Events            2.333333        1.888889
# 6            20                 Gaming            4.280220        4.222222
# 7            22         People & Blogs           15.635897       16.100000
# 8            23                 Comedy           16.871795       16.700000
# 9            24          Entertainment           48.661538       47.500000
# 10           25        News & Politics           12.123077       12.300000
# 11           26          Howto & Style           20.225641       20.200000
# 12           27              Education            8.046154        8.700000
# 13           28   Science & Technology           11.702564       11.900000
# 14           29  Nonprofits & Activism            1.078431        1.000000
# 15           43                  Shows            1.000000        1.000000
#
#     differences  relativ_diff in %
# 0      0.379487           3.322856
# 1     -0.366142         -12.774725
# 2     -1.230769          -3.891051
# 3      0.515464          11.494253
# 4      0.520513           4.920019
# 5     -0.444444         -19.047619
# 6     -0.057998          -1.355014
# 7      0.464103           2.968186
# 8     -0.171795          -1.018237
# 9     -1.161538          -2.386974
# 10     0.176923           1.459391
# 11    -0.025641          -0.126775
# 12     0.653846           8.126195
# 13     0.197436           1.687117
# 14    -0.078431          -7.272727
# 15     0.000000           0.000000

# %%
#setting up
video_categories = averages["category_name"]
avg_per_cat_non_sd = averages["avg_per_cat_non_sd"]
avg_per_cat_sd = averages["avg_per_cat_sd"]

# %%
# visualising Daily average on days without shootings

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
width = 0.75 #widht of the bars

cat_ns = ax.bar(video_categories, avg_per_cat_non_sd, width, label ="Non shooting day")

ax.set_ylabel("Average")
ax.set_title("Youtube video categories")
plt.setp(ax.get_xticklabels(), rotation = 30, horizontalalignment = "right")

plt.show()

# %%
# comparing video trend categories on days with and without shootings

#number of pairs of bars:
n = len(video_categories)

#position of bars on x-axis
ind = np.arange(n)

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111)
width = 0.4 #widht of the bars


cat_ns = ax.bar(ind, avg_per_cat_non_sd, width, label ="Non shooting day", color = "b")

cat_sd = ax.bar(ind + width, avg_per_cat_sd, width, label = "Shooting day", color = "r")

ax.set_ylabel("Average")
ax.set_title("Youtube video categories")
ax.legend((cat_ns, cat_sd), ("Non Shooting Day", "Shooting Day"))

#list of labels
plt.xticks(ind, video_categories)

plt.setp(ax.get_xticklabels(), rotation = 30, horizontalalignment = "right")


plt.show()
