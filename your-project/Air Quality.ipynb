# %%
import pandas as pd
import numpy as np
import requests
from pandas.io.json import json_normalize
from flatten_json import flatten

# %% [markdown]
# # OpenAQ API Conection

# %% [markdown]
# ## List Countries

# %%
url = "https://api.openaq.org/v1/countries"

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.json()
# response.text
response.json()['results']
# Out:
# [{'code': 'AD',
#   'count': 116822,
#   'locations': 3,
#   'cities': 2,
#   'name': 'Andorra'},
#  {'code': 'AE',
#   'count': 75269,
#   'locations': 4,
#   'cities': 3,
#   'name': 'United Arab Emirates'},
#  {'code': 'AF',
#   'count': 6885,
#   'locations': 2,
#   'cities': 2,
#   'name': 'Afghanistan'},
#  {'code': 'AG',
#   'count': 1,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Antigua and Barbuda'},
#  {'code': 'AR',
#   'count': 14976,
#   'locations': 4,
#   'cities': 1,
#   'name': 'Argentina'},
#  {'code': 'AT',
#   'count': 1637913,
#   'locations': 541,
#   'cities': 25,
#   'name': 'Austria'},
#  {'code': 'AU',
#   'count': 6805469,
#   'locations': 168,
#   'cities': 53,
#   'name': 'Australia'},
#  {'code': 'BA',
#   'count': 1083277,
#   'locations': 22,
#   'cities': 10,
#   'name': 'Bosnia and Herzegovina'},
#  {'code': 'BD',
#   'count': 33599,
#   'locations': 2,
#   'cities': 1,
#   'name': 'Bangladesh'},
#  {'code': 'BE',
#   'count': 1802746,
#   'locations': 198,
#   'cities': 14,
#   'name': 'Belgium'},
#  {'code': 'BG',
#   'count': 3570,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Bulgaria'},
#  {'code': 'BH',
#   'count': 47237,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Bahrain'},
#  {'code': 'BK', 'count': 3569, 'locations': 1, 'cities': 1},
#  {'code': 'BM', 'count': 4507, 'locations': 1, 'cities': 1, 'name': 'Bermuda'},
#  {'code': 'BR',
#   'count': 304267,
#   'locations': 61,
#   'cities': 31,
#   'name': 'Brazil'},
#  {'code': 'CA',
#   'count': 6280151,
#   'locations': 213,
#   'cities': 12,
#   'name': 'Canada'},
#  {'code': 'CE', 'count': 6220, 'locations': 1, 'cities': 1},
#  {'code': 'CH',
#   'count': 1544781,
#   'locations': 30,
#   'cities': 15,
#   'name': 'Switzerland'},
#  {'code': 'CI',
#   'count': 300,
#   'locations': 1,
#   'cities': 1,
#   'name': "Côte d'Ivoire"},
#  {'code': 'CL',
#   'count': 8081808,
#   'locations': 238,
#   'cities': 163,
#   'name': 'Chile'},
#  {'code': 'CN',
#   'count': 100527247,
#   'locations': 1724,
#   'cities': 387,
#   'name': 'China'},
#  {'code': 'CO',
#   'count': 654583,
#   'locations': 34,
#   'cities': 12,
#   'name': 'Colombia'},
#  {'code': 'CR',
#   'count': 2779,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Costa Rica'},
#  {'code': 'CS', 'count': 3306, 'locations': 2, 'cities': 1},
#  {'code': 'CW',
#   'count': 22509,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Curaçao'},
#  {'code': 'CZ',
#   'count': 6112227,
#   'locations': 200,
#   'cities': 15,
#   'name': 'Czech Republic'},
#  {'code': 'DE',
#   'count': 12113999,
#   'locations': 1086,
#   'cities': 36,
#   'name': 'Germany'},
#  {'code': 'DK',
#   'count': 584699,
#   'locations': 25,
#   'cities': 7,
#   'name': 'Denmark'},
#  {'code': 'DZ', 'count': 6806, 'locations': 1, 'cities': 1, 'name': 'Algeria'},
#  {'code': 'ES',
#   'count': 23811054,
#   'locations': 1235,
#   'cities': 115,
#   'name': 'Spain'},
#  {'code': 'ET',
#   'count': 58776,
#   'locations': 3,
#   'cities': 2,
#   'name': 'Ethiopia'},
#  {'code': 'FI',
#   'count': 2022601,
#   'locations': 119,
#   'cities': 35,
#   'name': 'Finland'},
#  {'code': 'FR',
#   'count': 25277254,
#   'locations': 1504,
#   'cities': 135,
#   'name': 'France'},
#  {'code': 'GB',
#   'count': 11112842,
#   'locations': 162,
#   'cities': 112,
#   'name': 'United Kingdom'},
#  {'code': 'GH', 'count': 1595, 'locations': 11, 'cities': 1, 'name': 'Ghana'},
#  {'code': 'GI',
#   'count': 40842,
#   'locations': 6,
#   'cities': 2,
#   'name': 'Gibraltar'},
#  {'code': 'GT',
#   'count': 7129,
#   'locations': 2,
#   'cities': 2,
#   'name': 'Guatemala'},
#  {'code': 'HK',
#   'count': 1551801,
#   'locations': 16,
#   'cities': 9,
#   'name': 'Hong Kong'},
#  {'code': 'HR',
#   'count': 908207,
#   'locations': 50,
#   'cities': 17,
#   'name': 'Croatia'},
#  {'code': 'HU',
#   'count': 2163556,
#   'locations': 50,
#   'cities': 14,
#   'name': 'Hungary'},
#  {'code': 'ID',
#   'count': 78962,
#   'locations': 5,
#   'cities': 3,
#   'name': 'Indonesia'},
#  {'code': 'IE',
#   'count': 498909,
#   'locations': 38,
#   'cities': 16,
#   'name': 'Ireland'},
#  {'code': 'IL',
#   'count': 173130367,
#   'locations': 2041,
#   'cities': 14,
#   'name': 'Israel'},
#  {'code': 'IN',
#   'count': 29192966,
#   'locations': 453,
#   'cities': 234,
#   'name': 'India'},
#  {'code': 'IQ', 'count': 9086, 'locations': 1, 'cities': 1, 'name': 'Iraq'},
#  {'code': 'IS',
#   'count': 23129,
#   'locations': 15,
#   'cities': 8,
#   'name': 'Iceland'},
#  {'code': 'IT',
#   'count': 3868465,
#   'locations': 104,
#   'cities': 45,
#   'name': 'Italy'},
#  {'code': 'IZ', 'count': 2429, 'locations': 1, 'cities': 1},
#  {'code': 'JO', 'count': 6957, 'locations': 2, 'cities': 2, 'name': 'Jordan'},
#  {'code': 'KE', 'count': 2842, 'locations': 2, 'cities': 1, 'name': 'Kenya'},
#  {'code': 'KG',
#   'count': 12666,
#   'locations': 2,
#   'cities': 2,
#   'name': 'Kyrgyzstan'},
#  {'code': 'KU', 'count': 3419, 'locations': 1, 'cities': 1},
#  {'code': 'KV', 'count': 3573, 'locations': 1, 'cities': 1},
#  {'code': 'KW', 'count': 24368, 'locations': 1, 'cities': 1, 'name': 'Kuwait'},
#  {'code': 'KZ',
#   'count': 12093,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Kazakhstan'},
#  {'code': 'LA',
#   'count': 10011,
#   'locations': 2,
#   'cities': 2,
#   'name': "Lao People's Democratic Republic"},
#  {'code': 'LK',
#   'count': 19043,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Sri Lanka'},
#  {'code': 'LT',
#   'count': 442928,
#   'locations': 17,
#   'cities': 8,
#   'name': 'Lithuania'},
#  {'code': 'LU',
#   'count': 458184,
#   'locations': 7,
#   'cities': 3,
#   'name': 'Luxembourg'},
#  {'code': 'LV',
#   'count': 195071,
#   'locations': 4,
#   'cities': 4,
#   'name': 'Latvia'},
#  {'code': 'MG',
#   'count': 3221,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Madagascar'},
#  {'code': 'MK',
#   'count': 1262405,
#   'locations': 45,
#   'cities': 16,
#   'name': 'Macedonia, the Former Yugoslav Republic of'},
#  {'code': 'ML', 'count': 273, 'locations': 1, 'cities': 1, 'name': 'Mali'},
#  {'code': 'MM', 'count': 9984, 'locations': 2, 'cities': 2, 'name': 'Myanmar'},
#  {'code': 'MN',
#   'count': 2823299,
#   'locations': 44,
#   'cities': 25,
#   'name': 'Mongolia'},
#  {'code': 'MT', 'count': 263943, 'locations': 4, 'cities': 4, 'name': 'Malta'},
#  {'code': 'MX',
#   'count': 3282240,
#   'locations': 103,
#   'cities': 5,
#   'name': 'Mexico'},
#  {'code': 'NG', 'count': 2541, 'locations': 1, 'cities': 1, 'name': 'Nigeria'},
#  {'code': 'NL',
#   'count': 8939474,
#   'locations': 111,
#   'cities': 67,
#   'name': 'Netherlands'},
#  {'code': 'NO',
#   'count': 3598736,
#   'locations': 88,
#   'cities': 37,
#   'name': 'Norway'},
#  {'code': 'NP', 'count': 98578, 'locations': 6, 'cities': 2, 'name': 'Nepal'},
#  {'code': 'PE', 'count': 727702, 'locations': 22, 'cities': 2, 'name': 'Peru'},
#  {'code': 'PH',
#   'count': 958,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Philippines'},
#  {'code': 'PK',
#   'count': 42739,
#   'locations': 8,
#   'cities': 5,
#   'name': 'Pakistan'},
#  {'code': 'PL',
#   'count': 8277670,
#   'locations': 233,
#   'cities': 172,
#   'name': 'Poland'},
#  {'code': 'PT',
#   'count': 3677061,
#   'locations': 67,
#   'cities': 16,
#   'name': 'Portugal'},
#  {'code': 'RS',
#   'count': 248710,
#   'locations': 6,
#   'cities': 4,
#   'name': 'Serbia'},
#  {'code': 'RU',
#   'count': 186861,
#   'locations': 48,
#   'cities': 1,
#   'name': 'Russian Federation'},
#  {'code': 'SA',
#   'count': 6918,
#   'locations': 2,
#   'cities': 2,
#   'name': 'Saudi Arabia'},
#  {'code': 'SE',
#   'count': 293247,
#   'locations': 11,
#   'cities': 3,
#   'name': 'Sweden'},
#  {'code': 'SG',
#   'count': 1275,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Singapore'},
#  {'code': 'SI',
#   'count': 148827,
#   'locations': 9,
#   'cities': 9,
#   'name': 'Slovenia'},
#  {'code': 'SK',
#   'count': 2469699,
#   'locations': 38,
#   'cities': 8,
#   'name': 'Slovakia'},
#  {'code': 'TH',
#   'count': 5306200,
#   'locations': 64,
#   'cities': 29,
#   'name': 'Thailand'},
#  {'code': 'TI', 'count': 3584, 'locations': 1, 'cities': 1},
#  {'code': 'TJ',
#   'count': 3803,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Tajikistan'},
#  {'code': 'TM',
#   'count': 3801,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Turkmenistan'},
#  {'code': 'TR',
#   'count': 5640285,
#   'locations': 159,
#   'cities': 43,
#   'name': 'Turkey'},
#  {'code': 'TW',
#   'count': 7518919,
#   'locations': 144,
#   'cities': 30,
#   'name': 'Taiwan'},
#  {'code': 'TX', 'count': 3440, 'locations': 1, 'cities': 1},
#  {'code': 'UC', 'count': 1, 'locations': 1, 'cities': 1},
#  {'code': 'UG', 'count': 27742, 'locations': 2, 'cities': 2, 'name': 'Uganda'},
#  {'code': 'US',
#   'count': 67345323,
#   'locations': 2264,
#   'cities': 790,
#   'name': 'United States'},
#  {'code': 'UZ',
#   'count': 30096,
#   'locations': 2,
#   'cities': 2,
#   'name': 'Uzbekistan'},
#  {'code': 'VM', 'count': 2099, 'locations': 2, 'cities': 1},
#  {'code': 'VN',
#   'count': 73091,
#   'locations': 5,
#   'cities': 3,
#   'name': 'Viet Nam'},
#  {'code': 'XK',
#   'count': 411255,
#   'locations': 9,
#   'cities': 8,
#   'name': 'Kosovo'},
#  {'code': 'ZA',
#   'count': 239159,
#   'locations': 3,
#   'cities': 1,
#   'name': 'South Africa'}]

# %%
# Convert to DF
data = pd.DataFrame(response.json()['results'])
data['name'].unique()
data.head()
# data.columns
# Out:
#    cities code   count  locations                  name
# 0       2   AD  116822          3               Andorra
# 1       3   AE   75269          4  United Arab Emirates
# 2       2   AF    6885          2           Afghanistan
# 3       1   AG       1          1   Antigua and Barbuda
# 4       1   AR   14976          4             Argentina

# %%
# Countries with the highest number of observations
data = pd.DataFrame(json_normalize(response.json()['results']))
data.sort_values(by='count', ascending=False).head(10)
# Out:
#     cities code      count  locations            name
# 42      14   IL  173130367       2041          Israel
# 20     387   CN  100527247       1724           China
# 92     790   US   67345323       2264   United States
# 43     234   IN   29192966        453           India
# 32     135   FR   25277254       1504          France
# 29     115   ES   23811054       1235           Spain
# 26      36   DE   12113999       1086         Germany
# 33     112   GB   11112842        162  United Kingdom
# 68      67   NL    8939474        111     Netherlands
# 74     172   PL    8277670        233          Poland

# %% [markdown]
# ## Requesting the latest data.

# %%
# criar outro df pra measurements
url = "https://api.openaq.org/v1/latest?country=US"

response = requests.get(url)
response
response.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': 'CC BY 4.0',
#   'website': 'https://docs.openaq.org/',
#   'page': 1,
#   'limit': 100,
#   'found': 2179},
#  'results': [{'location': '1001',
#    'city': 'CA8 - ARB',
#    'country': 'US',
#    'distance': 8649803.843769072,
#    'measurements': [{'parameter': 'pm25',
#      'value': 13.9,
#      'lastUpdated': '2020-03-09T15:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.684364, 'longitude': -120.98818}},
#   {'location': '1008',
#    'city': 'CA8 - ARB',
#    'country': 'US',
#    'distance': 8648898.391832057,
#    'measurements': [{'parameter': 'pm25',
#      'value': -4.2,
#      'lastUpdated': '2020-03-09T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.67386, 'longitude': -120.94338}},
#   {'location': '16th and Whitmore',
#    'city': 'Omaha-Council Bluffs',
#    'country': 'US',
#    'distance': 7177301.417128936,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.016,
#      'lastUpdated': '2017-11-01T11:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.32247, 'longitude': -95.93799}},
#   {'location': '1NL Navajo Lake',
#    'city': 'Farmington',
#    'country': 'US',
#    'distance': 8195307.26361047,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.024,
#      'lastUpdated': '2017-01-13T15:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 36.8097, 'longitude': -107.6517}},
#   {'location': '22nd Street & Craycr',
#    'city': 'Tucson',
#    'country': 'US',
#    'distance': 8784943.17147377,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.046,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 32.205, 'longitude': -110.8772}},
#   {'location': '24th & O',
#    'city': 'Omaha-Council Bluffs',
#    'country': 'US',
#    'distance': 7187427.691730639,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.012,
#      'lastUpdated': '2017-11-01T11:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.208084, 'longitude': -95.94744}},
#   {'location': '2912 Coffey',
#    'city': 'Omaha-Council Bluffs',
#    'country': 'US',
#    'distance': 7194185.186929283,
#    'measurements': [{'parameter': 'pm25',
#      'value': 5,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.133316, 'longitude': -95.95608}},
#   {'location': '2LL Los Lunas',
#    'city': 'Albuquerque',
#    'country': 'US',
#    'distance': 8328980.69448495,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.051,
#      'lastUpdated': '2020-03-28T04:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 34.8147, 'longitude': -106.7397}},
#   {'location': '46th and Farnam',
#    'city': 'Omaha-Council Bluffs',
#    'country': 'US',
#    'distance': 7185285.54561945,
#    'measurements': [{'parameter': 'pm10',
#      'value': 0,
#      'lastUpdated': '2018-04-25T04:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.257317, 'longitude': -95.98383}},
#   {'location': '5511 39TH STREET EAS',
#    'city': 'Sarasota-Bradenton-Venice',
#    'country': 'US',
#    'distance': 7532748.490766933,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.013,
#      'lastUpdated': '2017-11-07T02:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 27.4494, 'longitude': -82.5219}},
#   {'location': '60 Near Road',
#    'city': 'SAN BERNARDINO',
#    'country': 'US',
#    'distance': 8945838.747706125,
#    'measurements': [{'parameter': 'pm25',
#      'value': 51,
#      'lastUpdated': '2018-06-08T16:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.01,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 34.0309, 'longitude': -117.6174}},
#   {'location': '6th District',
#    'city': 'Cleveland-Elyria-Mentor',
#    'country': 'US',
#    'distance': 6331878.425098593,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.013,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.55523, 'longitude': -81.57526}},
#   {'location': '7004',
#    'city': 'ARCHULETA',
#    'country': 'US',
#    'distance': 8138934.023784697,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.042,
#      'lastUpdated': '2020-02-10T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0.002,
#      'lastUpdated': '2020-02-10T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.003,
#      'lastUpdated': '2020-02-10T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 37.20586, 'longitude': -107.25412}},
#   {'location': '710 Near Road',
#    'city': 'LOS ANGELES',
#    'country': 'US',
#    'distance': 8989599.421484336,
#    'measurements': [{'parameter': 'no2',
#      'value': 0.007,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 16.5,
#      'lastUpdated': '2018-06-08T12:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.85966, 'longitude': -118.20071}},
#   {'location': '77th and Dodge',
#    'city': 'Omaha-Council Bluffs',
#    'country': 'US',
#    'distance': 7187890.9913759325,
#    'measurements': [{'parameter': 'co',
#      'value': 0.53,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.25948, 'longitude': -96.03471}},
#   {'location': '7E Deming Airport',
#    'city': 'Deming',
#    'country': 'US',
#    'distance': 8614537.812281048,
#    'measurements': [{'parameter': 'pm10',
#      'value': 19,
#      'lastUpdated': '2020-03-28T04:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 32.2558, 'longitude': -107.7228}},
#   {'location': 'A Street',
#    'city': 'FAIRBANKS NORTH STAR',
#    'country': 'US',
#    'distance': 6752105.38212125,
#    'measurements': [{'parameter': 'pm25',
#      'value': 10,
#      'lastUpdated': '2019-11-09T14:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 1,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 64.84593, 'longitude': -147.69328}},
#   {'location': 'ADEQ-DSR',
#    'city': 'Little Rock-North Little Rock',
#    'country': 'US',
#    'distance': 7531784.844261049,
#    'measurements': [{'parameter': 'pm25',
#      'value': 19.1,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 34.6811, 'longitude': -92.3283}},
#   {'location': 'AIR LAB',
#    'city': 'Knoxville',
#    'country': 'US',
#    'distance': 6916388.56689076,
#    'measurements': [{'parameter': 'pm25',
#      'value': 10.8,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 35.9803, 'longitude': -83.9306}},
#   {'location': 'AJ Maintenance Yard',
#    'city': 'Phoenix-Mesa-Scottsdale',
#    'country': 'US',
#    'distance': 8703994.653972011,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.046,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.4206, 'longitude': -111.5033}},
#   {'location': 'ALBA',
#    'city': 'Joplin',
#    'country': 'US',
#    'distance': 7437102.48145281,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.044,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 37.2385, 'longitude': -94.42468}},
#   {'location': 'ALBNY',
#    'city': 'Albany-Schenectady-Troy',
#    'country': 'US',
#    'distance': 5772957.254878105,
#    'measurements': [{'parameter': 'pm25',
#      'value': 9.5,
#      'lastUpdated': '2018-02-27T11:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 42.6425, 'longitude': -73.7547}},
#   {'location': 'ALLE',
#    'city': 'Allentown-Bethlehem-Easton',
#    'country': 'US',
#    'distance': 6027179.871044229,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.033,
#      'lastUpdated': '2018-10-13T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 0.9,
#      'lastUpdated': '2018-10-05T15:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.6119, 'longitude': -75.4325}},
#   {'location': 'ALLEN PARK',
#    'city': 'Detroit-Warren-Livonia',
#    'country': 'US',
#    'distance': 6377469.966850806,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.026,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 6.9,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0.001,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'co',
#      'value': 0,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 42.2283, 'longitude': -83.2092}},
#   {'location': 'ALSIP',
#    'city': 'Chicago-Naperville-Joliet',
#    'country': 'US',
#    'distance': 6686202.308580533,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.01,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': -0.4,
#      'lastUpdated': '2020-03-13T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.6708, 'longitude': -87.7325}},
#   {'location': 'ALTO',
#    'city': 'Altoona',
#    'country': 'US',
#    'distance': 6217710.366796827,
#    'measurements': [{'parameter': 'pm25',
#      'value': 8.1,
#      'lastUpdated': '2018-04-18T18:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.037,
#      'lastUpdated': '2018-04-18T18:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.515, 'longitude': -78.3889}},
#   {'location': 'ALTON',
#    'city': 'St. Louis',
#    'country': 'US',
#    'distance': 7051905.391993014,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.02,
#      'lastUpdated': '2019-11-06T15:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.8903, 'longitude': -90.1481}},
#   {'location': 'APOLLO BEACH',
#    'city': 'HILLSBOROUGH',
#    'country': 'US',
#    'distance': 7498394.9610799,
#    'measurements': [{'parameter': 'pm25',
#      'value': 14.1,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0.001,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 27.779713, 'longitude': -82.41984}},
#   {'location': 'APPLETON AAL',
#    'city': 'Appleton',
#    'country': 'US',
#    'distance': 6515251.333594199,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.031,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 7.7,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 44.3069, 'longitude': -88.3956}},
#   {'location': 'ARB OER',
#    'city': 'CA8 - ARB',
#    'country': 'US',
#    'distance': 8682610.447079215,
#    'measurements': [{'parameter': 'pm25',
#      'value': -4,
#      'lastUpdated': '2016-08-08T16:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.568504, 'longitude': -121.493256}},
#   {'location': 'AREN',
#    'city': 'Gettysburg',
#    'country': 'US',
#    'distance': 6195992.756090364,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.046,
#      'lastUpdated': '2018-04-18T18:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 7.4,
#      'lastUpdated': '2018-04-18T18:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.9233, 'longitude': -77.3081}},
#   {'location': 'ARNOLD',
#    'city': 'St. Louis',
#    'country': 'US',
#    'distance': 7102910.197134886,
#    'measurements': [{'parameter': 'pm10',
#      'value': 19,
#      'lastUpdated': '2019-11-15T13:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 13,
#      'lastUpdated': '2019-11-15T13:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.003,
#      'lastUpdated': '2019-11-06T12:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.44858, 'longitude': -90.39844}},
#   {'location': 'ARNOLD WEST',
#    'city': 'St. Louis',
#    'country': 'US',
#    'distance': 7102910.197134886,
#    'measurements': [{'parameter': 'pm10',
#      'value': 19,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 14.7,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.024,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.44858, 'longitude': -90.39844}},
#   {'location': 'ASHBURN',
#    'city': 'Washington-Arlington-Alexandria',
#    'country': 'US',
#    'distance': 6276158.884019279,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.036,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.003,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.0244, 'longitude': -77.49}},
#   {'location': 'ATHENS',
#    'city': 'Athens',
#    'country': 'US',
#    'distance': 7000618.967292415,
#    'measurements': [{'parameter': 'pm25',
#      'value': 4,
#      'lastUpdated': '2020-03-26T15:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 35.4511, 'longitude': -84.5992}},
#   {'location': 'AURORA HILLS',
#    'city': 'Washington-Arlington-Alexandria',
#    'country': 'US',
#    'distance': 6261899.812380249,
#    'measurements': [{'parameter': 'no2',
#      'value': 0.004,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.039,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'co',
#      'value': 0.3,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.8594, 'longitude': -77.0589}},
#   {'location': 'Aberdeen',
#    'city': 'BROWN',
#    'country': 'US',
#    'distance': 6965753.835811586,
#    'measurements': [{'parameter': 'pm10',
#      'value': 16,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 9.8,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 45.468597, 'longitude': -98.494064}},
#   {'location': 'Aberdeen Bus Stop',
#    'city': 'BROWN',
#    'country': 'US',
#    'distance': 6965753.835811586,
#    'measurements': [{'parameter': 'pm10',
#      'value': 3,
#      'lastUpdated': '2020-01-03T12:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 2.3,
#      'lastUpdated': '2020-01-03T12:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 45.468597, 'longitude': -98.494064}},
#   {'location': 'Aberdeen-Division St',
#    'city': 'Aberdeen',
#    'country': 'US',
#    'distance': 7959992.474581845,
#    'measurements': [{'parameter': 'pm25',
#      'value': 1.4,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 46.9772, 'longitude': -123.8317}},
#   {'location': 'Abington',
#    'city': 'Willimantic',
#    'country': 'US',
#    'distance': 5722324.975196214,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.043,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.8402, 'longitude': -72.01}},
#   {'location': 'Acadia NP - McFarlan',
#    'city': 'HANCOCK',
#    'country': 'US',
#    'distance': 5308068.745435378,
#    'measurements': [{'parameter': 'pm25',
#      'value': 1.4,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.049,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 44.37705, 'longitude': -68.2609}},
#   {'location': 'Adams',
#    'city': 'Denver-Aurora',
#    'country': 'US',
#    'distance': 7784550.5565611245,
#    'measurements': [{'parameter': 'pm25',
#      'value': 2.2,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.82839, 'longitude': -104.93846}},
#   {'location': 'Airway Heights-West',
#    'city': 'SPOKANE',
#    'country': 'US',
#    'distance': 7654038.063082634,
#    'measurements': [{'parameter': 'pm25',
#      'value': 2.9,
#      'lastUpdated': '2018-06-14T19:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 47.64535, 'longitude': -117.58903}},
#   {'location': 'Ajo',
#    'city': 'PIMA',
#    'country': 'US',
#    'distance': 8869658.605333017,
#    'measurements': [{'parameter': 'pm10',
#      'value': 3,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 32.382034, 'longitude': -112.85745}},
#   {'location': 'Akron - NIHF_STEM',
#    'city': 'Akron',
#    'country': 'US',
#    'distance': 6365032.717139833,
#    'measurements': [{'parameter': 'co',
#      'value': 0,
#      'lastUpdated': '2017-04-25T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2017-04-25T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.07914, 'longitude': -81.51627}},
#   {'location': 'Akron NIFH/STEM',
#    'city': 'Akron',
#    'country': 'US',
#    'distance': 6365032.717139833,
#    'measurements': [{'parameter': 'co',
#      'value': 0.1,
#      'lastUpdated': '2018-11-14T13:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0.001,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.07914, 'longitude': -81.51627}},
#   {'location': 'Alabama-Coushatta',
#    'city': 'POLK',
#    'country': 'US',
#    'distance': 8015873.347053468,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.027,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 30.6681, 'longitude': -94.6739}},
#   {'location': 'Alamo Lake',
#    'city': 'LA PAZ',
#    'country': 'US',
#    'distance': 8730011.823559327,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.036,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0.001,
#      'lastUpdated': '2016-03-23T04:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm10',
#      'value': 8,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 4,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 34.24389, 'longitude': -113.55861}},
#   {'location': 'Albany',
#    'city': 'Albany-Schenectady-Troy',
#    'country': 'US',
#    'distance': 5772957.254878105,
#    'measurements': [{'parameter': 'pm25',
#      'value': 5.2,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.018,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 22.3,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 42.6425, 'longitude': -73.7547}},
#   {'location': 'Albany - Calapooia S',
#    'city': 'Albany-Lebanon',
#    'country': 'US',
#    'distance': 8161037.629364586,
#    'measurements': [{'parameter': 'pm25',
#      'value': 4.4,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 44.61569, 'longitude': -123.09145}},
#   {'location': 'Albemarle HS',
#    'city': 'Charlottesville',
#    'country': 'US',
#    'distance': 6412869.10945016,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.041,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 10.3,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.0766, 'longitude': -78.504}},
#   {'location': 'Aldino',
#    'city': 'Baltimore-Towson',
#    'country': 'US',
#    'distance': 6154563.720631901,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.043,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.5633, 'longitude': -76.2039}},
#   {'location': 'Alhambra',
#    'city': 'St. Louis',
#    'country': 'US',
#    'distance': 7022991.202887204,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.024,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.869, 'longitude': -89.6228}},
#   {'location': 'Allentown',
#    'city': 'Allentown-Bethlehem-Easton',
#    'country': 'US',
#    'distance': 6027179.871044229,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.028,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 6.7,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.6119, 'longitude': -75.4325}},
#   {'location': 'Alliance',
#    'city': 'Canton-Massillon',
#    'country': 'US',
#    'distance': 6352705.596505593,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.023,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.931396, 'longitude': -81.12352}},
#   {'location': 'Alpine',
#    'city': 'San Diego-Carlsbad-San Marcos',
#    'country': 'US',
#    'distance': 9018997.997884152,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.043,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 3.2,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 32.842297, 'longitude': -116.768326}},
#   {'location': 'Alton',
#    'city': 'MADISON',
#    'country': 'US',
#    'distance': 7050888.905160132,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.022,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.901318, 'longitude': -90.14621}},
#   {'location': 'Altoona',
#    'city': 'Altoona',
#    'country': 'US',
#    'distance': 6217710.366796827,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.03,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 4.2,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.515, 'longitude': -78.3889}},
#   {'location': 'Amanda  Elementary',
#    'city': 'BUTLER',
#    'country': 'US',
#    'distance': 6664534.137256318,
#    'measurements': [{'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 8.3,
#      'lastUpdated': '2018-05-18T18:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.478848, 'longitude': -84.40768}},
#   {'location': 'Amarillo Texas A&M C',
#    'city': 'Amarillo',
#    'country': 'US',
#    'distance': 8034127.475552028,
#    'measurements': [{'parameter': 'pm25',
#      'value': 2,
#      'lastUpdated': '2018-07-12T15:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 35.2006, 'longitude': -101.9083}},
#   {'location': 'Amherst',
#    'city': 'Buffalo-Niagara Falls',
#    'country': 'US',
#    'distance': 6054378.315844382,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.038,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 42.9925, 'longitude': -78.7764}},
#   {'location': 'Anacortes-202 Ave',
#    'city': 'SKAGIT',
#    'country': 'US',
#    'distance': 7765771.579261149,
#    'measurements': [{'parameter': 'pm25',
#      'value': 4,
#      'lastUpdated': '2017-01-11T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.031,
#      'lastUpdated': '2017-01-04T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 48.52059, 'longitude': -122.61428}},
#   {'location': 'Anacortes-202 Ave (S',
#    'city': 'SKAGIT',
#    'country': 'US',
#    'distance': 7765771.579261149,
#    'measurements': [{'parameter': 'pm25',
#      'value': 3,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.036,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 48.52059, 'longitude': -122.61428}},
#   {'location': 'Anacortes-Bartholome',
#    'city': 'SKAGIT',
#    'country': 'US',
#    'distance': 7769064.754632948,
#    'measurements': [{'parameter': 'pm25',
#      'value': 1.3,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 48.4654, 'longitude': -122.56}},
#   {'location': 'Anaheim',
#    'city': 'Los Angeles-Long Beach-Santa Ana',
#    'country': 'US',
#    'distance': 8980103.759161258,
#    'measurements': [{'parameter': 'co',
#      'value': 0.18,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.039,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm10',
#      'value': 14,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 5.6,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.004,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.830585, 'longitude': -117.93851}},
#   {'location': 'Anaheim Near Road',
#    'city': 'ORANGE',
#    'country': 'US',
#    'distance': 8980257.393347904,
#    'measurements': [{'parameter': 'co',
#      'value': 0.38,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.01,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.819305, 'longitude': -117.91876}},
#   {'location': 'Ancora State Hosptia',
#    'city': 'Philadelphia-Camden-Wilmington',
#    'country': 'US',
#    'distance': 6061188.368006626,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.043,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.68425, 'longitude': -74.86149}},
#   {'location': 'Anderson',
#    'city': 'Redding',
#    'country': 'US',
#    'distance': 8533421.995261427,
#    'measurements': [{'parameter': 'pm25',
#      'value': 14.7,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.04,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.4531, 'longitude': -122.2978}},
#   {'location': 'Anderson-Eastside El',
#    'city': 'Anderson',
#    'country': 'US',
#    'distance': 6687405.816089379,
#    'measurements': [{'parameter': 'pm25',
#      'value': 20.1,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.125557, 'longitude': -85.65222}},
#   {'location': 'Andrew Johnson Elem.',
#    'city': 'Kingsport-Bristol-Bristol',
#    'country': 'US',
#    'distance': 6785769.122134493,
#    'measurements': [{'parameter': 'so2',
#      'value': 0.01,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 36.526417, 'longitude': -82.52868}},
#   {'location': 'Ann Arbor',
#    'city': 'Ann Arbor',
#    'country': 'US',
#    'distance': 6403831.757466411,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.028,
#      'lastUpdated': '2020-03-28T13:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 42.4164, 'longitude': -83.9019}},
#   {'location': 'Antelope - North Hig',
#    'city': 'Sacramento--Arden-Arcade--Roseville',
#    'country': 'US',
#    'distance': 8663912.794083212,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.039,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'co',
#      'value': 0.4,
#      'lastUpdated': '2019-11-01T21:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.007,
#      'lastUpdated': '2017-11-14T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.71209, 'longitude': -121.38109}},
#   {'location': 'Anthony',
#    'city': 'Las Cruces',
#    'country': 'US',
#    'distance': 8577265.877009425,
#    'measurements': [{'parameter': 'pm10',
#      'value': 14,
#      'lastUpdated': '2020-03-28T04:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 7,
#      'lastUpdated': '2020-03-28T04:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 32.0036, 'longitude': -106.5992}},
#   {'location': 'Apache Junction',
#    'city': 'Phoenix-Mesa-Scottsdale',
#    'country': 'US',
#    'distance': 8704096.254074752,
#    'measurements': [{'parameter': 'pm10',
#      'value': 4,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.42, 'longitude': -111.5042}},
#   {'location': 'Apex',
#    'city': 'Las Vegas-Paradise',
#    'country': 'US',
#    'distance': 8593491.542333277,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.029,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 36.39103, 'longitude': -114.90743}},
#   {'location': 'Apple Valley',
#    'city': 'Minneapolis-St. Paul-Bloomington',
#    'country': 'US',
#    'distance': 6748231.133455951,
#    'measurements': [{'parameter': 'pm25',
#      'value': 5,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 44.7383, 'longitude': -93.2372}},
#   {'location': 'Archbold Biomedical',
#    'city': 'Sebring',
#    'country': 'US',
#    'distance': 7478141.308598186,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.064,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 27.1889, 'longitude': -81.3403}},
#   {'location': 'Arden Arcade - Del P',
#    'city': 'Sacramento--Arden-Arcade--Roseville',
#    'country': 'US',
#    'distance': 8672879.199325765,
#    'measurements': [{'parameter': 'co',
#      'value': 0.17,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.001,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.038,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'bc',
#      'value': 0,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 8,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.613804, 'longitude': -121.368004}},
#   {'location': 'Arendtsville',
#    'city': 'Gettysburg',
#    'country': 'US',
#    'distance': 6195992.756090364,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.025,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 11.3,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.9233, 'longitude': -77.3081}},
#   {'location': 'Arlington Municipal',
#    'city': 'Dallas-Fort Worth-Arlington',
#    'country': 'US',
#    'distance': 7985273.432166468,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.049,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 7.1,
#      'lastUpdated': '2018-12-04T15:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 32.6558, 'longitude': -97.0886}},
#   {'location': 'Arvin - Di Giorgio S',
#    'city': 'KERN',
#    'country': 'US',
#    'distance': 8884380.255467417,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.033,
#      'lastUpdated': '2019-12-01T19:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 35.23918, 'longitude': -118.78863}},
#   {'location': 'Ascarate Park Southe',
#    'city': 'El Paso',
#    'country': 'US',
#    'distance': 8590054.708319996,
#    'measurements': [{'parameter': 'o3',
#      'value': 0,
#      'lastUpdated': '2020-03-25T12:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 12.4,
#      'lastUpdated': '2020-03-25T12:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 31.7467, 'longitude': -106.4028}},
#   {'location': 'Ashland',
#    'city': 'AROOSTOOK',
#    'country': 'US',
#    'distance': 5167872.396081304,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.046,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 46.604, 'longitude': -68.4135}},
#   {'location': 'Ashland Fire Dept',
#    'city': 'JACKSON',
#    'country': 'US',
#    'distance': 8381013.480976249,
#    'measurements': [{'parameter': 'pm25',
#      'value': 5.6,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 42.1941, 'longitude': -122.7086}},
#   {'location': 'Ashton',
#    'city': 'Walterboro',
#    'country': 'US',
#    'distance': 6972369.087724689,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.04,
#      'lastUpdated': '2019-03-06T15:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 5,
#      'lastUpdated': '2019-03-06T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.0078, 'longitude': -80.965}},
#   {'location': 'Aspen Park',
#    'city': 'Denver-Aurora',
#    'country': 'US',
#    'distance': 7828563.102869393,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.034,
#      'lastUpdated': '2019-09-16T15:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.5415, 'longitude': -105.2984}},
#   {'location': 'Atascadero2',
#    'city': 'San Luis Obispo-Paso Robles',
#    'country': 'US',
#    'distance': 8944521.759469606,
#    'measurements': [{'parameter': 'no2',
#      'value': 0.001,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm10',
#      'value': 11,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 8,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.035,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 35.494556, 'longitude': -120.66621}},
#   {'location': 'Atascocita C560',
#    'city': 'Houston',
#    'country': 'US',
#    'distance': 8110878.608591575,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.051,
#      'lastUpdated': '2016-03-06T19:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'Texas',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 29.961945, 'longitude': -95.235}},
#   {'location': 'Athens',
#    'city': 'Athens-Clarke County',
#    'country': 'US',
#    'distance': 7048228.966435908,
#    'measurements': [{'parameter': 'pm10',
#      'value': 29,
#      'lastUpdated': '2020-03-27T19:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 19.6,
#      'lastUpdated': '2020-03-27T19:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.035,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.925, 'longitude': -83.3575}},
#   {'location': 'Athens Supersite',
#    'city': 'Athens',
#    'country': 'US',
#    'distance': 6539549.928084058,
#    'measurements': [{'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2017-04-13T14:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.039,
#      'lastUpdated': '2016-07-01T12:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'co',
#      'value': 2.8,
#      'lastUpdated': '2016-08-11T14:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.001,
#      'lastUpdated': '2016-05-03T12:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.308, 'longitude': -82.1183}},
#   {'location': 'Auburn',
#    'city': 'Sacramento--Arden-Arcade--Roseville',
#    'country': 'US',
#    'distance': 8630236.775040418,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.045,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 13,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.9378, 'longitude': -121.1039}},
#   {'location': 'Auburn M St SE',
#    'city': 'KING',
#    'country': 'US',
#    'distance': 7869341.479447658,
#    'measurements': [{'parameter': 'pm25',
#      'value': 14.6,
#      'lastUpdated': '2018-07-25T13:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': -1,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 47.2875, 'longitude': -122.2144}},
#   {'location': 'Audubon C38',
#    'city': 'Austin-Round Rock',
#    'country': 'US',
#    'distance': 8221408.914641437,
#    'measurements': [{'parameter': 'pm25',
#      'value': 2.6,
#      'lastUpdated': '2017-11-14T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.041,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 30.483168, 'longitude': -97.8723}},
#   {'location': 'Augusta',
#    'city': 'Augusta-Richmond County',
#    'country': 'US',
#    'distance': 7004546.15261561,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.028,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm10',
#      'value': 11,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 18.1,
#      'lastUpdated': '2020-03-27T19:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.4333, 'longitude': -82.0219}},
#   {'location': 'Aurora East',
#    'city': 'ARAPAHOE',
#    'country': 'US',
#    'distance': 7782393.134594338,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.051,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.638542, 'longitude': -104.56906}},
#   {'location': 'Austin Northwest C3',
#    'city': 'Austin-Round Rock',
#    'country': 'US',
#    'distance': 8226174.418969353,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.012,
#      'lastUpdated': '2020-02-18T13:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 14.6,
#      'lastUpdated': '2020-02-18T13:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 30.3542, 'longitude': -97.76}},
#   {'location': 'Austin Webberville R',
#    'city': 'Austin-Round Rock',
#    'country': 'US',
#    'distance': 8231420.724692773,
#    'measurements': [{'parameter': 'pm25',
#      'value': 18.5,
#      'lastUpdated': '2016-09-20T13:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 30.2633, 'longitude': -97.7131}},
#   {'location': 'Avenida de la Indust',
#    'city': 'El Paso',
#    'country': 'US',
#    'distance': 8592792.216584943,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.002,
#      'lastUpdated': '2017-11-23T03:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'co',
#      'value': 0.7,
#      'lastUpdated': '2017-12-30T12:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 31.7122, 'longitude': -106.3953}},
#   {'location': 'Avon',
#    'city': 'Indianapolis',
#    'country': 'US',
#    'distance': 6760895.256223481,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.026,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.7589, 'longitude': -86.3972}},
#   {'location': 'Azalea',
#    'city': 'Tampa-St. Petersburg-Clearwater',
#    'country': 'US',
#    'distance': 7518526.5344167035,
#    'measurements': [{'parameter': 'pm25',
#      'value': 13.2,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.002,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.049,
#      'lastUpdated': '2020-03-28T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 27.7858, 'longitude': -82.74}}]}

# %%
# Extracting the data 'results'
data = pd.DataFrame(json_normalize(response.json()['results'])).reset_index()
data.shape
data.head()
# Out:
#    index                  city  coordinates.latitude  coordinates.longitude  \
# 0      0             CA8 - ARB             38.684364             -120.98818
# 1      1             CA8 - ARB             38.673860             -120.94338
# 2      2  Omaha-Council Bluffs             41.322470              -95.93799
# 3      3            Farmington             36.809700             -107.65170
# 4      4                Tucson             32.205000             -110.87720
#
#   country      distance              location  \
# 0      US  8.649804e+06                  1001
# 1      US  8.648898e+06                  1008
# 2      US  7.177301e+06     16th and Whitmore
# 3      US  8.195307e+06       1NL Navajo Lake
# 4      US  8.784943e+06  22nd Street & Craycr
#
#                                         measurements
# 0  [{'parameter': 'pm25', 'value': 13.9, 'lastUpd...
# 1  [{'parameter': 'pm25', 'value': -4.2, 'lastUpd...
# 2  [{'parameter': 'o3', 'value': 0.016, 'lastUpda...
# 3  [{'parameter': 'o3', 'value': 0.024, 'lastUpda...
# 4  [{'parameter': 'o3', 'value': 0.046, 'lastUpda...

# %% [markdown]
# ### Flattening the DataFrame

# %%
dic_flatten = [flatten(d) for d in response.json()['results']]
dic_flatten
data_flatten = pd.DataFrame(dic_flatten).reset_index()
data_flatten.head()
# # data.shape
# data.columns

# Create for loop to extract parameters individually?
# Out:
#    index                  city  coordinates_latitude  coordinates_longitude  \
# 0      0             CA8 - ARB             38.684364             -120.98818
# 1      1             CA8 - ARB             38.673860             -120.94338
# 2      2  Omaha-Council Bluffs             41.322470              -95.93799
# 3      3            Farmington             36.809700             -107.65170
# 4      4                Tucson             32.205000             -110.87720
#
#   country      distance              location  \
# 0      US  8.649804e+06                  1001
# 1      US  8.648898e+06                  1008
# 2      US  7.177301e+06     16th and Whitmore
# 3      US  8.195307e+06       1NL Navajo Lake
# 4      US  8.784943e+06  22nd Street & Craycr
#
#   measurements_0_averagingPeriod_unit  measurements_0_averagingPeriod_value  \
# 0                               hours                                     1
# 1                               hours                                     1
# 2                               hours                                     1
# 3                               hours                                     1
# 4                               hours                                     1
#
#   measurements_0_lastUpdated  ... measurements_4_sourceName  \
# 0   2020-03-09T15:00:00.000Z  ...                       NaN
# 1   2020-03-09T17:00:00.000Z  ...                       NaN
# 2   2017-11-01T11:00:00.000Z  ...                       NaN
# 3   2017-01-13T15:00:00.000Z  ...                       NaN
# 4   2020-03-28T17:00:00.000Z  ...                       NaN
#
#   measurements_4_unit measurements_4_value  \
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
#    measurements_5_averagingPeriod_unit measurements_5_averagingPeriod_value  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    measurements_5_lastUpdated measurements_5_parameter  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
#
#   measurements_5_sourceName measurements_5_unit measurements_5_value
# 0                       NaN                 NaN                  NaN
# 1                       NaN                 NaN                  NaN
# 2                       NaN                 NaN                  NaN
# 3                       NaN                 NaN                  NaN
# 4                       NaN                 NaN                  NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# #### Trying to extract the parameters(sub dicts):

# %%
# First Try:

# len(data['measurements'])
# data['measurements'].apply(lambda x: json_normalize(dict(x)))

# %%
# Second Try:
data['measurements'][2]

# transformar em pd series
measurements = data['measurements'].apply(lambda x: pd.Series(x[0]))
measurements.head()

# Extracted only the first dictionary (parameter)
# Out:
#   parameter   value               lastUpdated   unit sourceName  \
# 0      pm25  13.900  2020-03-09T15:00:00.000Z  µg/m³     AirNow
# 1      pm25  -4.200  2020-03-09T17:00:00.000Z  µg/m³     AirNow
# 2        o3   0.016  2017-11-01T11:00:00.000Z    ppm     AirNow
# 3        o3   0.024  2017-01-13T15:00:00.000Z    ppm     AirNow
# 4        o3   0.046  2020-03-28T17:00:00.000Z    ppm     AirNow
#
#                  averagingPeriod
# 0  {'value': 1, 'unit': 'hours'}
# 1  {'value': 1, 'unit': 'hours'}
# 2  {'value': 1, 'unit': 'hours'}
# 3  {'value': 1, 'unit': 'hours'}
# 4  {'value': 1, 'unit': 'hours'}

# %%
# Merge tbales
# data.merge(measurements,  left_index=True,  right_index=True)
# drop measurements

# %% [markdown]
# ## Requesting by  Measurements

# %% [markdown]
# ### PM25

# %%
url = "https://api.openaq.org/v1/measurements?parameter=pm25"

response = requests.get(url)
response
response.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': 'CC BY 4.0',
#   'website': 'https://docs.openaq.org/',
#   'page': 1,
#   'limit': 100,
#   'found': 64245006},
#  'results': [{'location': 'Coyhaique',
#    'parameter': 'pm25',
#    'date': {'utc': '2028-08-05T20:00:00.000Z',
#     'local': '2028-08-05T16:00:00-04:00'},
#    'value': 81,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': -45.57996447948, 'longitude': -72.061125987766},
#    'country': 'CL',
#    'city': 'Coyhaique'},
#   {'location': 'Coyhaique',
#    'parameter': 'pm25',
#    'date': {'utc': '2028-07-01T22:00:00.000Z',
#     'local': '2028-07-01T18:00:00-04:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': -45.57996447948, 'longitude': -72.061125987766},
#    'country': 'CL',
#    'city': 'Coyhaique'},
#   {'location': 'Coyhaique',
#    'parameter': 'pm25',
#    'date': {'utc': '2027-10-30T12:00:00.000Z',
#     'local': '2027-10-30T09:00:00-03:00'},
#    'value': 18,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': -45.57996447948, 'longitude': -72.061125987766},
#    'country': 'CL',
#    'city': 'Coyhaique'},
#   {'location': 'Coyhaique',
#    'parameter': 'pm25',
#    'date': {'utc': '2027-02-09T16:00:00.000Z',
#     'local': '2027-02-09T13:00:00-03:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': -45.57996447948, 'longitude': -72.061125987766},
#    'country': 'CL',
#    'city': 'Coyhaique'},
#   {'location': 'Coyhaique',
#    'parameter': 'pm25',
#    'date': {'utc': '2026-09-08T08:00:00.000Z',
#     'local': '2026-09-08T05:00:00-03:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': -45.57996447948, 'longitude': -72.061125987766},
#    'country': 'CL',
#    'city': 'Coyhaique'},
#   {'location': 'Coyhaique',
#    'parameter': 'pm25',
#    'date': {'utc': '2026-09-08T07:00:00.000Z',
#     'local': '2026-09-08T04:00:00-03:00'},
#    'value': 82,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': -45.57996447948, 'longitude': -72.061125987766},
#    'country': 'CL',
#    'city': 'Coyhaique'},
#   {'location': 'Sector 11, Faridabad - HSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T20:15:00.000Z',
#     'local': '2020-03-29T01:45:00+05:30'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.376058, 'longitude': 77.315741},
#    'country': 'IN',
#    'city': 'Faridabad'},
#   {'location': 'Pusa, Delhi - IMD',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:30:00.000Z',
#     'local': '2020-03-29T01:00:00+05:30'},
#    'value': -47.16,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.639645, 'longitude': 77.146263},
#    'country': 'IN',
#    'city': 'Delhi'},
#   {'location': 'Aya Nagar, Delhi - IMD',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:30:00.000Z',
#     'local': '2020-03-29T01:00:00+05:30'},
#    'value': 24.66,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.4706914, 'longitude': 77.1099364},
#    'country': 'IN',
#    'city': 'Delhi'},
#   {'location': 'North Campus, DU, Delhi - IMD',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:30:00.000Z',
#     'local': '2020-03-29T01:00:00+05:30'},
#    'value': -3.54,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.6573814, 'longitude': 77.1585447},
#    'country': 'IN',
#    'city': 'Delhi'},
#   {'location': 'Sector - 62, Noida - IMD',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:30:00.000Z',
#     'local': '2020-03-29T01:00:00+05:30'},
#    'value': -25.06,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.6245479, 'longitude': 77.3577104},
#    'country': 'IN',
#    'city': 'Noida'},
#   {'location': 'BTM Layout, Bengaluru - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:30:00.000Z',
#     'local': '2020-03-29T01:00:00+05:30'},
#    'value': 13.49,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 12.9135218, 'longitude': 77.5950804},
#    'country': 'IN',
#    'city': 'Bengaluru'},
#   {'location': 'Karve Road, Pune - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:30:00.000Z',
#     'local': '2020-03-29T01:00:00+05:30'},
#    'value': 13,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 18.5011743, 'longitude': 73.8165527},
#    'country': 'IN',
#    'city': 'Pune'},
#   {'location': 'BWSSB Kadabesanahalli, Bengaluru - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:30:00.000Z',
#     'local': '2020-03-29T01:00:00+05:30'},
#    'value': 66.75,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 12.9352049, 'longitude': 77.6814488},
#    'country': 'IN',
#    'city': 'Bengaluru'},
#   {'location': 'Sector-1, Noida - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:30:00.000Z',
#     'local': '2020-03-29T01:00:00+05:30'},
#    'value': 20,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.5898, 'longitude': 77.3101},
#    'country': 'IN',
#    'city': 'Noida'},
#   {'location': 'Gomti Nagar, Lucknow - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:30:00.000Z',
#     'local': '2020-03-29T01:00:00+05:30'},
#    'value': 22,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 26.86812, 'longitude': 81.005119},
#    'country': 'IN',
#    'city': 'Lucknow'},
#   {'location': 'GIDC, Nandesari - Nandesari Ind. Association',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 31,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 22.410802, 'longitude': 73.097923},
#    'country': 'IN',
#    'city': 'Nandesari'},
#   {'location': 'Pusa, Delhi - IMD',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': -54.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.639645, 'longitude': 77.146263},
#    'country': 'IN',
#    'city': 'Delhi'},
#   {'location': 'Aya Nagar, Delhi - IMD',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 23.02,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.4706914, 'longitude': 77.1099364},
#    'country': 'IN',
#    'city': 'Delhi'},
#   {'location': 'North Campus, DU, Delhi - IMD',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': -6.27,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.6573814, 'longitude': 77.1585447},
#    'country': 'IN',
#    'city': 'Delhi'},
#   {'location': 'Sector - 62, Noida - IMD',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': -23.02,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.6245479, 'longitude': 77.3577104},
#    'country': 'IN',
#    'city': 'Noida'},
#   {'location': 'BTM Layout, Bengaluru - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 13.49,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 12.9135218, 'longitude': 77.5950804},
#    'country': 'IN',
#    'city': 'Bengaluru'},
#   {'location': 'Karve Road, Pune - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 10,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 18.5011743, 'longitude': 73.8165527},
#    'country': 'IN',
#    'city': 'Pune'},
#   {'location': 'Vasundhara, Ghaziabad - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 23,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.6603346, 'longitude': 77.3572563},
#    'country': 'IN',
#    'city': 'Ghaziabad'},
#   {'location': 'BWSSB Kadabesanahalli, Bengaluru - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 66.75,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 12.9352049, 'longitude': 77.6814488},
#    'country': 'IN',
#    'city': 'Bengaluru'},
#   {'location': 'ICRISAT Patancheru, Hyderabad - TSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 45,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 17.4342359, 'longitude': 78.4170318},
#    'country': 'IN',
#    'city': 'Hyderabad'},
#   {'location': 'Tata Stadium, Jorapokhar - JSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 37,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 23.707909, 'longitude': 86.41467},
#    'country': 'IN',
#    'city': 'Jorapokhar'},
#   {'location': 'GVM Corporation, Visakhapatnam - APPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 13,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 17.72, 'longitude': 83.3},
#    'country': 'IN',
#    'city': 'Visakhapatnam'},
#   {'location': 'Sector- 16A, Faridabad - HSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 25,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.4088421, 'longitude': 77.3099081},
#    'country': 'IN',
#    'city': 'Faridabad'},
#   {'location': 'Bollaram Industrial Area, Hyderabad - TSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 45,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 17.540891, 'longitude': 78.358528},
#    'country': 'IN',
#    'city': 'Hyderabad'},
#   {'location': 'Nehru Nagar, Kanpur - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 25,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 26.4703136, 'longitude': 80.3229863},
#    'country': 'IN',
#    'city': 'Kanpur'},
#   {'location': 'Zoo Park, Hyderabad - TSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 51,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 17.349694, 'longitude': 78.451437},
#    'country': 'IN',
#    'city': 'Hyderabad'},
#   {'location': 'Sanjay Palace, Agra - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 36,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 27.19865833, 'longitude': 78.00598056},
#    'country': 'IN',
#    'city': 'Agra'},
#   {'location': 'Mahakaleshwar Temple, Ujjain - MPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 33,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 23.182719, 'longitude': 75.768218},
#    'country': 'IN',
#    'city': 'Ujjain'},
#   {'location': 'Sector-D Industrial Area, Mandideep - MPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 17,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 23.10844, 'longitude': 77.511428},
#    'country': 'IN',
#    'city': 'Mandideep'},
#   {'location': 'Bhopal Chauraha, Dewas - MPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 20,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 22.9682591, 'longitude': 76.064118},
#    'country': 'IN',
#    'city': 'Dewas'},
#   {'location': 'Secretariat, Amaravati - APPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 28,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 16.5150833, 'longitude': 80.5181667},
#    'country': 'IN',
#    'city': 'Amaravati'},
#   {'location': 'Bandhavgar Colony, Satna - Birla Cement',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 6.54,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 24.58434363, 'longitude': 80.8549414},
#    'country': 'IN',
#    'city': 'Satna'},
#   {'location': 'Knowledge Park - III, Greater Noida - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 17,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.47272, 'longitude': 77.482},
#    'country': 'IN',
#    'city': 'Greater Noida'},
#   {'location': 'New Mandi, Muzaffarnagar - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 19,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 29.4723508, 'longitude': 77.7194031},
#    'country': 'IN',
#    'city': 'Muzaffarnagar'},
#   {'location': 'Hebbal, Bengaluru - KSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 22,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 13.029152, 'longitude': 77.585901},
#    'country': 'IN',
#    'city': 'Bengaluru'},
#   {'location': 'Jayanagar 5th Block, Bengaluru - KSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 18,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 12.920984, 'longitude': 77.584908},
#    'country': 'IN',
#    'city': 'Bengaluru'},
#   {'location': 'Hombegowda Nagar, Bengaluru - KSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 29,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 12.938539, 'longitude': 77.5901},
#    'country': 'IN',
#    'city': 'Bengaluru'},
#   {'location': 'Phase-1 GIDC, Vapi - GPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 41.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 20.362421, 'longitude': 72.918013},
#    'country': 'IN',
#    'city': 'Vapi'},
#   {'location': 'Phase-4 GIDC, Vatva - GPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 24.88,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 22.969611, 'longitude': 72.6435},
#    'country': 'IN',
#    'city': 'Vatva'},
#   {'location': 'Indirapuram, Ghaziabad - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 17,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.646233, 'longitude': 77.358075},
#    'country': 'IN',
#    'city': 'Ghaziabad'},
#   {'location': 'Sanjay Nagar, Ghaziabad - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 43,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.685382, 'longitude': 77.453839},
#    'country': 'IN',
#    'city': 'Ghaziabad'},
#   {'location': 'Vile Parle West, Mumbai - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 15,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 19.10861, 'longitude': 72.83622},
#    'country': 'IN',
#    'city': 'Mumbai'},
#   {'location': 'Sector-116, Noida - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 20,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.56923, 'longitude': 77.393848},
#    'country': 'IN',
#    'city': 'Noida'},
#   {'location': 'Sector-1, Noida - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 20,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.5898, 'longitude': 77.3101},
#    'country': 'IN',
#    'city': 'Noida'},
#   {'location': 'Knowledge Park - V, Greater Noida - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 18,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.557054, 'longitude': 77.453663},
#    'country': 'IN',
#    'city': 'Greater Noida'},
#   {'location': 'Sector-25, Chandigarh - CPCC',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 30.751462, 'longitude': 76.762879},
#    'country': 'IN',
#    'city': 'Chandigarh'},
#   {'location': 'Gomti Nagar, Lucknow - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 22,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 26.86812, 'longitude': 81.005119},
#    'country': 'IN',
#    'city': 'Lucknow'},
#   {'location': 'Marhatal, Jabalpur - MPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 30,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 23.168606, 'longitude': 79.932247},
#    'country': 'IN',
#    'city': 'Jabalpur'},
#   {'location': 'Yamunapuram, Bulandshahr - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 25,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.406963, 'longitude': 77.849831},
#    'country': 'IN',
#    'city': 'Bulandshahr'},
#   {'location': 'GIDC, Ankleshwar - GPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 42.04,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 21.613267, 'longitude': 73.010555},
#    'country': 'IN',
#    'city': 'Ankleshwar'},
#   {'location': 'Rishi Nagar, Kaithal - HSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 10.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 29.8006, 'longitude': 76.4155},
#    'country': 'IN',
#    'city': 'Kaithal'},
#   {'location': 'Nerul, Navi Mumbai - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 34,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 19.008751, 'longitude': 73.01662},
#    'country': 'IN',
#    'city': 'Navi Mumbai'},
#   {'location': 'SIDCO Kurichi, Coimbatore - TNPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 30.06,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 10.942451, 'longitude': 76.978996},
#    'country': 'IN',
#    'city': 'Coimbatore'},
#   {'location': 'Kurla, Mumbai - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 39,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 19.0863, 'longitude': 72.8888},
#    'country': 'IN',
#    'city': 'Mumbai'},
#   {'location': 'Udyogamandal, Eloor - Kerala PCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 39.85,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 10.073232, 'longitude': 76.302765},
#    'country': 'IN',
#    'city': 'Eloor'},
#   {'location': 'Jadavpur, Kolkata - WBPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 57.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 22.49929, 'longitude': 88.36917},
#    'country': 'IN',
#    'city': 'Kolkata'},
#   {'location': 'Chhatrapati Shivaji Intl. Airport (T2), Mumbai - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 37,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 19.10078, 'longitude': 72.87462},
#    'country': 'IN',
#    'city': 'Mumbai'},
#   {'location': 'Borivali East, Mumbai - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 19,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 19.13276, 'longitude': 72.52048},
#    'country': 'IN',
#    'city': 'Mumbai'},
#   {'location': 'Khadakpada, Kalyan - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 985,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 19.25292, 'longitude': 73.142019},
#    'country': 'IN',
#    'city': 'Kalyan'},
#   {'location': 'Worli, Mumbai - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 24,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 18.9936162, 'longitude': 72.8128113},
#    'country': 'IN',
#    'city': 'Mumbai'},
#   {'location': 'Sion, Mumbai - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 27,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 19.047, 'longitude': 72.8746},
#    'country': 'IN',
#    'city': 'Mumbai'},
#   {'location': 'Mahape, Navi Mumbai - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 45.68,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 19.1135051, 'longitude': 73.008978},
#    'country': 'IN',
#    'city': 'Navi Mumbai'},
#   {'location': 'Colaba, Mumbai - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 24.33,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 18.91, 'longitude': 72.82},
#    'country': 'IN',
#    'city': 'Mumbai'},
#   {'location': 'Gole Bazar, Katni - MPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 27,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 23.50016, 'longitude': 80.23284},
#    'country': 'IN',
#    'city': 'Katni'},
#   {'location': 'Chhoti Gwaltoli, Indore - MPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 17,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 22.431, 'longitude': 75.5213},
#    'country': 'IN',
#    'city': 'Indore'},
#   {'location': 'Collector Office, Yadgir - KSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 37,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 16.7602, 'longitude': 77.1428},
#    'country': 'IN',
#    'city': 'Yadgir'},
#   {'location': 'Vijay Nagar, Ramanagara - KSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 22,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 12.733409, 'longitude': 77.298051},
#    'country': 'IN',
#    'city': 'Ramanagara'},
#   {'location': 'Ganga Nagar, Meerut - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 17,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.999264, 'longitude': 77.7590354},
#    'country': 'IN',
#    'city': 'Meerut'},
#   {'location': 'Pallavpuram Phase 2, Meerut - UPPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 27,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 29.06351, 'longitude': 77.709723},
#    'country': 'IN',
#    'city': 'Meerut'},
#   {'location': 'Vyttila, Kochi - Kerala PCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 26.63,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 9.969447, 'longitude': 76.321186},
#    'country': 'IN',
#    'city': 'Kochi'},
#   {'location': 'Palayam, Kozhikode - Kerala PCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 32.72,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 11.249077, 'longitude': 75.784371},
#    'country': 'IN',
#    'city': 'Kozhikode'},
#   {'location': 'DTU, Delhi - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 999.99,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.7500499, 'longitude': 77.1112615},
#    'country': 'IN',
#    'city': 'Delhi'},
#   {'location': 'ITO, Delhi - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 92,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.628624, 'longitude': 77.24106},
#    'country': 'IN',
#    'city': 'Delhi'},
#   {'location': 'NSIT Dwarka, Delhi - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 48.52,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.60909, 'longitude': 77.0325413},
#    'country': 'IN',
#    'city': 'Delhi'},
#   {'location': 'IHBAS, Dilshad Garden, Delhi - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 10,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.6811736, 'longitude': 77.3025234},
#    'country': 'IN',
#    'city': 'Delhi'},
#   {'location': 'Shadipur, Delhi - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 26.2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.6514781, 'longitude': 77.1473105},
#    'country': 'IN',
#    'city': 'Delhi'},
#   {'location': 'Sirifort, Delhi - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 36,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.5504249, 'longitude': 77.2159377},
#    'country': 'IN',
#    'city': 'Delhi'},
#   {'location': 'Bandra, Mumbai - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 18.93,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 19.0627, 'longitude': 72.84614},
#    'country': 'IN',
#    'city': 'Mumbai'},
#   {'location': 'MD University, Rohtak - HSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 39.06,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.52123, 'longitude': 76.37138},
#    'country': 'IN',
#    'city': 'Rohtak'},
#   {'location': 'Collectorate, Jodhpur - RSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 112.91,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 26.268249, 'longitude': 73.0193853},
#    'country': 'IN',
#    'city': 'Jodhpur'},
#   {'location': 'Peenya, Bengaluru - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 24.98,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 13.0270199, 'longitude': 77.494094},
#    'country': 'IN',
#    'city': 'Bengaluru'},
#   {'location': 'Collectorate, Gaya - BSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 63,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 24.7955, 'longitude': 84.9994},
#    'country': 'IN',
#    'city': 'Gaya'},
#   {'location': 'Plammoodu, Thiruvananthapuram - Kerala PCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 15,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 8.5149093, 'longitude': 76.9435879},
#    'country': 'IN',
#    'city': 'Thiruvananthapuram'},
#   {'location': 'Muzaffarpur Collectorate, Muzaffarpur - BSPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 34,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 26.1209, 'longitude': 85.3647},
#    'country': 'IN',
#    'city': 'Muzaffarpur'},
#   {'location': 'Central School, Lucknow - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 48.25,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 26.8821003, 'longitude': 80.9302753},
#    'country': 'IN',
#    'city': 'Lucknow'},
#   {'location': 'Sector-6, Panchkula - HSPCB ',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 6.18,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 30.7057778, 'longitude': 76.8531805555555},
#    'country': 'IN',
#    'city': 'Panchkula'},
#   {'location': 'Alandur Bus Depot, Chennai - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 16.34,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 12.9099161, 'longitude': 80.1076538},
#    'country': 'IN',
#    'city': 'Chennai'},
#   {'location': 'Velachery Res. Area, Chennai - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 21.68,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 13.0052189, 'longitude': 80.2398125},
#    'country': 'IN',
#    'city': 'Chennai'},
#   {'location': 'Talkatora District Industries Center, Lucknow - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 55.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 26.83399722, 'longitude': 80.8917361},
#    'country': 'IN',
#    'city': 'Lucknow'},
#   {'location': 'MIDC Khutala, Chandrapur - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 13.61,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 19.9775302, 'longitude': 79.2337086},
#    'country': 'IN',
#    'city': 'Chandrapur'},
#   {'location': 'Gangapur Road, Nashik - MPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 25.99,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 20.0073285, 'longitude': 73.7762427},
#    'country': 'IN',
#    'city': 'Nashik'},
#   {'location': 'Manali, Chennai - CPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 33.19,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 13.164544, 'longitude': 80.26285},
#    'country': 'IN',
#    'city': 'Chennai'},
#   {'location': 'Maninagar, Ahmedabad - GPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 21.73,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 23.002657, 'longitude': 72.591912},
#    'country': 'IN',
#    'city': 'Ahmedabad'},
#   {'location': 'Victoria, Kolkata - WBPCB',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-28T19:15:00.000Z',
#     'local': '2020-03-29T00:45:00+05:30'},
#    'value': 61.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 22.5448082, 'longitude': 88.3403691},
#    'country': 'IN',
#    'city': 'Kolkata'}]}

# %%
# pd.DataFrame(response.json())
data = pd.DataFrame(json_normalize(response.json()['results'])).reset_index()
data.tail()
# Out:
#     index        city  coordinates.latitude  coordinates.longitude country  \
# 95     95  Chandrapur             19.977530              79.233709      IN
# 96     96      Nashik             20.007328              73.776243      IN
# 97     97     Chennai             13.164544              80.262850      IN
# 98     98   Ahmedabad             23.002657              72.591912      IN
# 99     99     Kolkata             22.544808              88.340369      IN
#
#                    date.local                  date.utc  \
# 95  2020-03-29T00:45:00+05:30  2020-03-28T19:15:00.000Z
# 96  2020-03-29T00:45:00+05:30  2020-03-28T19:15:00.000Z
# 97  2020-03-29T00:45:00+05:30  2020-03-28T19:15:00.000Z
# 98  2020-03-29T00:45:00+05:30  2020-03-28T19:15:00.000Z
# 99  2020-03-29T00:45:00+05:30  2020-03-28T19:15:00.000Z
#
#                            location parameter   unit  value
# 95  MIDC Khutala, Chandrapur - MPCB      pm25  µg/m³  13.61
# 96     Gangapur Road, Nashik - MPCB      pm25  µg/m³  25.99
# 97           Manali, Chennai - CPCB      pm25  µg/m³  33.19
# 98      Maninagar, Ahmedabad - GPCB      pm25  µg/m³  21.73
# 99        Victoria, Kolkata - WBPCB      pm25  µg/m³  61.40

# %%
# Fazer requests separadas e depois concat

# Criar um for loop pra request de todos os parâmetros?

# Criar logica para buscar só as infos das cidades que quero analisar?
