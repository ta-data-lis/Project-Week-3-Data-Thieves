# %%
import pandas as pd
import numpy as np
import requests
from pandas.io.json import json_normalize
from flatten_json import flatten

# %% [markdown]
# # OpenAQ API Conection

# %% [markdown]
# ## List Countries

# %%
url = "https://api.openaq.org/v1/countries"

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.json()
# response.text
response.json()['results']
# Out:
# [{'code': 'AD',
#   'count': 117134,
#   'locations': 3,
#   'cities': 2,
#   'name': 'Andorra'},
#  {'code': 'AE',
#   'count': 75685,
#   'locations': 4,
#   'cities': 3,
#   'name': 'United Arab Emirates'},
#  {'code': 'AF',
#   'count': 6989,
#   'locations': 2,
#   'cities': 2,
#   'name': 'Afghanistan'},
#  {'code': 'AG',
#   'count': 1,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Antigua and Barbuda'},
#  {'code': 'AR',
#   'count': 14976,
#   'locations': 4,
#   'cities': 1,
#   'name': 'Argentina'},
#  {'code': 'AT',
#   'count': 1659404,
#   'locations': 541,
#   'cities': 25,
#   'name': 'Austria'},
#  {'code': 'AU',
#   'count': 6820975,
#   'locations': 168,
#   'cities': 53,
#   'name': 'Australia'},
#  {'code': 'BA',
#   'count': 1084500,
#   'locations': 22,
#   'cities': 10,
#   'name': 'Bosnia and Herzegovina'},
#  {'code': 'BD',
#   'count': 33651,
#   'locations': 2,
#   'cities': 1,
#   'name': 'Bangladesh'},
#  {'code': 'BE',
#   'count': 1803288,
#   'locations': 198,
#   'cities': 14,
#   'name': 'Belgium'},
#  {'code': 'BG',
#   'count': 3622,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Bulgaria'},
#  {'code': 'BH',
#   'count': 47289,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Bahrain'},
#  {'code': 'BK', 'count': 3621, 'locations': 1, 'cities': 1},
#  {'code': 'BM', 'count': 4611, 'locations': 1, 'cities': 1, 'name': 'Bermuda'},
#  {'code': 'BR',
#   'count': 304267,
#   'locations': 61,
#   'cities': 31,
#   'name': 'Brazil'},
#  {'code': 'CA',
#   'count': 6294986,
#   'locations': 213,
#   'cities': 12,
#   'name': 'Canada'},
#  {'code': 'CE', 'count': 6272, 'locations': 1, 'cities': 1},
#  {'code': 'CH',
#   'count': 1549794,
#   'locations': 30,
#   'cities': 15,
#   'name': 'Switzerland'},
#  {'code': 'CI',
#   'count': 352,
#   'locations': 1,
#   'cities': 1,
#   'name': "Côte d'Ivoire"},
#  {'code': 'CL',
#   'count': 8095648,
#   'locations': 238,
#   'cities': 163,
#   'name': 'Chile'},
#  {'code': 'CN',
#   'count': 100974638,
#   'locations': 1724,
#   'cities': 387,
#   'name': 'China'},
#  {'code': 'CO',
#   'count': 657339,
#   'locations': 34,
#   'cities': 12,
#   'name': 'Colombia'},
#  {'code': 'CR',
#   'count': 2831,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Costa Rica'},
#  {'code': 'CS', 'count': 3353, 'locations': 2, 'cities': 1},
#  {'code': 'CW',
#   'count': 22613,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Curaçao'},
#  {'code': 'CZ',
#   'count': 6126320,
#   'locations': 200,
#   'cities': 15,
#   'name': 'Czech Republic'},
#  {'code': 'DE',
#   'count': 12118284,
#   'locations': 1086,
#   'cities': 36,
#   'name': 'Germany'},
#  {'code': 'DK',
#   'count': 585902,
#   'locations': 25,
#   'cities': 7,
#   'name': 'Denmark'},
#  {'code': 'DZ', 'count': 6858, 'locations': 1, 'cities': 1, 'name': 'Algeria'},
#  {'code': 'ES',
#   'count': 23825133,
#   'locations': 1235,
#   'cities': 115,
#   'name': 'Spain'},
#  {'code': 'ET',
#   'count': 58932,
#   'locations': 3,
#   'cities': 2,
#   'name': 'Ethiopia'},
#  {'code': 'FI',
#   'count': 2026764,
#   'locations': 119,
#   'cities': 35,
#   'name': 'Finland'},
#  {'code': 'FR',
#   'count': 25335783,
#   'locations': 1504,
#   'cities': 135,
#   'name': 'France'},
#  {'code': 'GB',
#   'count': 11129792,
#   'locations': 162,
#   'cities': 112,
#   'name': 'United Kingdom'},
#  {'code': 'GH', 'count': 1595, 'locations': 11, 'cities': 1, 'name': 'Ghana'},
#  {'code': 'GI',
#   'count': 40842,
#   'locations': 6,
#   'cities': 2,
#   'name': 'Gibraltar'},
#  {'code': 'GT',
#   'count': 7234,
#   'locations': 2,
#   'cities': 2,
#   'name': 'Guatemala'},
#  {'code': 'HK',
#   'count': 1556168,
#   'locations': 16,
#   'cities': 9,
#   'name': 'Hong Kong'},
#  {'code': 'HR',
#   'count': 910283,
#   'locations': 50,
#   'cities': 17,
#   'name': 'Croatia'},
#  {'code': 'HU',
#   'count': 2168929,
#   'locations': 50,
#   'cities': 14,
#   'name': 'Hungary'},
#  {'code': 'ID',
#   'count': 79171,
#   'locations': 5,
#   'cities': 3,
#   'name': 'Indonesia'},
#  {'code': 'IE',
#   'count': 500621,
#   'locations': 38,
#   'cities': 16,
#   'name': 'Ireland'},
#  {'code': 'IL',
#   'count': 173130367,
#   'locations': 2041,
#   'cities': 14,
#   'name': 'Israel'},
#  {'code': 'IN',
#   'count': 29344532,
#   'locations': 454,
#   'cities': 234,
#   'name': 'India'},
#  {'code': 'IQ', 'count': 9140, 'locations': 1, 'cities': 1, 'name': 'Iraq'},
#  {'code': 'IS',
#   'count': 24847,
#   'locations': 15,
#   'cities': 8,
#   'name': 'Iceland'},
#  {'code': 'IT',
#   'count': 3877434,
#   'locations': 104,
#   'cities': 45,
#   'name': 'Italy'},
#  {'code': 'IZ', 'count': 2475, 'locations': 1, 'cities': 1},
#  {'code': 'JO', 'count': 7061, 'locations': 2, 'cities': 2, 'name': 'Jordan'},
#  {'code': 'KE', 'count': 2842, 'locations': 2, 'cities': 1, 'name': 'Kenya'},
#  {'code': 'KG',
#   'count': 12771,
#   'locations': 2,
#   'cities': 2,
#   'name': 'Kyrgyzstan'},
#  {'code': 'KU', 'count': 3471, 'locations': 1, 'cities': 1},
#  {'code': 'KV', 'count': 3625, 'locations': 1, 'cities': 1},
#  {'code': 'KW', 'count': 24402, 'locations': 1, 'cities': 1, 'name': 'Kuwait'},
#  {'code': 'KZ',
#   'count': 12141,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Kazakhstan'},
#  {'code': 'LA',
#   'count': 10110,
#   'locations': 2,
#   'cities': 2,
#   'name': "Lao People's Democratic Republic"},
#  {'code': 'LK',
#   'count': 19064,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Sri Lanka'},
#  {'code': 'LT',
#   'count': 443075,
#   'locations': 17,
#   'cities': 8,
#   'name': 'Lithuania'},
#  {'code': 'LU',
#   'count': 459415,
#   'locations': 7,
#   'cities': 3,
#   'name': 'Luxembourg'},
#  {'code': 'LV',
#   'count': 195674,
#   'locations': 4,
#   'cities': 4,
#   'name': 'Latvia'},
#  {'code': 'MG',
#   'count': 3273,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Madagascar'},
#  {'code': 'MK',
#   'count': 1265788,
#   'locations': 45,
#   'cities': 16,
#   'name': 'Macedonia, the Former Yugoslav Republic of'},
#  {'code': 'ML', 'count': 309, 'locations': 1, 'cities': 1, 'name': 'Mali'},
#  {'code': 'MM',
#   'count': 10070,
#   'locations': 2,
#   'cities': 2,
#   'name': 'Myanmar'},
#  {'code': 'MN',
#   'count': 2825857,
#   'locations': 44,
#   'cities': 25,
#   'name': 'Mongolia'},
#  {'code': 'MT', 'count': 264796, 'locations': 4, 'cities': 4, 'name': 'Malta'},
#  {'code': 'MX',
#   'count': 3284543,
#   'locations': 103,
#   'cities': 5,
#   'name': 'Mexico'},
#  {'code': 'NG', 'count': 2541, 'locations': 1, 'cities': 1, 'name': 'Nigeria'},
#  {'code': 'NL',
#   'count': 8952479,
#   'locations': 111,
#   'cities': 67,
#   'name': 'Netherlands'},
#  {'code': 'NO',
#   'count': 3606703,
#   'locations': 88,
#   'cities': 37,
#   'name': 'Norway'},
#  {'code': 'NP', 'count': 98891, 'locations': 6, 'cities': 2, 'name': 'Nepal'},
#  {'code': 'PE', 'count': 729283, 'locations': 22, 'cities': 2, 'name': 'Peru'},
#  {'code': 'PH',
#   'count': 958,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Philippines'},
#  {'code': 'PK',
#   'count': 43157,
#   'locations': 8,
#   'cities': 5,
#   'name': 'Pakistan'},
#  {'code': 'PL',
#   'count': 8313426,
#   'locations': 233,
#   'cities': 172,
#   'name': 'Poland'},
#  {'code': 'PT',
#   'count': 3685995,
#   'locations': 67,
#   'cities': 16,
#   'name': 'Portugal'},
#  {'code': 'RS',
#   'count': 249906,
#   'locations': 6,
#   'cities': 4,
#   'name': 'Serbia'},
#  {'code': 'RU',
#   'count': 186861,
#   'locations': 48,
#   'cities': 1,
#   'name': 'Russian Federation'},
#  {'code': 'SA',
#   'count': 7018,
#   'locations': 2,
#   'cities': 2,
#   'name': 'Saudi Arabia'},
#  {'code': 'SE',
#   'count': 293247,
#   'locations': 11,
#   'cities': 3,
#   'name': 'Sweden'},
#  {'code': 'SG',
#   'count': 1275,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Singapore'},
#  {'code': 'SI',
#   'count': 149190,
#   'locations': 9,
#   'cities': 9,
#   'name': 'Slovenia'},
#  {'code': 'SK',
#   'count': 2476492,
#   'locations': 38,
#   'cities': 8,
#   'name': 'Slovakia'},
#  {'code': 'TH',
#   'count': 5316130,
#   'locations': 64,
#   'cities': 29,
#   'name': 'Thailand'},
#  {'code': 'TI', 'count': 3636, 'locations': 1, 'cities': 1},
#  {'code': 'TJ',
#   'count': 3856,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Tajikistan'},
#  {'code': 'TM',
#   'count': 3854,
#   'locations': 1,
#   'cities': 1,
#   'name': 'Turkmenistan'},
#  {'code': 'TR',
#   'count': 5640285,
#   'locations': 159,
#   'cities': 43,
#   'name': 'Turkey'},
#  {'code': 'TW',
#   'count': 7542202,
#   'locations': 144,
#   'cities': 30,
#   'name': 'Taiwan'},
#  {'code': 'TX', 'count': 3492, 'locations': 1, 'cities': 1},
#  {'code': 'UC', 'count': 1, 'locations': 1, 'cities': 1},
#  {'code': 'UG', 'count': 27831, 'locations': 2, 'cities': 2, 'name': 'Uganda'},
#  {'code': 'US',
#   'count': 67482887,
#   'locations': 2264,
#   'cities': 790,
#   'name': 'United States'},
#  {'code': 'UZ',
#   'count': 30302,
#   'locations': 2,
#   'cities': 2,
#   'name': 'Uzbekistan'},
#  {'code': 'VM', 'count': 2202, 'locations': 2, 'cities': 1},
#  {'code': 'VN',
#   'count': 73189,
#   'locations': 5,
#   'cities': 3,
#   'name': 'Viet Nam'},
#  {'code': 'XK',
#   'count': 413119,
#   'locations': 9,
#   'cities': 8,
#   'name': 'Kosovo'},
#  {'code': 'ZA',
#   'count': 239159,
#   'locations': 3,
#   'cities': 1,
#   'name': 'South Africa'}]

# %%
# Convert to DF
data = pd.DataFrame(response.json()['results'])
data['name'].unique()
data.head()
# data.columns
# Out:
#    cities code   count  locations                  name
# 0       2   AD  117134          3               Andorra
# 1       3   AE   75685          4  United Arab Emirates
# 2       2   AF    6989          2           Afghanistan
# 3       1   AG       1          1   Antigua and Barbuda
# 4       1   AR   14976          4             Argentina

# %%
# Countries with the highest number of observations
data = pd.DataFrame(json_normalize(response.json()['results']))
data.sort_values(by='count', ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-2f17ad3e26fa> in <module>
#       1 # Countries with the highest number of observations
#       2 data = pd.DataFrame(json_normalize(response.json()['results']))
# ----> 3 data.sort_values(by='count', ascending=False).head(10)
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 'count'

# %% [markdown]
# ## Listing cities

# %%
# Cities
url = "https://api.openaq.org/v1/countries"

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': 'CC BY 4.0',
#   'website': 'https://docs.openaq.org/',
#   'page': 1,
#   'limit': 100,
#   'found': 98},
#  'results': [{'code': 'AD',
#    'count': 117134,
#    'locations': 3,
#    'cities': 2,
#    'name': 'Andorra'},
#   {'code': 'AE',
#    'count': 75685,
#    'locations': 4,
#    'cities': 3,
#    'name': 'United Arab Emirates'},
#   {'code': 'AF',
#    'count': 6989,
#    'locations': 2,
#    'cities': 2,
#    'name': 'Afghanistan'},
#   {'code': 'AG',
#    'count': 1,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Antigua and Barbuda'},
#   {'code': 'AR',
#    'count': 14976,
#    'locations': 4,
#    'cities': 1,
#    'name': 'Argentina'},
#   {'code': 'AT',
#    'count': 1659404,
#    'locations': 541,
#    'cities': 25,
#    'name': 'Austria'},
#   {'code': 'AU',
#    'count': 6820975,
#    'locations': 168,
#    'cities': 53,
#    'name': 'Australia'},
#   {'code': 'BA',
#    'count': 1084500,
#    'locations': 22,
#    'cities': 10,
#    'name': 'Bosnia and Herzegovina'},
#   {'code': 'BD',
#    'count': 33651,
#    'locations': 2,
#    'cities': 1,
#    'name': 'Bangladesh'},
#   {'code': 'BE',
#    'count': 1803288,
#    'locations': 198,
#    'cities': 14,
#    'name': 'Belgium'},
#   {'code': 'BG',
#    'count': 3622,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Bulgaria'},
#   {'code': 'BH',
#    'count': 47289,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Bahrain'},
#   {'code': 'BK', 'count': 3621, 'locations': 1, 'cities': 1},
#   {'code': 'BM',
#    'count': 4611,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Bermuda'},
#   {'code': 'BR',
#    'count': 304267,
#    'locations': 61,
#    'cities': 31,
#    'name': 'Brazil'},
#   {'code': 'CA',
#    'count': 6294986,
#    'locations': 213,
#    'cities': 12,
#    'name': 'Canada'},
#   {'code': 'CE', 'count': 6272, 'locations': 1, 'cities': 1},
#   {'code': 'CH',
#    'count': 1549794,
#    'locations': 30,
#    'cities': 15,
#    'name': 'Switzerland'},
#   {'code': 'CI',
#    'count': 352,
#    'locations': 1,
#    'cities': 1,
#    'name': "Côte d'Ivoire"},
#   {'code': 'CL',
#    'count': 8095648,
#    'locations': 238,
#    'cities': 163,
#    'name': 'Chile'},
#   {'code': 'CN',
#    'count': 100974638,
#    'locations': 1724,
#    'cities': 387,
#    'name': 'China'},
#   {'code': 'CO',
#    'count': 657339,
#    'locations': 34,
#    'cities': 12,
#    'name': 'Colombia'},
#   {'code': 'CR',
#    'count': 2831,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Costa Rica'},
#   {'code': 'CS', 'count': 3353, 'locations': 2, 'cities': 1},
#   {'code': 'CW',
#    'count': 22613,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Curaçao'},
#   {'code': 'CZ',
#    'count': 6126320,
#    'locations': 200,
#    'cities': 15,
#    'name': 'Czech Republic'},
#   {'code': 'DE',
#    'count': 12118284,
#    'locations': 1086,
#    'cities': 36,
#    'name': 'Germany'},
#   {'code': 'DK',
#    'count': 585902,
#    'locations': 25,
#    'cities': 7,
#    'name': 'Denmark'},
#   {'code': 'DZ',
#    'count': 6858,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Algeria'},
#   {'code': 'ES',
#    'count': 23825133,
#    'locations': 1235,
#    'cities': 115,
#    'name': 'Spain'},
#   {'code': 'ET',
#    'count': 58932,
#    'locations': 3,
#    'cities': 2,
#    'name': 'Ethiopia'},
#   {'code': 'FI',
#    'count': 2026764,
#    'locations': 119,
#    'cities': 35,
#    'name': 'Finland'},
#   {'code': 'FR',
#    'count': 25335783,
#    'locations': 1504,
#    'cities': 135,
#    'name': 'France'},
#   {'code': 'GB',
#    'count': 11129792,
#    'locations': 162,
#    'cities': 112,
#    'name': 'United Kingdom'},
#   {'code': 'GH', 'count': 1595, 'locations': 11, 'cities': 1, 'name': 'Ghana'},
#   {'code': 'GI',
#    'count': 40842,
#    'locations': 6,
#    'cities': 2,
#    'name': 'Gibraltar'},
#   {'code': 'GT',
#    'count': 7234,
#    'locations': 2,
#    'cities': 2,
#    'name': 'Guatemala'},
#   {'code': 'HK',
#    'count': 1556168,
#    'locations': 16,
#    'cities': 9,
#    'name': 'Hong Kong'},
#   {'code': 'HR',
#    'count': 910283,
#    'locations': 50,
#    'cities': 17,
#    'name': 'Croatia'},
#   {'code': 'HU',
#    'count': 2168929,
#    'locations': 50,
#    'cities': 14,
#    'name': 'Hungary'},
#   {'code': 'ID',
#    'count': 79171,
#    'locations': 5,
#    'cities': 3,
#    'name': 'Indonesia'},
#   {'code': 'IE',
#    'count': 500621,
#    'locations': 38,
#    'cities': 16,
#    'name': 'Ireland'},
#   {'code': 'IL',
#    'count': 173130367,
#    'locations': 2041,
#    'cities': 14,
#    'name': 'Israel'},
#   {'code': 'IN',
#    'count': 29344532,
#    'locations': 454,
#    'cities': 234,
#    'name': 'India'},
#   {'code': 'IQ', 'count': 9140, 'locations': 1, 'cities': 1, 'name': 'Iraq'},
#   {'code': 'IS',
#    'count': 24847,
#    'locations': 15,
#    'cities': 8,
#    'name': 'Iceland'},
#   {'code': 'IT',
#    'count': 3877434,
#    'locations': 104,
#    'cities': 45,
#    'name': 'Italy'},
#   {'code': 'IZ', 'count': 2475, 'locations': 1, 'cities': 1},
#   {'code': 'JO', 'count': 7061, 'locations': 2, 'cities': 2, 'name': 'Jordan'},
#   {'code': 'KE', 'count': 2842, 'locations': 2, 'cities': 1, 'name': 'Kenya'},
#   {'code': 'KG',
#    'count': 12771,
#    'locations': 2,
#    'cities': 2,
#    'name': 'Kyrgyzstan'},
#   {'code': 'KU', 'count': 3471, 'locations': 1, 'cities': 1},
#   {'code': 'KV', 'count': 3625, 'locations': 1, 'cities': 1},
#   {'code': 'KW',
#    'count': 24402,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Kuwait'},
#   {'code': 'KZ',
#    'count': 12141,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Kazakhstan'},
#   {'code': 'LA',
#    'count': 10110,
#    'locations': 2,
#    'cities': 2,
#    'name': "Lao People's Democratic Republic"},
#   {'code': 'LK',
#    'count': 19064,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Sri Lanka'},
#   {'code': 'LT',
#    'count': 443075,
#    'locations': 17,
#    'cities': 8,
#    'name': 'Lithuania'},
#   {'code': 'LU',
#    'count': 459415,
#    'locations': 7,
#    'cities': 3,
#    'name': 'Luxembourg'},
#   {'code': 'LV',
#    'count': 195674,
#    'locations': 4,
#    'cities': 4,
#    'name': 'Latvia'},
#   {'code': 'MG',
#    'count': 3273,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Madagascar'},
#   {'code': 'MK',
#    'count': 1265788,
#    'locations': 45,
#    'cities': 16,
#    'name': 'Macedonia, the Former Yugoslav Republic of'},
#   {'code': 'ML', 'count': 309, 'locations': 1, 'cities': 1, 'name': 'Mali'},
#   {'code': 'MM',
#    'count': 10070,
#    'locations': 2,
#    'cities': 2,
#    'name': 'Myanmar'},
#   {'code': 'MN',
#    'count': 2825857,
#    'locations': 44,
#    'cities': 25,
#    'name': 'Mongolia'},
#   {'code': 'MT',
#    'count': 264796,
#    'locations': 4,
#    'cities': 4,
#    'name': 'Malta'},
#   {'code': 'MX',
#    'count': 3284543,
#    'locations': 103,
#    'cities': 5,
#    'name': 'Mexico'},
#   {'code': 'NG',
#    'count': 2541,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Nigeria'},
#   {'code': 'NL',
#    'count': 8952479,
#    'locations': 111,
#    'cities': 67,
#    'name': 'Netherlands'},
#   {'code': 'NO',
#    'count': 3606703,
#    'locations': 88,
#    'cities': 37,
#    'name': 'Norway'},
#   {'code': 'NP', 'count': 98891, 'locations': 6, 'cities': 2, 'name': 'Nepal'},
#   {'code': 'PE',
#    'count': 729283,
#    'locations': 22,
#    'cities': 2,
#    'name': 'Peru'},
#   {'code': 'PH',
#    'count': 958,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Philippines'},
#   {'code': 'PK',
#    'count': 43157,
#    'locations': 8,
#    'cities': 5,
#    'name': 'Pakistan'},
#   {'code': 'PL',
#    'count': 8313426,
#    'locations': 233,
#    'cities': 172,
#    'name': 'Poland'},
#   {'code': 'PT',
#    'count': 3685995,
#    'locations': 67,
#    'cities': 16,
#    'name': 'Portugal'},
#   {'code': 'RS',
#    'count': 249906,
#    'locations': 6,
#    'cities': 4,
#    'name': 'Serbia'},
#   {'code': 'RU',
#    'count': 186861,
#    'locations': 48,
#    'cities': 1,
#    'name': 'Russian Federation'},
#   {'code': 'SA',
#    'count': 7018,
#    'locations': 2,
#    'cities': 2,
#    'name': 'Saudi Arabia'},
#   {'code': 'SE',
#    'count': 293247,
#    'locations': 11,
#    'cities': 3,
#    'name': 'Sweden'},
#   {'code': 'SG',
#    'count': 1275,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Singapore'},
#   {'code': 'SI',
#    'count': 149190,
#    'locations': 9,
#    'cities': 9,
#    'name': 'Slovenia'},
#   {'code': 'SK',
#    'count': 2476492,
#    'locations': 38,
#    'cities': 8,
#    'name': 'Slovakia'},
#   {'code': 'TH',
#    'count': 5316130,
#    'locations': 64,
#    'cities': 29,
#    'name': 'Thailand'},
#   {'code': 'TI', 'count': 3636, 'locations': 1, 'cities': 1},
#   {'code': 'TJ',
#    'count': 3856,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Tajikistan'},
#   {'code': 'TM',
#    'count': 3854,
#    'locations': 1,
#    'cities': 1,
#    'name': 'Turkmenistan'},
#   {'code': 'TR',
#    'count': 5640285,
#    'locations': 159,
#    'cities': 43,
#    'name': 'Turkey'},
#   {'code': 'TW',
#    'count': 7542202,
#    'locations': 144,
#    'cities': 30,
#    'name': 'Taiwan'},
#   {'code': 'TX', 'count': 3492, 'locations': 1, 'cities': 1},
#   {'code': 'UC', 'count': 1, 'locations': 1, 'cities': 1},
#   {'code': 'UG',
#    'count': 27831,
#    'locations': 2,
#    'cities': 2,
#    'name': 'Uganda'},
#   {'code': 'US',
#    'count': 67482887,
#    'locations': 2264,
#    'cities': 790,
#    'name': 'United States'},
#   {'code': 'UZ',
#    'count': 30302,
#    'locations': 2,
#    'cities': 2,
#    'name': 'Uzbekistan'},
#   {'code': 'VM', 'count': 2202, 'locations': 2, 'cities': 1},
#   {'code': 'VN',
#    'count': 73189,
#    'locations': 5,
#    'cities': 3,
#    'name': 'Viet Nam'},
#   {'code': 'XK',
#    'count': 413119,
#    'locations': 9,
#    'cities': 8,
#    'name': 'Kosovo'},
#   {'code': 'ZA',
#    'count': 239159,
#    'locations': 3,
#    'cities': 1,
#    'name': 'South Africa'}]}

# %% [markdown]
# ## Requesting the latest data.

# %%
# criar outro df pra measurements
url = "https://api.openaq.org/v1/latest?country=US"

response = requests.get(url)
response
response.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': 'CC BY 4.0',
#   'website': 'https://docs.openaq.org/',
#   'page': 1,
#   'limit': 100,
#   'found': 2179},
#  'results': [{'location': '1001',
#    'city': 'CA8 - ARB',
#    'country': 'US',
#    'distance': 8648898.161045589,
#    'measurements': [{'parameter': 'pm25',
#      'value': 13.9,
#      'lastUpdated': '2020-03-09T15:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.684364, 'longitude': -120.98818}},
#   {'location': '1008',
#    'city': 'CA8 - ARB',
#    'country': 'US',
#    'distance': 8648331.782792693,
#    'measurements': [{'parameter': 'pm25',
#      'value': -4.2,
#      'lastUpdated': '2020-03-09T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.67386, 'longitude': -120.94338}},
#   {'location': '16th and Whitmore',
#    'city': 'Omaha-Council Bluffs',
#    'country': 'US',
#    'distance': 7317289.4981282065,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.016,
#      'lastUpdated': '2017-11-01T11:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.32247, 'longitude': -95.93799}},
#   {'location': '1NL Navajo Lake',
#    'city': 'Farmington',
#    'country': 'US',
#    'distance': 8289568.688757036,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.024,
#      'lastUpdated': '2017-01-13T15:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 36.8097, 'longitude': -107.6517}},
#   {'location': '22nd Street & Craycr',
#    'city': 'Tucson',
#    'country': 'US',
#    'distance': 8880825.353075182,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.054,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 32.205, 'longitude': -110.8772}},
#   {'location': '24th & O',
#    'city': 'Omaha-Council Bluffs',
#    'country': 'US',
#    'distance': 7328058.090918123,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.012,
#      'lastUpdated': '2017-11-01T11:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.208084, 'longitude': -95.94744}},
#   {'location': '2912 Coffey',
#    'city': 'Omaha-Council Bluffs',
#    'country': 'US',
#    'distance': 7335220.451681372,
#    'measurements': [{'parameter': 'pm25',
#      'value': 2,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.133316, 'longitude': -95.95608}},
#   {'location': '2LL Los Lunas',
#    'city': 'Albuquerque',
#    'country': 'US',
#    'distance': 8439227.634263288,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.055,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 34.8147, 'longitude': -106.7397}},
#   {'location': '46th and Farnam',
#    'city': 'Omaha-Council Bluffs',
#    'country': 'US',
#    'distance': 7325406.147325607,
#    'measurements': [{'parameter': 'pm10',
#      'value': 0,
#      'lastUpdated': '2018-04-25T04:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.257317, 'longitude': -95.98383}},
#   {'location': '5511 39TH STREET EAS',
#    'city': 'Sarasota-Bradenton-Venice',
#    'country': 'US',
#    'distance': 7829309.7824333655,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.013,
#      'lastUpdated': '2017-11-07T02:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 27.4494, 'longitude': -82.5219}},
#   {'location': '60 Near Road',
#    'city': 'SAN BERNARDINO',
#    'country': 'US',
#    'distance': 8987790.972990196,
#    'measurements': [{'parameter': 'pm25',
#      'value': 51,
#      'lastUpdated': '2018-06-08T16:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.03,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 34.0309, 'longitude': -117.6174}},
#   {'location': '6th District',
#    'city': 'Cleveland-Elyria-Mentor',
#    'country': 'US',
#    'distance': 6550312.190019143,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.032,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.55523, 'longitude': -81.57526}},
#   {'location': '7004',
#    'city': 'ARCHULETA',
#    'country': 'US',
#    'distance': 8233678.593376018,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.042,
#      'lastUpdated': '2020-02-10T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0.002,
#      'lastUpdated': '2020-02-10T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.003,
#      'lastUpdated': '2020-02-10T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 37.20586, 'longitude': -107.25412}},
#   {'location': '710 Near Road',
#    'city': 'LOS ANGELES',
#    'country': 'US',
#    'distance': 9028327.960355323,
#    'measurements': [{'parameter': 'no2',
#      'value': 0.03,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 16.5,
#      'lastUpdated': '2018-06-08T12:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.85966, 'longitude': -118.20071}},
#   {'location': '77th and Dodge',
#    'city': 'Omaha-Council Bluffs',
#    'country': 'US',
#    'distance': 7327704.701870088,
#    'measurements': [{'parameter': 'co',
#      'value': 0.29,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.25948, 'longitude': -96.03471}},
#   {'location': '7E Deming Airport',
#    'city': 'Deming',
#    'country': 'US',
#    'distance': 8731130.783172999,
#    'measurements': [{'parameter': 'pm10',
#      'value': 12,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 32.2558, 'longitude': -107.7228}},
#   {'location': 'A Street',
#    'city': 'FAIRBANKS NORTH STAR',
#    'country': 'US',
#    'distance': 6515930.781871644,
#    'measurements': [{'parameter': 'pm25',
#      'value': 10,
#      'lastUpdated': '2019-11-09T14:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 2,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 64.84593, 'longitude': -147.69328}},
#   {'location': 'ADEQ-DSR',
#    'city': 'Little Rock-North Little Rock',
#    'country': 'US',
#    'distance': 7731975.612364057,
#    'measurements': [{'parameter': 'pm25',
#      'value': 3.8,
#      'lastUpdated': '2020-03-30T18:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 34.6811, 'longitude': -92.3283}},
#   {'location': 'AIR LAB',
#    'city': 'Knoxville',
#    'country': 'US',
#    'distance': 7157596.134833732,
#    'measurements': [{'parameter': 'pm25',
#      'value': 5.3,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 35.9803, 'longitude': -83.9306}},
#   {'location': 'AJ Maintenance Yard',
#    'city': 'Phoenix-Mesa-Scottsdale',
#    'country': 'US',
#    'distance': 8789918.309850113,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.059,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.4206, 'longitude': -111.5033}},
#   {'location': 'ALBA',
#    'city': 'Joplin',
#    'country': 'US',
#    'distance': 7610219.540200055,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.042,
#      'lastUpdated': '2020-03-30T21:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 37.2385, 'longitude': -94.42468}},
#   {'location': 'ALBNY',
#    'city': 'Albany-Schenectady-Troy',
#    'country': 'US',
#    'distance': 6024704.674799274,
#    'measurements': [{'parameter': 'pm25',
#      'value': 9.5,
#      'lastUpdated': '2018-02-27T11:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 42.6425, 'longitude': -73.7547}},
#   {'location': 'ALLE',
#    'city': 'Allentown-Bethlehem-Easton',
#    'country': 'US',
#    'distance': 6284750.124186543,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.033,
#      'lastUpdated': '2018-10-13T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 0.9,
#      'lastUpdated': '2018-10-05T15:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.6119, 'longitude': -75.4325}},
#   {'location': 'ALLEN PARK',
#    'city': 'Detroit-Warren-Livonia',
#    'country': 'US',
#    'distance': 6582501.065232539,
#    'measurements': [{'parameter': 'co',
#      'value': 0,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 4.2,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0.001,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.033,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 42.2283, 'longitude': -83.2092}},
#   {'location': 'ALSIP',
#    'city': 'Chicago-Naperville-Joliet',
#    'country': 'US',
#    'distance': 6870315.081425183,
#    'measurements': [{'parameter': 'pm25',
#      'value': 0.2,
#      'lastUpdated': '2020-03-29T11:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.041,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.6708, 'longitude': -87.7325}},
#   {'location': 'ALTO',
#    'city': 'Altoona',
#    'country': 'US',
#    'distance': 6460305.562409385,
#    'measurements': [{'parameter': 'pm25',
#      'value': 8.1,
#      'lastUpdated': '2018-04-18T18:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.037,
#      'lastUpdated': '2018-04-18T18:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.515, 'longitude': -78.3889}},
#   {'location': 'ALTON',
#    'city': 'St. Louis',
#    'country': 'US',
#    'distance': 7240076.751157881,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.02,
#      'lastUpdated': '2019-11-06T15:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.8903, 'longitude': -90.1481}},
#   {'location': 'APOLLO BEACH',
#    'city': 'HILLSBOROUGH',
#    'country': 'US',
#    'distance': 7793837.33566706,
#    'measurements': [{'parameter': 'pm25',
#      'value': 12.4,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0.001,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 27.779713, 'longitude': -82.41984}},
#   {'location': 'APPLETON AAL',
#    'city': 'Appleton',
#    'country': 'US',
#    'distance': 6678007.769781301,
#    'measurements': [{'parameter': 'pm25',
#      'value': 2.5,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.045,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 44.3069, 'longitude': -88.3956}},
#   {'location': 'ARB OER',
#    'city': 'CA8 - ARB',
#    'country': 'US',
#    'distance': 8678884.787514225,
#    'measurements': [{'parameter': 'pm25',
#      'value': -4,
#      'lastUpdated': '2016-08-08T16:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.568504, 'longitude': -121.493256}},
#   {'location': 'AREN',
#    'city': 'Gettysburg',
#    'country': 'US',
#    'distance': 6448362.207000937,
#    'measurements': [{'parameter': 'pm25',
#      'value': 7.4,
#      'lastUpdated': '2018-04-18T18:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.046,
#      'lastUpdated': '2018-04-18T18:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.9233, 'longitude': -77.3081}},
#   {'location': 'ARNOLD',
#    'city': 'St. Louis',
#    'country': 'US',
#    'distance': 7292342.313764914,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.003,
#      'lastUpdated': '2019-11-06T12:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm10',
#      'value': 19,
#      'lastUpdated': '2019-11-15T13:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 13,
#      'lastUpdated': '2019-11-15T13:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.44858, 'longitude': -90.39844}},
#   {'location': 'ARNOLD WEST',
#    'city': 'St. Louis',
#    'country': 'US',
#    'distance': 7292342.313764914,
#    'measurements': [{'parameter': 'pm10',
#      'value': 6,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 6.6,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.048,
#      'lastUpdated': '2020-03-30T21:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.44858, 'longitude': -90.39844}},
#   {'location': 'ASHBURN',
#    'city': 'Washington-Arlington-Alexandria',
#    'country': 'US',
#    'distance': 6533564.542167597,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.05,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.002,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.0244, 'longitude': -77.49}},
#   {'location': 'ATHENS',
#    'city': 'Athens',
#    'country': 'US',
#    'distance': 7241211.949024892,
#    'measurements': [{'parameter': 'pm25',
#      'value': 4,
#      'lastUpdated': '2020-03-26T15:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 35.4511, 'longitude': -84.5992}},
#   {'location': 'AURORA HILLS',
#    'city': 'Washington-Arlington-Alexandria',
#    'country': 'US',
#    'distance': 6522702.4777639955,
#    'measurements': [{'parameter': 'no2',
#      'value': 0.002,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.05,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'co',
#      'value': 0.2,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.8594, 'longitude': -77.0589}},
#   {'location': 'Aberdeen',
#    'city': 'BROWN',
#    'country': 'US',
#    'distance': 7065432.790527657,
#    'measurements': [{'parameter': 'pm10',
#      'value': 20,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 1.8,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 45.468597, 'longitude': -98.494064}},
#   {'location': 'Aberdeen Bus Stop',
#    'city': 'BROWN',
#    'country': 'US',
#    'distance': 7065432.790527657,
#    'measurements': [{'parameter': 'pm10',
#      'value': 3,
#      'lastUpdated': '2020-01-03T12:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 2.3,
#      'lastUpdated': '2020-01-03T12:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 45.468597, 'longitude': -98.494064}},
#   {'location': 'Aberdeen-Division St',
#    'city': 'Aberdeen',
#    'country': 'US',
#    'distance': 7905412.244457996,
#    'measurements': [{'parameter': 'pm25',
#      'value': 3.1,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 46.9772, 'longitude': -123.8317}},
#   {'location': 'Abington',
#    'city': 'Willimantic',
#    'country': 'US',
#    'distance': 5988910.52735185,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.042,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.8402, 'longitude': -72.01}},
#   {'location': 'Acadia NP - McFarlan',
#    'city': 'HANCOCK',
#    'country': 'US',
#    'distance': 5574110.321174569,
#    'measurements': [{'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.046,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 1.4,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 44.37705, 'longitude': -68.2609}},
#   {'location': 'Adams',
#    'city': 'Denver-Aurora',
#    'country': 'US',
#    'distance': 7879766.736190029,
#    'measurements': [{'parameter': 'pm25',
#      'value': 6.8,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.82839, 'longitude': -104.93846}},
#   {'location': 'Airway Heights-West',
#    'city': 'SPOKANE',
#    'country': 'US',
#    'distance': 7632772.461021186,
#    'measurements': [{'parameter': 'pm25',
#      'value': 2.9,
#      'lastUpdated': '2018-06-14T19:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 47.64535, 'longitude': -117.58903}},
#   {'location': 'Ajo',
#    'city': 'PIMA',
#    'country': 'US',
#    'distance': 8951385.051154805,
#    'measurements': [{'parameter': 'pm10',
#      'value': 6,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 32.382034, 'longitude': -112.85745}},
#   {'location': 'Akron - NIHF_STEM',
#    'city': 'Akron',
#    'country': 'US',
#    'distance': 6587028.270146287,
#    'measurements': [{'parameter': 'co',
#      'value': 0,
#      'lastUpdated': '2017-04-25T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2017-04-25T17:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.07914, 'longitude': -81.51627}},
#   {'location': 'Akron NIFH/STEM',
#    'city': 'Akron',
#    'country': 'US',
#    'distance': 6587028.270146287,
#    'measurements': [{'parameter': 'co',
#      'value': 0.1,
#      'lastUpdated': '2018-11-14T13:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0.001,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 41.07914, 'longitude': -81.51627}},
#   {'location': 'Alabama-Coushatta',
#    'city': 'POLK',
#    'country': 'US',
#    'distance': 8223739.197218029,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.038,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 30.6681, 'longitude': -94.6739}},
#   {'location': 'Alamo Lake',
#    'city': 'LA PAZ',
#    'country': 'US',
#    'distance': 8798352.111687617,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.05,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm10',
#      'value': 3,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 3,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0.001,
#      'lastUpdated': '2016-03-23T04:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 34.24389, 'longitude': -113.55861}},
#   {'location': 'Albany',
#    'city': 'Albany',
#    'country': 'US',
#    'distance': 7554088.805036022,
#    'measurements': [{'parameter': 'pm25',
#      'value': 10.8,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 3.1,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.04,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 31.5767, 'longitude': -84.1002}},
#   {'location': 'Albany - Calapooia S',
#    'city': 'Albany-Lebanon',
#    'country': 'US',
#    'distance': 8121174.039473314,
#    'measurements': [{'parameter': 'pm25',
#      'value': 2.1,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 44.61569, 'longitude': -123.09145}},
#   {'location': 'Albemarle HS',
#    'city': 'Charlottesville',
#    'country': 'US',
#    'distance': 6670995.062839826,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.055,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 3.1,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.0766, 'longitude': -78.504}},
#   {'location': 'Aldino',
#    'city': 'Baltimore-Towson',
#    'country': 'US',
#    'distance': 6415230.660420659,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.04,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.5633, 'longitude': -76.2039}},
#   {'location': 'Alhambra',
#    'city': 'St. Louis',
#    'country': 'US',
#    'distance': 7214295.877968675,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.047,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.869, 'longitude': -89.6228}},
#   {'location': 'Allentown',
#    'city': 'Allentown-Bethlehem-Easton',
#    'country': 'US',
#    'distance': 6284750.124186543,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.03,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 9.2,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.6119, 'longitude': -75.4325}},
#   {'location': 'Alliance',
#    'city': 'Canton-Massillon',
#    'country': 'US',
#    'distance': 6577818.35909508,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.034,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.931396, 'longitude': -81.12352}},
#   {'location': 'Alpine',
#    'city': 'San Diego-Carlsbad-San Marcos',
#    'country': 'US',
#    'distance': 9072012.935491908,
#    'measurements': [{'parameter': 'pm25',
#      'value': 4.8,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.047,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 32.842297, 'longitude': -116.768326}},
#   {'location': 'Alton',
#    'city': 'MADISON',
#    'country': 'US',
#    'distance': 7239003.488967499,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.048,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.901318, 'longitude': -90.14621}},
#   {'location': 'Altoona',
#    'city': 'Altoona',
#    'country': 'US',
#    'distance': 6460305.562409385,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.037,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 3,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.515, 'longitude': -78.3889}},
#   {'location': 'Amanda  Elementary',
#    'city': 'BUTLER',
#    'country': 'US',
#    'distance': 6881308.676335157,
#    'measurements': [{'parameter': 'pm25',
#      'value': 8.3,
#      'lastUpdated': '2018-05-18T18:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.478848, 'longitude': -84.40768}},
#   {'location': 'Amarillo Texas A&M C',
#    'city': 'Amarillo',
#    'country': 'US',
#    'distance': 8173010.936087946,
#    'measurements': [{'parameter': 'pm25',
#      'value': 2,
#      'lastUpdated': '2018-07-12T15:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 35.2006, 'longitude': -101.9083}},
#   {'location': 'Amherst',
#    'city': 'Buffalo-Niagara Falls',
#    'country': 'US',
#    'distance': 6277548.706545618,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.034,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 42.9925, 'longitude': -78.7764}},
#   {'location': 'Anacortes-202 Ave',
#    'city': 'SKAGIT',
#    'country': 'US',
#    'distance': 7711406.180621735,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.031,
#      'lastUpdated': '2017-01-04T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 4,
#      'lastUpdated': '2017-01-11T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 48.52059, 'longitude': -122.61428}},
#   {'location': 'Anacortes-202 Ave (S',
#    'city': 'SKAGIT',
#    'country': 'US',
#    'distance': 7711406.180621735,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.039,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': -1,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 48.52059, 'longitude': -122.61428}},
#   {'location': 'Anacortes-Bartholome',
#    'city': 'SKAGIT',
#    'country': 'US',
#    'distance': 7715262.401305174,
#    'measurements': [{'parameter': 'pm25',
#      'value': 1.2,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 48.4654, 'longitude': -122.56}},
#   {'location': 'Anaheim',
#    'city': 'Los Angeles-Long Beach-Santa Ana',
#    'country': 'US',
#    'distance': 9020750.082138224,
#    'measurements': [{'parameter': 'no2',
#      'value': 0.004,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'co',
#      'value': 0.21,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm10',
#      'value': 13,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 1.9,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.048,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.830585, 'longitude': -117.93851}},
#   {'location': 'Anaheim Near Road',
#    'city': 'ORANGE',
#    'country': 'US',
#    'distance': 9021088.068644237,
#    'measurements': [{'parameter': 'no2',
#      'value': 0.013,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'co',
#      'value': 0.41,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.819305, 'longitude': -117.91876}},
#   {'location': 'Ancora State Hosptia',
#    'city': 'Philadelphia-Camden-Wilmington',
#    'country': 'US',
#    'distance': 6328133.55154059,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.034,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.68425, 'longitude': -74.86149}},
#   {'location': 'Anderson',
#    'city': 'Redding',
#    'country': 'US',
#    'distance': 8516422.780370833,
#    'measurements': [{'parameter': 'pm25',
#      'value': 4.5,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.03,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.4531, 'longitude': -122.2978}},
#   {'location': 'Anderson-Eastside El',
#    'city': 'Anderson',
#    'country': 'US',
#    'distance': 6893114.354203739,
#    'measurements': [{'parameter': 'pm25',
#      'value': 3.4,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 40.125557, 'longitude': -85.65222}},
#   {'location': 'Andrew Johnson Elem.',
#    'city': 'Kingsport-Bristol-Bristol',
#    'country': 'US',
#    'distance': 7031517.081182913,
#    'measurements': [{'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 36.526417, 'longitude': -82.52868}},
#   {'location': 'Ann Arbor',
#    'city': 'Ann Arbor',
#    'country': 'US',
#    'distance': 6603840.31438034,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.035,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 42.4164, 'longitude': -83.9019}},
#   {'location': 'Antelope - North Hig',
#    'city': 'Sacramento--Arden-Arcade--Roseville',
#    'country': 'US',
#    'distance': 8660310.33135106,
#    'measurements': [{'parameter': 'co',
#      'value': 0.4,
#      'lastUpdated': '2019-11-01T21:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.007,
#      'lastUpdated': '2017-11-14T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.039,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.71209, 'longitude': -121.38109}},
#   {'location': 'Anthony',
#    'city': 'Las Cruces',
#    'country': 'US',
#    'distance': 8702484.638868349,
#    'measurements': [{'parameter': 'pm10',
#      'value': 24,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 6,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 32.0036, 'longitude': -106.5992}},
#   {'location': 'Apache Junction',
#    'city': 'Phoenix-Mesa-Scottsdale',
#    'country': 'US',
#    'distance': 8790016.773197263,
#    'measurements': [{'parameter': 'pm10',
#      'value': 11,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.42, 'longitude': -111.5042}},
#   {'location': 'Apex',
#    'city': 'Las Vegas-Paradise',
#    'country': 'US',
#    'distance': 8642870.615319094,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.024,
#      'lastUpdated': '2020-03-30T15:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 36.39103, 'longitude': -114.90743}},
#   {'location': 'Apple Valley',
#    'city': 'Minneapolis-St. Paul-Bloomington',
#    'country': 'US',
#    'distance': 6881716.543046194,
#    'measurements': [{'parameter': 'pm25',
#      'value': 5,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 44.7383, 'longitude': -93.2372}},
#   {'location': 'Archbold Biomedical',
#    'city': 'Sebring',
#    'country': 'US',
#    'distance': 7782692.291380871,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.038,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 27.1889, 'longitude': -81.3403}},
#   {'location': 'Arden Arcade - Del P',
#    'city': 'Sacramento--Arden-Arcade--Roseville',
#    'country': 'US',
#    'distance': 8669783.277347706,
#    'measurements': [{'parameter': 'bc',
#      'value': 0,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.002,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.039,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'co',
#      'value': 0.12,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 2,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.613804, 'longitude': -121.368004}},
#   {'location': 'Arendtsville',
#    'city': 'Gettysburg',
#    'country': 'US',
#    'distance': 6448362.207000937,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.044,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 3.2,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.9233, 'longitude': -77.3081}},
#   {'location': 'Arlington Municipal',
#    'city': 'Dallas-Fort Worth-Arlington',
#    'country': 'US',
#    'distance': 8167714.228040257,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.037,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 7.1,
#      'lastUpdated': '2018-12-04T15:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 32.6558, 'longitude': -97.0886}},
#   {'location': 'Arvin - Di Giorgio S',
#    'city': 'KERN',
#    'country': 'US',
#    'distance': 8913080.618044697,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.033,
#      'lastUpdated': '2019-12-01T19:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 35.23918, 'longitude': -118.78863}},
#   {'location': 'Ascarate Park Southe',
#    'city': 'El Paso',
#    'country': 'US',
#    'distance': 8717830.763376612,
#    'measurements': [{'parameter': 'pm25',
#      'value': 12.4,
#      'lastUpdated': '2020-03-25T12:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0,
#      'lastUpdated': '2020-03-25T12:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 31.7467, 'longitude': -106.4028}},
#   {'location': 'Ashland',
#    'city': 'AROOSTOOK',
#    'country': 'US',
#    'distance': 5414701.441371723,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.042,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 46.604, 'longitude': -68.4135}},
#   {'location': 'Ashland Fire Dept',
#    'city': 'JACKSON',
#    'country': 'US',
#    'distance': 8353959.4775850205,
#    'measurements': [{'parameter': 'pm25',
#      'value': 1.9,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 42.1941, 'longitude': -122.7086}},
#   {'location': 'Ashton',
#    'city': 'Walterboro',
#    'country': 'US',
#    'distance': 7247655.376122562,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.04,
#      'lastUpdated': '2019-03-06T15:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 5,
#      'lastUpdated': '2019-03-06T17:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.0078, 'longitude': -80.965}},
#   {'location': 'Aspen Park',
#    'city': 'Denver-Aurora',
#    'country': 'US',
#    'distance': 7923137.442877305,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.034,
#      'lastUpdated': '2019-09-16T15:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.5415, 'longitude': -105.2984}},
#   {'location': 'Atascadero2',
#    'city': 'San Luis Obispo-Paso Robles',
#    'country': 'US',
#    'distance': 8959410.584839927,
#    'measurements': [{'parameter': 'no2',
#      'value': 0,
#      'lastUpdated': '2020-03-30T21:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm10',
#      'value': 3,
#      'lastUpdated': '2020-03-30T21:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 2,
#      'lastUpdated': '2020-03-30T21:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.038,
#      'lastUpdated': '2020-03-30T21:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 35.494556, 'longitude': -120.66621}},
#   {'location': 'Atascocita C560',
#    'city': 'Houston',
#    'country': 'US',
#    'distance': 8318983.316680867,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.051,
#      'lastUpdated': '2016-03-06T19:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'Texas',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 29.961945, 'longitude': -95.235}},
#   {'location': 'Athens',
#    'city': 'Athens-Clarke County',
#    'country': 'US',
#    'distance': 7304795.210328097,
#    'measurements': [{'parameter': 'pm10',
#      'value': 29,
#      'lastUpdated': '2020-03-27T19:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 19.6,
#      'lastUpdated': '2020-03-27T19:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.054,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.925, 'longitude': -83.3575}},
#   {'location': 'Athens Supersite',
#    'city': 'Athens',
#    'country': 'US',
#    'distance': 6770030.649334451,
#    'measurements': [{'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2017-04-13T14:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.039,
#      'lastUpdated': '2016-07-01T12:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'co',
#      'value': 2.8,
#      'lastUpdated': '2016-08-11T14:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'no2',
#      'value': 0.001,
#      'lastUpdated': '2016-05-03T12:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.308, 'longitude': -82.1183}},
#   {'location': 'Auburn',
#    'city': 'Sacramento--Arden-Arcade--Roseville',
#    'country': 'US',
#    'distance': 8627481.246281315,
#    'measurements': [{'parameter': 'pm25',
#      'value': 15,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.041,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 38.9378, 'longitude': -121.1039}},
#   {'location': 'Auburn M St SE',
#    'city': 'KING',
#    'country': 'US',
#    'distance': 7822890.431865128,
#    'measurements': [{'parameter': 'pm25',
#      'value': 14.6,
#      'lastUpdated': '2018-07-25T13:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': -1,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 47.2875, 'longitude': -122.2144}},
#   {'location': 'Audubon C38',
#    'city': 'Austin-Round Rock',
#    'country': 'US',
#    'distance': 8410379.725039419,
#    'measurements': [{'parameter': 'pm25',
#      'value': 2.6,
#      'lastUpdated': '2017-11-14T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.009,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 30.483168, 'longitude': -97.8723}},
#   {'location': 'Augusta',
#    'city': 'Augusta-Richmond County',
#    'country': 'US',
#    'distance': 7271475.2034831885,
#    'measurements': [{'parameter': 'pm10',
#      'value': 8,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 11.1,
#      'lastUpdated': '2020-03-30T04:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'so2',
#      'value': 0,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.049,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 33.4333, 'longitude': -82.0219}},
#   {'location': 'Aurora East',
#    'city': 'ARAPAHOE',
#    'country': 'US',
#    'distance': 7880898.871247764,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.051,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.638542, 'longitude': -104.56906}},
#   {'location': 'Austin Northwest C3',
#    'city': 'Austin-Round Rock',
#    'country': 'US',
#    'distance': 8416516.768234277,
#    'measurements': [{'parameter': 'pm25',
#      'value': 14.6,
#      'lastUpdated': '2020-02-18T13:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.012,
#      'lastUpdated': '2020-02-18T13:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 30.3542, 'longitude': -97.76}},
#   {'location': 'Austin Webberville R',
#    'city': 'Austin-Round Rock',
#    'country': 'US',
#    'distance': 8422526.94503689,
#    'measurements': [{'parameter': 'pm25',
#      'value': 18.5,
#      'lastUpdated': '2016-09-20T13:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 30.2633, 'longitude': -97.7131}},
#   {'location': 'Avenida de la Indust',
#    'city': 'El Paso',
#    'country': 'US',
#    'distance': 8720787.837976858,
#    'measurements': [{'parameter': 'co',
#      'value': 0.7,
#      'lastUpdated': '2017-12-30T12:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.002,
#      'lastUpdated': '2017-11-23T03:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 31.7122, 'longitude': -106.3953}},
#   {'location': 'Avon',
#    'city': 'Indianapolis',
#    'country': 'US',
#    'distance': 6964820.012434115,
#    'measurements': [{'parameter': 'o3',
#      'value': 0.045,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 39.7589, 'longitude': -86.3972}},
#   {'location': 'Azalea',
#    'city': 'Tampa-St. Petersburg-Clearwater',
#    'country': 'US',
#    'distance': 7812123.35404671,
#    'measurements': [{'parameter': 'no2',
#      'value': 0.001,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'o3',
#      'value': 0.036,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'ppm',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}},
#     {'parameter': 'pm25',
#      'value': 7.1,
#      'lastUpdated': '2020-03-30T20:00:00.000Z',
#      'unit': 'µg/m³',
#      'sourceName': 'AirNow',
#      'averagingPeriod': {'value': 1, 'unit': 'hours'}}],
#    'coordinates': {'latitude': 27.7858, 'longitude': -82.74}}]}

# %%
# Extracting the data 'results'
data = pd.DataFrame(json_normalize(response.json()['results'])).reset_index()
data.shape
data.head()
# Out:
#    index                  city  coordinates.latitude  coordinates.longitude  \
# 0      0             CA8 - ARB             38.684364             -120.98818
# 1      1             CA8 - ARB             38.673860             -120.94338
# 2      2  Omaha-Council Bluffs             41.322470              -95.93799
# 3      3            Farmington             36.809700             -107.65170
# 4      4                Tucson             32.205000             -110.87720
#
#   country      distance              location  \
# 0      US  8.648898e+06                  1001
# 1      US  8.648332e+06                  1008
# 2      US  7.317289e+06     16th and Whitmore
# 3      US  8.289569e+06       1NL Navajo Lake
# 4      US  8.880825e+06  22nd Street & Craycr
#
#                                         measurements
# 0  [{'parameter': 'pm25', 'value': 13.9, 'lastUpd...
# 1  [{'parameter': 'pm25', 'value': -4.2, 'lastUpd...
# 2  [{'parameter': 'o3', 'value': 0.016, 'lastUpda...
# 3  [{'parameter': 'o3', 'value': 0.024, 'lastUpda...
# 4  [{'parameter': 'o3', 'value': 0.054, 'lastUpda...

# %% [markdown]
# ### Flattening the DataFrame

# %%
dic_flatten = [flatten(d) for d in response.json()['results']]
dic_flatten
data_flatten = pd.DataFrame(dic_flatten).reset_index()
data_flatten.head()
# # data.shape
# data.columns

# Create for loop to extract parameters individually?
# Out:
#    index                  city  coordinates_latitude  coordinates_longitude  \
# 0      0             CA8 - ARB             38.684364             -120.98818
# 1      1             CA8 - ARB             38.673860             -120.94338
# 2      2  Omaha-Council Bluffs             41.322470              -95.93799
# 3      3            Farmington             36.809700             -107.65170
# 4      4                Tucson             32.205000             -110.87720
#
#   country      distance              location  \
# 0      US  8.648898e+06                  1001
# 1      US  8.648332e+06                  1008
# 2      US  7.317289e+06     16th and Whitmore
# 3      US  8.289569e+06       1NL Navajo Lake
# 4      US  8.880825e+06  22nd Street & Craycr
#
#   measurements_0_averagingPeriod_unit  measurements_0_averagingPeriod_value  \
# 0                               hours                                     1
# 1                               hours                                     1
# 2                               hours                                     1
# 3                               hours                                     1
# 4                               hours                                     1
#
#   measurements_0_lastUpdated  ... measurements_4_sourceName  \
# 0   2020-03-09T15:00:00.000Z  ...                       NaN
# 1   2020-03-09T17:00:00.000Z  ...                       NaN
# 2   2017-11-01T11:00:00.000Z  ...                       NaN
# 3   2017-01-13T15:00:00.000Z  ...                       NaN
# 4   2020-03-30T20:00:00.000Z  ...                       NaN
#
#   measurements_4_unit measurements_4_value  \
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
#    measurements_5_averagingPeriod_unit measurements_5_averagingPeriod_value  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    measurements_5_lastUpdated measurements_5_parameter  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
#
#   measurements_5_sourceName measurements_5_unit measurements_5_value
# 0                       NaN                 NaN                  NaN
# 1                       NaN                 NaN                  NaN
# 2                       NaN                 NaN                  NaN
# 3                       NaN                 NaN                  NaN
# 4                       NaN                 NaN                  NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# #### Trying to extract the parameters(sub dicts):

# %%
# First Try:

# len(data['measurements'])
# data['measurements'].apply(lambda x: json_normalize(dict(x)))

# %%
# Second Try:
data['measurements'][2]

# transformar em pd series
measurements = data['measurements'].apply(lambda x: pd.Series(x[0]))
measurements.head()

# Extracted only the first dictionary (parameter)
# Out:
#   parameter   value               lastUpdated   unit sourceName  \
# 0      pm25  13.900  2020-03-09T15:00:00.000Z  µg/m³     AirNow
# 1      pm25  -4.200  2020-03-09T17:00:00.000Z  µg/m³     AirNow
# 2        o3   0.016  2017-11-01T11:00:00.000Z    ppm     AirNow
# 3        o3   0.024  2017-01-13T15:00:00.000Z    ppm     AirNow
# 4        o3   0.054  2020-03-30T20:00:00.000Z    ppm     AirNow
#
#                  averagingPeriod
# 0  {'value': 1, 'unit': 'hours'}
# 1  {'value': 1, 'unit': 'hours'}
# 2  {'value': 1, 'unit': 'hours'}
# 3  {'value': 1, 'unit': 'hours'}
# 4  {'value': 1, 'unit': 'hours'}

# %%
# Merge tbales
# data.merge(measurements,  left_index=True,  right_index=True)
# drop measurements

# %% [markdown]
# ## Requesting by  Measurements

# %% [markdown]
# ### PM25

# %%
url = "https://api.openaq.org/v1/measurements?parameter=pm25&limit=2000&city=US&date_from=2019-01-20"

response = requests.get(url)
response
response.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': 'CC BY 4.0',
#   'website': 'https://docs.openaq.org/',
#   'page': 1,
#   'limit': 2000,
#   'found': 1588159},
#  'results': [{'location': 'Healdton',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 4.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.256901, 'longitude': -97.474197},
#    'country': 'US',
#    'city': 'Ardmore'},
#   {'location': 'Moore',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 4.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 35.32, 'longitude': -97.4883},
#    'country': 'US',
#    'city': 'Oklahoma City'},
#   {'location': 'Lawton North',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 4.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.632999, 'longitude': -98.428802},
#    'country': 'US',
#    'city': 'Lawton'},
#   {'location': 'Seiling',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 3.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.1589, 'longitude': -98.9353},
#    'country': 'US',
#    'city': 'DEWEY'},
#   {'location': 'Mesa 2 /Nipomo',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 31,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 35.02079, 'longitude': -120.56389},
#    'country': 'US',
#    'city': 'San Luis Obispo-Paso Robles'},
#   {'location': 'Nipomo Mesa CDF',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 44,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 35.04676, 'longitude': -120.58777},
#    'country': 'US',
#    'city': 'SAN LUIS OBISPO'},
#   {'location': 'Atascadero2',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 35.494556, 'longitude': -120.666203},
#    'country': 'US',
#    'city': 'San Luis Obispo-Paso Robles'},
#   {'location': 'Zayante Fire Station',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.067003, 'longitude': -122.057206},
#    'country': 'US',
#    'city': 'Santa Cruz-Watsonville'},
#   {'location': 'Felton Cal-Fire',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.0481, 'longitude': -122.074603},
#    'country': 'US',
#    'city': 'Santa Cruz-Watsonville'},
#   {'location': 'Boulder Creek',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.125861, 'longitude': -122.122127},
#    'country': 'US',
#    'city': 'Santa Cruz-Watsonville'},
#   {'location': 'Red Bluff - Walnut o',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 40.170917, 'longitude': -122.255667},
#    'country': 'US',
#    'city': 'Red Bluff'},
#   {'location': 'McMillan Reservoir',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.921848, 'longitude': -77.013176},
#    'country': 'US',
#    'city': 'Washington-Arlington-Alexandria'},
#   {'location': 'Plummer CDA Tribe',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 2.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 47.3386, 'longitude': -116.885902},
#    'country': 'US',
#    'city': 'BENEWAH'},
#   {'location': 'CLEVELAND',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 5.1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.750833, 'longitude': -90.734167},
#    'country': 'US',
#    'city': 'BOLIVAR'},
#   {'location': 'HERNANDO',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 10.5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.820556, 'longitude': -89.987778},
#    'country': 'US',
#    'city': 'Memphis'},
#   {'location': 'Hattiesburg',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 5.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 31.322779, 'longitude': -89.287498},
#    'country': 'US',
#    'city': 'Hattiesburg'},
#   {'location': 'WAVELAND',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 6.5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 30.3008, 'longitude': -89.395798},
#    'country': 'US',
#    'city': 'Gulfport-Biloxi'},
#   {'location': 'GPORT YC',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 8.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 30.39, 'longitude': -89.0497},
#    'country': 'US',
#    'city': 'Gulfport-Biloxi'},
#   {'location': 'Hinds CC',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 8.1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.346905, 'longitude': -90.225928},
#    'country': 'US',
#    'city': 'Jackson'},
#   {'location': 'Ponca City',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 4.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.697189, 'longitude': -97.081278},
#    'country': 'US',
#    'city': 'Ponca City'},
#   {'location': 'Near Road OKC',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 6.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 35.502968, 'longitude': -97.577674},
#    'country': 'US',
#    'city': 'Oklahoma City'},
#   {'location': 'North OKC',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 4.5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 35.612801, 'longitude': -97.472198},
#    'country': 'US',
#    'city': 'Oklahoma City'},
#   {'location': 'McAlester',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 4.9,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.906082, 'longitude': -95.794128},
#    'country': 'US',
#    'city': 'McAlester'},
#   {'location': 'Glenpool',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 5.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 35.9525, 'longitude': -96.0033},
#    'country': 'US',
#    'city': 'Tulsa'},
#   {'location': 'Tulsa',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 7.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.206699, 'longitude': -95.976402},
#    'country': 'US',
#    'city': 'Tulsa'},
#   {'location': 'Copan',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 8.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.908115, 'longitude': -95.88235},
#    'country': 'US',
#    'city': 'WASHINGTON'},
#   {'location': 'South Pass',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 42.5275, 'longitude': -108.7203},
#    'country': 'US',
#    'city': 'Riverton'},
#   {'location': 'Cheyenne NCore',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.18222, 'longitude': -104.778336},
#    'country': 'US',
#    'city': 'Cheyenne'},
#   {'location': 'Casper Gaseous',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 42.82231, 'longitude': -106.36501},
#    'country': 'US',
#    'city': 'Casper'},
#   {'location': 'Pinedale Gaseous',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': -1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 42.8698, 'longitude': -109.8708},
#    'country': 'US',
#    'city': 'SUBLETTE'},
#   {'location': 'Laramie County Mobil',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': -1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.08536, 'longitude': -104.52277},
#    'country': 'US',
#    'city': 'Cheyenne'},
#   {'location': 'James Town Mobile',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.55643, 'longitude': -109.53044},
#    'country': 'US',
#    'city': 'Rock Springs'},
#   {'location': 'NCore',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T13:00:00-09:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 64.8458, 'longitude': -147.72727},
#    'country': 'US',
#    'city': 'Fairbanks'},
#   {'location': 'Hurst Road',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T13:00:00-09:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 64.762973, 'longitude': -147.310297},
#    'country': 'US',
#    'city': 'Fairbanks'},
#   {'location': 'Floyd Dryden',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T13:00:00-09:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 58.388889, 'longitude': -134.565556},
#    'country': 'US',
#    'city': 'JUNEAU'},
#   {'location': 'Butte (Harrison Cour',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T13:00:00-09:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 61.534163, 'longitude': -149.031655},
#    'country': 'US',
#    'city': 'MATANUSKA-SUSITNA'},
#   {'location': 'Camp Pendleton',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 7.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.217026, 'longitude': -117.396156},
#    'country': 'US',
#    'city': 'San Diego-Carlsbad-San Marcos'},
#   {'location': 'Otay Mesa - Donovan',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 7.9,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.579361, 'longitude': -116.929486},
#    'country': 'US',
#    'city': 'San Diego-Carlsbad-San Marcos'},
#   {'location': 'El Cajon - Lexington',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 10.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.789561, 'longitude': -116.944222},
#    'country': 'US',
#    'city': 'San Diego-Carlsbad-San Marcos'},
#   {'location': 'San Francisco',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.7658, 'longitude': -122.3978},
#    'country': 'US',
#    'city': 'San Francisco-Oakland-Fremont'},
#   {'location': 'Stockton - Hazelton',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.95075, 'longitude': -121.26897},
#    'country': 'US',
#    'city': 'Stockton'},
#   {'location': 'San Luis Obispo - Hi',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 35.25651, 'longitude': -120.6693},
#    'country': 'US',
#    'city': 'SAN LUIS OBISPO'},
#   {'location': 'Redwood City',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.4828, 'longitude': -122.2022},
#    'country': 'US',
#    'city': 'San Francisco-Oakland-Fremont'},
#   {'location': 'Santa Barbara',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.42775, 'longitude': -119.69091},
#    'country': 'US',
#    'city': 'Santa Barbara-Santa Maria'},
#   {'location': 'Santa Maria - Broadw',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.942872, 'longitude': -120.435611},
#    'country': 'US',
#    'city': 'Santa Barbara-Santa Maria'},
#   {'location': 'MCADORY',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 7.2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.3311, 'longitude': -87.0036},
#    'country': 'US',
#    'city': 'Birmingham-Hoover'},
#   {'location': 'WYLAM',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 9.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.4997, 'longitude': -86.9242},
#    'country': 'US',
#    'city': 'Birmingham-Hoover'},
#   {'location': 'CORNER',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 13.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.8017, 'longitude': -86.9425},
#    'country': 'US',
#    'city': 'Birmingham-Hoover'},
#   {'location': 'Shuttlesworth',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 8.5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.565278, 'longitude': -86.796389},
#    'country': 'US',
#    'city': 'Birmingham-Hoover'},
#   {'location': 'MONTG',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 14.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.4069, 'longitude': -86.2564},
#    'country': 'US',
#    'city': 'Montgomery'},
#   {'location': 'Ward',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 5.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.36253, 'longitude': -88.27792},
#    'country': 'US',
#    'city': 'SUMTER'},
#   {'location': 'Garden',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T13:00:00-09:00'},
#    'value': 4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 61.205861, 'longitude': -149.8246},
#    'country': 'US',
#    'city': 'Anchorage'},
#   {'location': 'Bethel',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T13:00:00-09:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 60.79583, 'longitude': -161.767},
#    'country': 'US',
#    'city': 'BETHEL'},
#   {'location': 'Keeler',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 2.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.4878, 'longitude': -117.871},
#    'country': 'US',
#    'city': 'Bishop'},
#   {'location': 'Mojave - 923 Poole S',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 35.05045, 'longitude': -118.14778},
#    'country': 'US',
#    'city': 'Bakersfield'},
#   {'location': 'Bakersfield - Califo',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 35.356615, 'longitude': -119.062613},
#    'country': 'US',
#    'city': 'Bakersfield'},
#   {'location': 'Glendora - Laurel',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 11.1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.1439, 'longitude': -117.8508},
#    'country': 'US',
#    'city': 'Los Angeles-Long Beach-Santa Ana'},
#   {'location': 'Los Angeles - N. Mai',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.066429, 'longitude': -118.226755},
#    'country': 'US',
#    'city': 'Los Angeles-Long Beach-Santa Ana'},
#   {'location': 'Reseda',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 4.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.1992, 'longitude': -118.5331},
#    'country': 'US',
#    'city': 'Los Angeles-Long Beach-Santa Ana'},
#   {'location': 'South Long Beach',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 10.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.792221, 'longitude': -118.175278},
#    'country': 'US',
#    'city': 'Los Angeles-Long Beach-Santa Ana'},
#   {'location': 'Santa Clarita',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 2.5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.3833, 'longitude': -118.5283},
#    'country': 'US',
#    'city': 'Los Angeles-Long Beach-Santa Ana'},
#   {'location': 'Lancaster-Division',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.669589, 'longitude': -118.130689},
#    'country': 'US',
#    'city': 'Los Angeles-Long Beach-Santa Ana'},
#   {'location': 'San Rafael',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.9722, 'longitude': -122.5189},
#    'country': 'US',
#    'city': 'San Francisco-Oakland-Fremont'},
#   {'location': 'Yosemite Village - V',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.748707, 'longitude': -119.587094},
#    'country': 'US',
#    'city': 'MARIPOSA'},
#   {'location': 'Ukiah Library',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.150478, 'longitude': -123.206528},
#    'country': 'US',
#    'city': 'MENDOCINO'},
#   {'location': 'Willits Justice Cent',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': -1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.411743, 'longitude': -123.352661},
#    'country': 'US',
#    'city': 'Ukiah'},
#   {'location': 'Mammoth Lakes',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.645718, 'longitude': -118.966515},
#    'country': 'US',
#    'city': 'MONO'},
#   {'location': 'Carmel Valley AMS',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.48187, 'longitude': -121.73333},
#    'country': 'US',
#    'city': 'Salinas'},
#   {'location': 'King City AMS',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.209286, 'longitude': -121.126371},
#    'country': 'US',
#    'city': 'MONTEREY'},
#   {'location': 'Salinas AMS',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.694261, 'longitude': -121.623271},
#    'country': 'US',
#    'city': 'Salinas'},
#   {'location': 'Napa - Napa Valley C',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.278849, 'longitude': -122.275024},
#    'country': 'US',
#    'city': 'Napa'},
#   {'location': 'Anaheim',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 9.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.830586, 'longitude': -117.938509},
#    'country': 'US',
#    'city': 'Los Angeles-Long Beach-Santa Ana'},
#   {'location': 'Mission Viejo',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 6.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.629991, 'longitude': -117.675875},
#    'country': 'US',
#    'city': 'Los Angeles-Long Beach-Santa Ana'},
#   {'location': 'Roseville - N.Sunris',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.74643, 'longitude': -121.26498},
#    'country': 'US',
#    'city': 'Sacramento--Arden-Arcade--Roseville'},
#   {'location': 'Joshua Tree NP - Cot',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.7472, 'longitude': -115.8201},
#    'country': 'US',
#    'city': 'RIVERSIDE'},
#   {'location': 'Banning - South Hath',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.920758, 'longitude': -116.858419},
#    'country': 'US',
#    'city': 'Riverside-San Bernardino-Ontario'},
#   {'location': 'Temecula (Lake Skinn',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.583099, 'longitude': -117.072197},
#    'country': 'US',
#    'city': 'Riverside-San Bernardino-Ontario'},
#   {'location': 'Indio - Jackson Stre',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.708566, 'longitude': -116.215394},
#    'country': 'US',
#    'city': 'Riverside-San Bernardino-Ontario'},
#   {'location': 'Riverside - Rubidoux',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.999449, 'longitude': -117.415831},
#    'country': 'US',
#    'city': 'Riverside-San Bernardino-Ontario'},
#   {'location': 'Mira Loma - Van Bure',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 4.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.996387, 'longitude': -117.4925},
#    'country': 'US',
#    'city': 'Riverside-San Bernardino-Ontario'},
#   {'location': 'Lake Elsinore - W. F',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.676535, 'longitude': -117.331027},
#    'country': 'US',
#    'city': 'Riverside-San Bernardino-Ontario'},
#   {'location': 'Arden Arcade - Del P',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.613804, 'longitude': -121.368007},
#    'country': 'US',
#    'city': 'Sacramento--Arden-Arcade--Roseville'},
#   {'location': 'Downtown Sacramento',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.56844, 'longitude': -121.49311},
#    'country': 'US',
#    'city': 'Sacramento--Arden-Arcade--Roseville'},
#   {'location': 'Elk Grove',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.302591, 'longitude': -121.420838},
#    'country': 'US',
#    'city': 'Sacramento--Arden-Arcade--Roseville'},
#   {'location': 'Sloughhouse',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.494475, 'longitude': -121.211131},
#    'country': 'US',
#    'city': 'Sacramento--Arden-Arcade--Roseville'},
#   {'location': 'Hollister AMS',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.843425, 'longitude': -121.3621},
#    'country': 'US',
#    'city': 'San Jose-Sunnyvale-Santa Clara'},
#   {'location': 'Crestline - Lake Gre',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 4.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.243132, 'longitude': -117.272275},
#    'country': 'US',
#    'city': 'Riverside-San Bernardino-Ontario'},
#   {'location': 'Victorville - Park A',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.51, 'longitude': -117.3306},
#    'country': 'US',
#    'city': 'Riverside-San Bernardino-Ontario'},
#   {'location': 'Upland',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.10366, 'longitude': -117.629096},
#    'country': 'US',
#    'city': 'Riverside-San Bernardino-Ontario'},
#   {'location': 'Alpine',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 8.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.842297, 'longitude': -116.768326},
#    'country': 'US',
#    'city': 'San Diego-Carlsbad-San Marcos'},
#   {'location': 'Lompoc H Street',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.637798, 'longitude': -120.456703},
#    'country': 'US',
#    'city': 'Santa Barbara-Santa Maria'},
#   {'location': 'Goleta',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.445301, 'longitude': -119.827797},
#    'country': 'US',
#    'city': 'Santa Barbara-Santa Maria'},
#   {'location': 'Gilory - 9th Street',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.999571, 'longitude': -121.574684},
#    'country': 'US',
#    'city': 'San Jose-Sunnyvale-Santa Clara'},
#   {'location': 'San Jose - Jackson S',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.3483, 'longitude': -121.8947},
#    'country': 'US',
#    'city': 'San Jose-Sunnyvale-Santa Clara'},
#   {'location': 'San Jose - Knox Ave',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.338202, 'longitude': -121.849892},
#    'country': 'US',
#    'city': 'San Jose-Sunnyvale-Santa Clara'},
#   {'location': 'Santa Cruz AMS',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.98332, 'longitude': -121.98822},
#    'country': 'US',
#    'city': 'Santa Cruz-Watsonville'},
#   {'location': 'SLV Middle School AM',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': -1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.06315, 'longitude': -122.083092},
#    'country': 'US',
#    'city': 'Santa Cruz-Watsonville'},
#   {'location': 'Redding',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 40.5497, 'longitude': -122.3792},
#    'country': 'US',
#    'city': 'Redding'},
#   {'location': 'Anderson',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 7.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 40.4531, 'longitude': -122.2978},
#    'country': 'US',
#    'city': 'Redding'},
#   {'location': 'Alamo Lake',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.243889, 'longitude': -113.558611},
#    'country': 'US',
#    'city': 'LA PAZ'},
#   {'location': 'West Phoenix',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 3.9,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.483799, 'longitude': -112.142601},
#    'country': 'US',
#    'city': 'Phoenix-Mesa-Scottsdale'},
#   {'location': 'Mesa - Brooks Reserv',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 3.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.4105, 'longitude': -111.8651},
#    'country': 'US',
#    'city': 'Phoenix-Mesa-Scottsdale'},
#   {'location': 'North Phoenix',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 3.5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.560299, 'longitude': -112.066299},
#    'country': 'US',
#    'city': 'Phoenix-Mesa-Scottsdale'},
#   {'location': 'Glendale Community C',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 0.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.5694, 'longitude': -112.1915},
#    'country': 'US',
#    'city': 'Phoenix-Mesa-Scottsdale'},
#   {'location': 'South Phoenix',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 1.1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.4033, 'longitude': -112.0731},
#    'country': 'US',
#    'city': 'Phoenix-Mesa-Scottsdale'},
#   {'location': 'Tempe',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 3.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.4124, 'longitude': -111.9347},
#    'country': 'US',
#    'city': 'Phoenix-Mesa-Scottsdale'},
#   {'location': 'Thirty Third',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': -2.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.461807, 'longitude': -112.128044},
#    'country': 'US',
#    'city': 'Phoenix-Mesa-Scottsdale'},
#   {'location': 'Durango Complex',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 8.2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.4265, 'longitude': -112.1181},
#    'country': 'US',
#    'city': 'Phoenix-Mesa-Scottsdale'},
#   {'location': 'Phoenix JLG Supersit',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 33.503601, 'longitude': -112.095001},
#    'country': 'US',
#    'city': 'Phoenix-Mesa-Scottsdale'},
#   {'location': 'Orange Grove',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': -3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.322573, 'longitude': -111.037709},
#    'country': 'US',
#    'city': 'PIMA'},
#   {'location': "Children's Park Site",
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.2953, 'longitude': -110.9822},
#    'country': 'US',
#    'city': 'Tucson'},
#   {'location': 'Geronimo',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.25, 'longitude': -110.9667},
#    'country': 'US',
#    'city': 'Tucson'},
#   {'location': 'Casa Grande Downtown',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.877583, 'longitude': -111.852219},
#    'country': 'US',
#    'city': 'Phoenix-Mesa-Scottsdale'},
#   {'location': 'Hidden Valley',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.884761, 'longitude': -112.03705},
#    'country': 'US',
#    'city': 'PINAL'},
#   {'location': 'Nogales Post Office',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 31.337204, 'longitude': -110.936722},
#    'country': 'US',
#    'city': 'Nogales'},
#   {'location': 'Yuma Supersite',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T15:00:00-07:00'},
#    'value': 5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.690277, 'longitude': -114.614441},
#    'country': 'US',
#    'city': 'Yuma'},
#   {'location': 'PARR',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 5.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 34.7561, 'longitude': -92.2758},
#    'country': 'US',
#    'city': 'Little Rock-North Little Rock'},
#   {'location': 'SPRNGDLE',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.1797, 'longitude': -94.1167},
#    'country': 'US',
#    'city': 'Fayetteville-Springdale-Rogers'},
#   {'location': 'Livermore - Rincon',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.687526, 'longitude': -121.784217},
#    'country': 'US',
#    'city': 'San Francisco-Oakland-Fremont'},
#   {'location': 'Oakland',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.743061, 'longitude': -122.169907},
#    'country': 'US',
#    'city': 'San Francisco-Oakland-Fremont'},
#   {'location': 'Oakland West',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': -4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.8148, 'longitude': -122.282402},
#    'country': 'US',
#    'city': 'San Francisco-Oakland-Fremont'},
#   {'location': 'Laney College',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.793624, 'longitude': -122.263376},
#    'country': 'US',
#    'city': 'San Francisco-Oakland-Fremont'},
#   {'location': 'Berkeley Aquatic Par',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': -2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.864767, 'longitude': -122.302741},
#    'country': 'US',
#    'city': 'ALAMEDA'},
#   {'location': 'Pleasanton - Owens C',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.701222, 'longitude': -121.903019},
#    'country': 'US',
#    'city': 'San Francisco-Oakland-Fremont'},
#   {'location': 'Chico -  East',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.76168, 'longitude': -121.84047},
#    'country': 'US',
#    'city': 'BUTTE'},
#   {'location': 'Paradise Theater',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.77919, 'longitude': -121.59135},
#    'country': 'US',
#    'city': 'BUTTE'},
#   {'location': 'San Andreas',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.20185, 'longitude': -120.680277},
#    'country': 'US',
#    'city': 'CALAVERAS'},
#   {'location': 'Colusa - Sunrise Blv',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': -3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.18919, 'longitude': -121.99887},
#    'country': 'US',
#    'city': 'COLUSA'},
#   {'location': 'Concord',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.9383, 'longitude': -122.025},
#    'country': 'US',
#    'city': 'San Francisco-Oakland-Fremont'},
#   {'location': 'San Pablo - Rumrill',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 20,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.9604, 'longitude': -122.3571},
#    'country': 'US',
#    'city': 'San Francisco-Oakland-Fremont'},
#   {'location': 'Fresno - Garland',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 5.9,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.78538, 'longitude': -119.77321},
#    'country': 'US',
#    'city': 'FRESNO'},
#   {'location': 'Willows-Colusa',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.53387, 'longitude': -122.190834},
#    'country': 'US',
#    'city': 'GLENN'},
#   {'location': 'Calexico - Ethel Str',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.67618, 'longitude': -115.48307},
#    'country': 'US',
#    'city': 'El Centro'},
#   {'location': 'NCore - White Mounta',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 4.1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 37.360701, 'longitude': -118.330835},
#    'country': 'US',
#    'city': 'Bishop'},
#   {'location': 'SYDNEY',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 7.2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 27.9659, 'longitude': -82.230617},
#    'country': 'US',
#    'city': 'Tampa-St. Petersburg-Clearwater'},
#   {'location': 'Bonifay',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T16:00:00-06:00'},
#    'value': 17.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 30.8475, 'longitude': -85.6044},
#    'country': 'US',
#    'city': 'HOLMES'},
#   {'location': 'Winkler Pump Station',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 5.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 26.6028, 'longitude': -81.8789},
#    'country': 'US',
#    'city': 'Cape Coral-Fort Myers'},
#   {'location': 'Tallahassee Communit',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 48.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 30.4397, 'longitude': -84.3483},
#    'country': 'US',
#    'city': 'Tallahassee'},
#   {'location': 'YMCA - Marion County',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 9.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 29.170799, 'longitude': -82.1008},
#    'country': 'US',
#    'city': 'Ocala'},
#   {'location': 'Stuart',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 4.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 27.172459, 'longitude': -80.240692},
#    'country': 'US',
#    'city': 'MARTIN'},
#   {'location': 'Kendal',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 5.1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 25.686944, 'longitude': -80.686944},
#    'country': 'US',
#    'city': 'Miami-Fort Lauderdale-Miami Beach'},
#   {'location': 'Miami Fire Station #',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 5.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 25.7947, 'longitude': -80.2156},
#    'country': 'US',
#    'city': 'Miami-Fort Lauderdale-Miami Beach'},
#   {'location': 'Homestead Fire Stati',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 5.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 25.4719, 'longitude': -80.4828},
#    'country': 'US',
#    'city': 'Miami-Fort Lauderdale-Miami Beach'},
#   {'location': 'Winter Park',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 5.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.5997, 'longitude': -81.3628},
#    'country': 'US',
#    'city': 'Orlando-Kissimmee'},
#   {'location': 'Belle Glade',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 16.2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 26.724167, 'longitude': -80.663055},
#    'country': 'US',
#    'city': 'PALM BEACH'},
#   {'location': 'St. Petersburg Colle',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 5.5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 27.9711, 'longitude': -82.7361},
#    'country': 'US',
#    'city': 'Tampa-St. Petersburg-Clearwater'},
#   {'location': 'Azalea',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 6.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 27.7858, 'longitude': -82.74},
#    'country': 'US',
#    'city': 'Tampa-St. Petersburg-Clearwater'},
#   {'location': 'John A. Chesnut Sr.',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 7.5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.0903, 'longitude': -82.7008},
#    'country': 'US',
#    'city': 'Tampa-St. Petersburg-Clearwater'},
#   {'location': 'Fl. Baptist Children',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 15.5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.0294, 'longitude': -81.9719},
#    'country': 'US',
#    'city': 'Lakeland'},
#   {'location': 'Bee Ridge',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 5.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 27.2906, 'longitude': -82.5072},
#    'country': 'US',
#    'city': 'Sarasota-Bradenton-Venice'},
#   {'location': 'Jackson Road',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 6.1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 27.0892, 'longitude': -82.3625},
#    'country': 'US',
#    'city': 'Sarasota-Bradenton-Venice'},
#   {'location': 'Seminole Community C',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 8.5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 28.7456, 'longitude': -81.31},
#    'country': 'US',
#    'city': 'Orlando-Kissimmee'},
#   {'location': 'Blind Services; 1185',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 10.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 29.2069, 'longitude': -81.0531},
#    'country': 'US',
#    'city': 'Deltona-Daytona Beach-Ormond Beach'},
#   {'location': 'St. Marks Wildlife R',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T17:00:00-05:00'},
#    'value': 6.9,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 30.0842, 'longitude': -84.1617},
#    'country': 'US',
#    'city': 'Tallahassee'},
#   {'location': 'Yreka',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.72679, 'longitude': -122.63359},
#    'country': 'US',
#    'city': 'SISKIYOU'},
#   {'location': 'Vallejo',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.102507, 'longitude': -122.237976},
#    'country': 'US',
#    'city': 'Vallejo-Fairfield'},
#   {'location': 'Sebastopol',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T22:00:00.000Z',
#     'local': '2020-03-30T14:00:00-08:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.403765, 'longitude': -122.818294},
#    'country': 'US',
#    'city': 'Santa Rosa-Petaluma'},
#   {'location': 'Modesto - 14th Stree',
#    'parameter': 'pm25',
# ...
#     'local': '2020-03-30T15:00:00-06:00'},
#    'value': 5.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.650259, 'longitude': -90.350463},
#    'country': 'US',
#    'city': 'St. Louis'},
#   {'location': 'BROADWAY (South)',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T15:00:00-06:00'},
#    'value': -1.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.5425, 'longitude': -90.263611},
#    'country': 'US',
#    'city': 'St. Louis'},
#   {'location': 'BLAIR STREET',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T15:00:00-06:00'},
#    'value': 5.1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.656449, 'longitude': -90.198548},
#    'country': 'US',
#    'city': 'St. Louis'},
#   {'location': 'Branch Street',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T15:00:00-06:00'},
#    'value': 5.1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.65643, 'longitude': -90.18977},
#    'country': 'US',
#    'city': 'ST. LOUIS (CITY)'},
#   {'location': 'Forest Park',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T15:00:00-06:00'},
#    'value': 1.5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.631057, 'longitude': -90.281144},
#    'country': 'US',
#    'city': 'St. Louis'},
#   {'location': 'NCORE',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T15:00:00-06:00'},
#    'value': 4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.2474, 'longitude': -95.9731},
#    'country': 'US',
#    'city': 'Omaha-Council Bluffs'},
#   {'location': 'LLCHD BAM',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T15:00:00-06:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 40.812558, 'longitude': -96.675733},
#    'country': 'US',
#    'city': 'Lincoln'},
#   {'location': '2912 Coffey',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T15:00:00-06:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.133317, 'longitude': -95.956078},
#    'country': 'US',
#    'city': 'Omaha-Council Bluffs'},
#   {'location': 'Paul Meyer',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T13:00:00-08:00'},
#    'value': 3.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.106389, 'longitude': -115.253333},
#    'country': 'US',
#    'city': 'Las Vegas-Paradise'},
#   {'location': 'Santa Teresa',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T14:00:00-07:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 31.7878, 'longitude': -106.6828},
#    'country': 'US',
#    'city': 'Las Cruces'},
#   {'location': 'Las Cruces ED',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T14:00:00-07:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.310332, 'longitude': -106.751211},
#    'country': 'US',
#    'city': 'DONA ANA'},
#   {'location': 'Hobbs Jefferson',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T14:00:00-07:00'},
#    'value': 6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 32.7267, 'longitude': -103.1233},
#    'country': 'US',
#    'city': 'Hobbs'},
#   {'location': 'Santa Fe Airport',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T14:00:00-07:00'},
#    'value': 0,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 35.6198, 'longitude': -106.0797},
#    'country': 'US',
#    'city': 'Santa Fe'},
#   {'location': 'Taos Fire Station',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T14:00:00-07:00'},
#    'value': 6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.3833, 'longitude': -105.5833},
#    'country': 'US',
#    'city': 'Taos'},
#   {'location': 'Burdens Creek',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 3.9,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 35.889402, 'longitude': -78.8747},
#    'country': 'US',
#    'city': 'Durham'},
#   {'location': 'HATTIEAVEN',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 3.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.1106, 'longitude': -80.2267},
#    'country': 'US',
#    'city': 'Winston-Salem'},
#   {'location': 'Clemmons Middle',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 3.9,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 36.0261, 'longitude': -80.3419},
#    'country': 'US',
#    'city': 'Winston-Salem'},
#   {'location': 'West Union',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': -1.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.79471, 'longitude': -83.533988},
#    'country': 'US',
#    'city': 'ADAMS'},
#   {'location': 'Lima',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': -0.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 40.771, 'longitude': -84.0539},
#    'country': 'US',
#    'city': 'Lima'},
#   {'location': 'CHARLESTON',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.346258, 'longitude': -81.621161},
#    'country': 'US',
#    'city': 'KANAWHA'},
#   {'location': 'Bad River Tribal Sch',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T15:00:00-06:00'},
#    'value': 3.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 46.6144, 'longitude': -90.6986},
#    'country': 'US',
#    'city': 'ASHLAND'},
#   {'location': 'GREEN BAY E HIGH',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T15:00:00-06:00'},
#    'value': 3.9,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 44.5167, 'longitude': -87.9939},
#    'country': 'US',
#    'city': 'Green Bay'},
#   {'location': 'MADISON EAST',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T15:00:00-06:00'},
#    'value': 3.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 43.1008, 'longitude': -89.3572},
#    'country': 'US',
#    'city': 'Madison'},
#   {'location': 'Springfield PM',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 1.9,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.92882, 'longitude': -83.80949},
#    'country': 'US',
#    'city': 'Springfield'},
#   {'location': 'Batavia',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': -1.9,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.0828, 'longitude': -84.1441},
#    'country': 'US',
#    'city': 'Cincinnati-Middletown'},
#   {'location': 'G.T.Craig',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.492191, 'longitude': -81.678552},
#    'country': 'US',
#    'city': 'Cleveland-Elyria-Mentor'},
#   {'location': 'Cleveland Near Road',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 6.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.4409, 'longitude': -81.4949},
#    'country': 'US',
#    'city': 'Cleveland-Elyria-Mentor'},
#   {'location': 'New Albany',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 2.2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 40.0845, 'longitude': -82.81552},
#    'country': 'US',
#    'city': 'Columbus'},
#   {'location': 'Columbus NR - Smoky',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 2.8,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 40.11109, 'longitude': -83.065376},
#    'country': 'US',
#    'city': 'Columbus'},
#   {'location': 'Sycamore',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 2.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.2787, 'longitude': -84.36612},
#    'country': 'US',
#    'city': 'Cincinnati-Middletown'},
#   {'location': 'Colerain',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 3.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.21494, 'longitude': -84.69086},
#    'country': 'US',
#    'city': 'Cincinnati-Middletown'},
#   {'location': 'Taft',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 2.1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.12886, 'longitude': -84.50404},
#    'country': 'US',
#    'city': 'Cincinnati-Middletown'},
#   {'location': 'Cincinnati Near Road',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 1.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.146025, 'longitude': -84.538375},
#    'country': 'US',
#    'city': 'Cincinnati-Middletown'},
#   {'location': 'Steubenville',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 1.2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 40.366452, 'longitude': -80.615691},
#    'country': 'US',
#    'city': 'Weirton-Steubenville'},
#   {'location': 'Painesville - JFS',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 4.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.726811, 'longitude': -81.242156},
#    'country': 'US',
#    'city': 'Cleveland-Elyria-Mentor'},
#   {'location': 'Ironton - ODOT',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 0.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 38.508114, 'longitude': -82.659301},
#    'country': 'US',
#    'city': 'Portsmouth'},
#   {'location': 'Erie',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 4.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.644067, 'longitude': -83.54625},
#    'country': 'US',
#    'city': 'Toledo'},
#   {'location': 'Youngstown - Head St',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 5.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.095938, 'longitude': -80.658467},
#    'country': 'US',
#    'city': 'Youngstown-Warren-Boardman'},
#   {'location': 'Preble County',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.83562, 'longitude': -84.72049},
#    'country': 'US',
#    'city': 'Dayton'},
#   {'location': 'Canton',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 1.1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 40.800717, 'longitude': -81.373},
#    'country': 'US',
#    'city': 'Canton-Massillon'},
#   {'location': 'East High School',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 3.2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.063526, 'longitude': -81.468956},
#    'country': 'US',
#    'city': 'Akron'},
#   {'location': 'Youngstown - Laird A',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': -1.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 41.23172, 'longitude': -80.80116},
#    'country': 'US',
#    'city': 'Youngstown-Warren-Boardman'},
#   {'location': 'Lebanon',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T16:00:00-05:00'},
#    'value': 5.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 39.42689, 'longitude': -84.20077},
#    'country': 'US',
#    'city': 'Cincinnati-Middletown'},
#   {'location': 'Baker City - Forest',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T13:00:00-08:00'},
#    'value': 2.6,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 44.78822, 'longitude': -117.8446},
#    'country': 'US',
#    'city': 'BAKER'},
#   {'location': 'Corvallis - Circle B',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T13:00:00-08:00'},
#    'value': 2.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 44.5884, 'longitude': -123.2673},
#    'country': 'US',
#    'city': 'Corvallis'},
#   {'location': 'Portland - Sauvie Is',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T13:00:00-08:00'},
#    'value': 2.3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 45.768531, 'longitude': -122.7721},
#    'country': 'US',
#    'city': 'Portland-Vancouver-Beaverton'},
#   {'location': 'CTCLUSI Radar Hill-O',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T13:00:00-08:00'},
#    'value': 2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 43.381943, 'longitude': -124.263885},
#    'country': 'US',
#    'city': 'COOS'},
#   {'location': 'Prineville - Davidso',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T13:00:00-08:00'},
#    'value': 1,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 44.299787, 'longitude': -120.844773},
#    'country': 'US',
#    'city': 'Prineville'},
#   {'location': 'Sisters Forest Servi',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T13:00:00-08:00'},
#    'value': 1.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 44.2921, 'longitude': -121.5555},
#    'country': 'US',
#    'city': 'DESCHUTES'},
#   {'location': 'Bend - Pump Station',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T13:00:00-08:00'},
#    'value': 1.4,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 44.063916, 'longitude': -121.312554},
#    'country': 'US',
#    'city': 'Bend'},
#   {'location': 'Roseburg - Garden Va',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T13:00:00-08:00'},
#    'value': 1.5,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 43.2266, 'longitude': -123.36479},
#    'country': 'US',
#    'city': 'Roseburg'},
#   {'location': 'John Day Dayton St',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T13:00:00-08:00'},
#    'value': 3,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 44.417999, 'longitude': -118.951302},
#    'country': 'US',
#    'city': 'GRANT'},
#   {'location': 'Shady Cove - Shady C',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T13:00:00-08:00'},
#    'value': 2.7,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 42.623225, 'longitude': -122.810158},
#    'country': 'US',
#    'city': 'Medford'},
#   {'location': 'Ashland Fire Dept',
#    'parameter': 'pm25',
#    'date': {'utc': '2020-03-30T21:00:00.000Z',
#     'local': '2020-03-30T13:00:00-08:00'},
#    'value': 2.2,
#    'unit': 'µg/m³',
#    'coordinates': {'latitude': 42.1941, 'longitude': -122.7086},
#    'country': 'US',
#    'city': 'JACKSON'},
#   ...]}

# %%
# pd.DataFrame(response.json())
data = pd.DataFrame(json_normalize(response.json()['results'])).reset_index()
data.head()
data.shape
# Out:
# (2000, 11)

# %%
# Fazer requests separadas e depois concat

# Criar um for loop pra request de todos os parâmetros?

# Criar logica para buscar só as infos das cidades que quero analisar?
