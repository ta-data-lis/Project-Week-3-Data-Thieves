# %%
import pandas as pd
import numpy as np
import requests
from pandas.io.json import json_normalize
from flatten_json import flatten
from datetime import date

# %%
#import
pm25 = pd.read_csv('data/openaq_pm25.csv')
no2 = pd.read_csv('data/openaq_NO2.csv')
o3 = pd.read_csv('data/openaq_o3.csv')

# %%
# Concat pm25 e NO2
data = pd.concat([pm25,no2,o3])

# %%
data.shape
data.columns
# Out:
# Index(['Unnamed: 0', 'index', 'city', 'coordinates_latitude',
#        'coordinates_longitude', 'country', 'date_local', 'date_utc',
#        'location', 'parameter', 'unit', 'value'],
#       dtype='object')

# %% [markdown]
# # Date

# %%
data['datetime'] = pd.to_datetime(data['date_utc'])
data['date'] = data['datetime'].dt.strftime('%Y-%m-%d')
data['hour'] = data['datetime'].dt.strftime('%H:%M:%S')
data.head()
# Out:
#    Unnamed: 0  index    city  coordinates_latitude  coordinates_longitude  \
# 0           0      0  Madrid              40.59333               -3.50306
# 1           1      1  Madrid              40.63389               -4.01333
# 2           2      2  Madrid              40.18528               -3.67972
# 3           3      3  Madrid              40.43000               -3.54583
# 4           4      4  Madrid              40.47917               -3.37778
#
#   country                 date_local                  date_utc location  \
# 0      ES  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1838A
# 1      ES  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1803A
# 2      ES  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1809A
# 3      ES  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1869A
# 4      ES  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1563A
#
#   parameter   unit  value                  datetime        date      hour
# 0      pm25  µg/m³   25.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00
# 1      pm25  µg/m³   13.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00
# 2      pm25  µg/m³   10.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00
# 3      pm25  µg/m³   35.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00
# 4      pm25  µg/m³   18.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00

# %%
# Separar dia e mês
data['day'] = data['date'].apply(lambda x: str(x)[8:])
data['month'] = data['date'].apply(lambda x: str(x)[5:7])
data.head()
# Out:
#    Unnamed: 0  index    city  coordinates_latitude  coordinates_longitude  \
# 0           0      0  Madrid              40.59333               -3.50306
# 1           1      1  Madrid              40.63389               -4.01333
# 2           2      2  Madrid              40.18528               -3.67972
# 3           3      3  Madrid              40.43000               -3.54583
# 4           4      4  Madrid              40.47917               -3.37778
#
#   country                 date_local                  date_utc location  \
# 0      ES  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1838A
# 1      ES  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1803A
# 2      ES  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1809A
# 3      ES  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1869A
# 4      ES  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1563A
#
#   parameter   unit  value                  datetime        date      hour day  \
# 0      pm25  µg/m³   25.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00  30
# 1      pm25  µg/m³   13.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00  30
# 2      pm25  µg/m³   10.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00  30
# 3      pm25  µg/m³   35.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00  30
# 4      pm25  µg/m³   18.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00  30
#
#   month
# 0    03
# 1    03
# 2    03
# 3    03
# 4    03

# %%
# data.dtypes
data['month'] = data['month'].astype(int)
data['day'] = data['day'].astype(int)
data.dtypes
# data.head()
# Out:
# Unnamed: 0                             int64
# index                                  int64
# city                                  object
# coordinates_latitude                 float64
# coordinates_longitude                float64
# country                               object
# date_local                            object
# date_utc                              object
# location                              object
# parameter                             object
# unit                                  object
# value                                float64
# datetime                 datetime64[ns, UTC]
# date                                  object
# hour                                  object
# day                                    int32
# month                                  int32
# dtype: object

# %% [markdown]
# # Data cleaning

# %%
data.month.unique()
data.day.unique()
# data = data.groupby(['CountryName'])['CountryName'].count()
# Out:
# array([30, 29, 28, 27, 26, 25, 24, 23, 22, 21, 20, 19, 18, 17, 31, 16, 15,
#        14, 13, 12, 11, 10,  9,  8,  7,  6,  5,  3,  2,  1,  4],
#       dtype=int64)

# %%
# Removing columns
data.columns
data.drop(columns=['Unnamed: 0'], inplace =True)
data.columns
# Out:
# Index(['index', 'city', 'coordinates_latitude', 'coordinates_longitude',
#        'country', 'date_local', 'date_utc', 'location', 'parameter', 'unit',
#        'value', 'datetime', 'date', 'hour', 'day', 'month'],
#       dtype='object')

# %%
# Cleaning names
data['city'].replace(['New York-Northern New Jersey-Long Island'], 'New York', inplace = True)
data.city.unique()
# Out:
# array(['Madrid', 'Delhi', 'Lisboa', 'New York', 'Santiago'], dtype=object)

# %%
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
msno.matrix(data)
plt.show()

# %%
data.isnull().sum()
# Out:
# index                    0
# city                     0
# coordinates_latitude     0
# coordinates_longitude    0
# country                  0
# date_local               0
# date_utc                 0
# location                 0
# parameter                0
# unit                     0
# value                    0
# datetime                 0
# date                     0
# hour                     0
# day                      0
# month                    0
# dtype: int64

# %%
# Estatística descritiva
data.groupby(['city', 'month','parameter'])['value'].describe()
# Out:
#                            count       mean         std      min      25%  \
# city     month parameter
# Delhi    2     no2        5000.0  43.587200  301.326242     0.00  24.5950
#                o3         5000.0  34.626154   30.966085    -6.70  12.6675
#                pm25       5000.0  88.545590   65.543690     0.00  69.0000
#          3     no2        5000.0  16.991308   73.883605  -323.92   8.4000
#                o3         5000.0  42.181890   45.900160    -4.79  18.1975
#                pm25       5000.0  81.432046  262.621001 -1262.00  15.8925
# Lisboa   2     no2        5000.0  34.823920   26.299808     1.30  14.3000
#                o3         5000.0  43.390720   26.920995     0.00  19.0000
#                pm25         77.0  13.357143    6.099211     1.70   7.4000
#          3     no2        5000.0  13.518460   10.985368     0.70   5.7000
#                o3         5000.0  68.145960   19.932853     1.50  57.0000
#                pm25        126.0   9.178571    4.301825     1.20   6.0750
# Madrid   2     no2        5000.0  35.980800   28.798922     1.00  13.0000
#                o3         5000.0  45.409426   28.175136     0.83  18.2800
#                pm25       5000.0  14.950400   13.652063     0.00   6.0000
#          3     no2        5000.0  13.423600   11.002326     1.00   6.0000
#                o3         5000.0  66.061962   20.756974     2.78  53.0000
#                pm25       5000.0   8.961400    6.134381     1.00   4.7500
# New York 2     no2        4543.0  17.352410   12.179749     0.00   7.0000
#                o3         5000.0  26.783200   11.910003     0.00  19.0000
#                pm25       5000.0   8.213180    5.104927    -4.90   4.9000
#          3     no2        4793.0  12.546631   10.458678     0.00   4.0000
#                o3         5000.0  32.448600    8.974980     0.00  28.0000
#                pm25       5000.0   5.083420    3.848657    -4.90   2.6000
# Santiago 2     no2         672.0  31.469643   20.137380     6.74  15.8200
#                o3          508.0  46.390059   37.680944    10.59  11.8900
#                pm25        672.0  16.168155    8.017120     4.00  11.0000
#          3     no2         721.0  31.883662   19.064947     5.43  18.0200
#                o3          629.0  45.800397   42.973727     0.86  11.0800
#                pm25        721.0  13.765603   35.861566     0.00   3.0000
#
#                              50%      75%       max
# city     month parameter
# Delhi    2     no2        35.800   50.800  21299.17
#                o3         24.700   44.900    221.10
#                pm25       82.000  100.000   2000.00
#          3     no2        12.400   18.500   3813.83
#                o3         31.700   53.810    526.80
#                pm25       27.000   45.000   2000.00
# Lisboa   2     no2        27.900   49.325    187.00
#                o3         45.000   66.000    109.00
#                pm25       14.600   17.700     31.00
#          3     no2        10.000   17.800     82.80
#                o3         72.000   82.000    121.00
#                pm25        8.700   11.700     24.20
# Madrid   2     no2        27.000   53.000    155.00
#                o3         51.000   68.000    136.20
#                pm25       11.000   20.000    182.00
#          3     no2        10.000   18.000     96.00
#                o3         68.000   81.250    112.00
#                pm25        8.000   12.000     62.00
# New York 2     no2        15.000   26.000     58.00
#                o3         30.000   36.000     55.00
#                pm25        7.300   10.700     44.20
#          3     no2        10.000   18.000     60.00
#                o3         34.000   39.000     52.00
#                pm25        4.600    6.800     39.40
# Santiago 2     no2        26.160   43.475    137.40
#                o3         32.905   75.355    157.44
#                pm25       15.000   20.000    113.00
#          3     no2        26.530   41.050    122.36
#                o3         36.230   73.710    477.71
#                pm25       12.000   18.000    937.00

# %%
# # remove rows > 400
data = data.where(data['value'] < 350)
data.sort_values(by="value").head()
data = data.dropna()
# data.shape (10395)

# remove rows abaixo de -100
data = data.where(data['value'] > 0)
data.sort_values(by="value").head()
data = data.dropna()
data.shape
# Out:
# (111552, 16)

# %%
# # # analise de corrrelação entre stringency index e mean de ar quality
# ax = sns.scatterplot(x="city", y="value", hue = 'parameter', sizes=(10, 200),data=data)

# #ao inves de mes fazer por semanas?

# %% [markdown]
# # Data Vis

# %% [markdown]
# ## PM 2.5

# %%
pm25 = data.loc[data['parameter'] == 'pm25']

# Outliers
# remove rows > 125
pm25 = pm25.where(pm25['value'] < 150)
pm25.sort_values(by="value", ascending = False).head()

pm25 = pm25.dropna()
# madrid.shape(9889)

sns.set()
fig, ax = plt.subplots(figsize=(13,8))
ax = sns.boxplot(x="city", y="value", hue = "month",
                  data=pm25, palette="PuBu")

# ax.set_xticklabels(['February, 'March'])
ax.set_xlabel("Cities")
ax.set_ylabel(" PM 2.5")
ax.set_title('PM 2.5')
  
plt.show()

# %% [markdown]
# # NO2

# %%
no2 = data.loc[data['parameter'] == 'no2']

# Outliers
# # remove rows > 125
no2 = no2.where(no2['value'] < 120)
no2.sort_values(by="value", ascending = False).head()

no2 = no2.dropna()
# # madrid.shape(9889)

sns.set()
fig, ax = plt.subplots(figsize=(13,8))
ax = sns.boxplot(x="city", y="value", hue = "month",
                  data=no2, palette="PuBu")

# ax.set_xticklabels(['February, 'March'])
ax.set_xlabel("Cities")
ax.set_ylabel("NO2")
ax.set_title('NO2 ')
   
plt.show()

# %% [markdown]
# # O3

# %%
o3 = data.loc[data['parameter'] == 'o3']

# Outliers
# # remove rows > 125
o3 = o3.where(o3['value'] < 175)
o3.sort_values(by="value", ascending = False).head()

o3 = o3.dropna()
# # madrid.shape(9889)

sns.set()
fig, ax = plt.subplots(figsize=(13,8))
ax = sns.boxplot(x="city", y="value", hue = "month",
                  data=o3, palette="PuBu")

# ax.set_xticklabels(['February, 'March'])
ax.set_xlabel("Cities")
ax.set_ylabel("NO2")
ax.set_title('NO2 ')
   
plt.show()

# %% [markdown]
# ## Madrid

# %%
# madrid = data.loc[data['city'] == 'Madrid']
# madrid = madrid.loc[madrid['parameter'] == 'pm25']
# madrid.head()

# # Outliers
# # remove rows > 125
# madrid = madrid.where(madrid['value'] < 50)
# madrid.sort_values(by="value", ascending = False).head()

# madrid = madrid.dropna()
# # madrid.shape(9889)

# sns.set()
# fig, ax = plt.subplots(figsize=(8,6))
# ax = sns.boxplot(x="month", y="value",
#                   data=madrid, palette="Blues_d")

# ax.set_xticklabels(['February', 'March'])
# ax.set_xlabel(" Months ")
# ax.set_ylabel(" PM 2.5")
# ax.set_title('PM 2.5 in Madrid')
   
# plt.show()

# %% [markdown]
# # Dheli

# %%
# delhi = data.loc[data['city'] == 'Delhi']
# delhi = delhi.loc[delhi['parameter'] == 'pm25']
# delhi.head()

# # # # Outliers
# # # remove rows > 125
# delhi = delhi.where(delhi['value'] < 200)
# delhi.sort_values(by="value", ascending = False).head()

# delhi = delhi.dropna()

# # delhi.shape (9517)
# # delhi.shape (9362)

# sns.set()
# fig, ax = plt.subplots(figsize=(8,6))
# ax = sns.boxplot(x="month", y="value",
#                   data=delhi, palette="Blues_d")

# ax.set_xticklabels(['February', 'March'])
# ax.set_xlabel(" Months ")
# ax.set_ylabel(" PM 2.5")
# ax.set_title('PM 2.5 in Delhi')
   
# plt.show()

# %% [markdown]
# # New York

# %%
# newyork = data.loc[data['city'] == 'New York']
# newyork = newyork.loc[newyork['parameter'] == 'pm25']
# newyork.head()

# # # # Outliers
# # # remove rows > 125
# # newyork = delhi.where(newyork['value'] < 200)
# # newyork.sort_values(by="value", ascending = False).head()

# # newyork = newyork.dropna()

# # delhi.shape (9517)
# # delhi.shape (9362)

# # sns.set()
# # fig, ax = plt.subplots(figsize=(8,6))
# # ax = sns.boxplot(x="month", y="value",
# #                   data=newyork, palette="Blues_d")

# # ax.set_xticklabels(['February', 'March'])
# # ax.set_xlabel(" Months ")
# # ax.set_ylabel(" PM 2.5")
# # ax.set_title('PM 2.5 in Delhi')
   
# # plt.show()

# %% [markdown]
# # Lisbon

# %%
# lis = data.loc[data['city'] == 'Lisboa']
# lis.head()
# fig, ax = plt.subplots(figsize=(8,6))
# ax = sns.boxplot(x="month", y="value",
#                   data=lis, palette="Blues_d")

# ax.set_xticklabels(['January', 'February', 'March'])
# ax.set_xlabel(" Months ")
# ax.set_ylabel(" PM 2.5")
# ax.set_title('Quadratic x Exponencial')
   
# plt.show()

# %%
# requeste mais 2 parametros NO2, CO, O3
#  mapa.
# lineplots


# POp -> Index -> Disponibilidade 

# Southend-on-Sea - London, tem todos
