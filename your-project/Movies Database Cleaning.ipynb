# %% [markdown]
# # Movies Database Cleaning

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
original_movies_db = pd.read_excel('movies.xls')
original_movies_db.head()
# Out:
#        budget                                 company country        director  \
# 0   8000000.0           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000.0                      Paramount Pictures     USA     John Hughes
# 2  15000000.0                      Paramount Pictures     USA      Tony Scott
# 3  18500000.0  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000.0                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating  \
# 0  Adventure   52287414.0               Stand by Me      R
# 1     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13
# 2     Action  179800601.0                   Top Gun     PG
# 3     Action   85160248.0                    Aliens      R
# 4  Adventure   18564613.0   Flight of the Navigator     PG
#
#               released  runtime  score               star     votes  \
# 0  1986-08-22 00:00:00     89.0    8.1        Wil Wheaton  299174.0
# 1  1986-06-11 00:00:00    103.0    7.8  Matthew Broderick  264740.0
# 2  1986-05-16 00:00:00    110.0    6.9         Tom Cruise  236909.0
# 3  1986-07-18 00:00:00    137.0    8.4   Sigourney Weaver  540152.0
# 4  1986-08-01 00:00:00     90.0    6.9        Joey Cramer   36636.0
#
#           writer    year
# 0   Stephen King  1986.0
# 1    John Hughes  1986.0
# 2       Jim Cash  1986.0
# 3  James Cameron  1986.0
# 4  Mark H. Baker  1986.0

# %%
movies_db = original_movies_db

# %%
# Filtering to just get 'USA' matches
#movies_db = movies_db[(movies_db['country'] == 'USA')]


# Filtering to just get 'BUDGET' not equal to 0.0
movies_db = movies_db[(movies_db['budget'] != 0.0)]


movies_db.head()
# Out:
#        budget                                 company country        director  \
# 0   8000000.0           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000.0                      Paramount Pictures     USA     John Hughes
# 2  15000000.0                      Paramount Pictures     USA      Tony Scott
# 3  18500000.0  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000.0                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating  \
# 0  Adventure   52287414.0               Stand by Me      R
# 1     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13
# 2     Action  179800601.0                   Top Gun     PG
# 3     Action   85160248.0                    Aliens      R
# 4  Adventure   18564613.0   Flight of the Navigator     PG
#
#               released  runtime  score               star     votes  \
# 0  1986-08-22 00:00:00     89.0    8.1        Wil Wheaton  299174.0
# 1  1986-06-11 00:00:00    103.0    7.8  Matthew Broderick  264740.0
# 2  1986-05-16 00:00:00    110.0    6.9         Tom Cruise  236909.0
# 3  1986-07-18 00:00:00    137.0    8.4   Sigourney Weaver  540152.0
# 4  1986-08-01 00:00:00     90.0    6.9        Joey Cramer   36636.0
#
#           writer    year
# 0   Stephen King  1986.0
# 1    John Hughes  1986.0
# 2       Jim Cash  1986.0
# 3  James Cameron  1986.0
# 4  Mark H. Baker  1986.0

# %%
movies_db.loc[(movies_db['year'].isnull())]
# Out:
#           budget company country director genre  gross name rating released  \
# 199   18000000.0     J&M     NaN      NaN   NaN    NaN  NaN    NaN      NaN
# 1454   5000000.0     A&M     NaN      NaN   NaN    NaN  NaN    NaN      NaN
# 1714  12000000.0     A&M     NaN      NaN   NaN    NaN  NaN    NaN      NaN
# 4831   6000000.0     B&W     NaN      NaN   NaN    NaN  NaN    NaN      NaN
#
#       runtime  score star  votes writer  year
# 199       NaN    NaN  NaN    NaN    NaN   NaN
# 1454      NaN    NaN  NaN    NaN    NaN   NaN
# 1714      NaN    NaN  NaN    NaN    NaN   NaN
# 4831      NaN    NaN  NaN    NaN    NaN   NaN

# %%
# Exclude year nan rows

movies_db = movies_db.dropna()
movies_db.isnull().sum()
# Out:
# budget      0
# company     0
# country     0
# director    0
# genre       0
# gross       0
# name        0
# rating      0
# released    0
# runtime     0
# score       0
# star        0
# votes       0
# writer      0
# year        0
# dtype: int64

# %%
# Checking column names

movies_db.columns
# Out:
# Index(['budget', 'company', 'country', 'director', 'genre', 'gross', 'name',
#        'rating', 'released', 'runtime', 'score', 'star', 'votes', 'writer',
#        'year'],
#       dtype='object')

# %%
# Selecting the columns we want to keep
movies_db = movies_db[['year', 'name', 'budget', 'gross', 'score']]


# Renaming the columns
movies_db.columns = ['YEAR', 'TITLE', 'BUDGET', 'REVENUE', 'IMDB SCORE']

movies_db
# Out:
#         YEAR                                      TITLE      BUDGET  \
# 0     1986.0                                Stand by Me   8000000.0
# 1     1986.0                   Ferris Bueller's Day Off   6000000.0
# 2     1986.0                                    Top Gun  15000000.0
# 3     1986.0                                     Aliens  18500000.0
# 4     1986.0                    Flight of the Navigator   9000000.0
# ...      ...                                        ...         ...
# 6808  2016.0                          Love & Friendship   3000000.0
# 6809  2016.0                                The Hollars   3800000.0
# 6811  2016.0  Middle School: The Worst Years of My Life   8500000.0
# 6814  2016.0                                      Risen  20000000.0
# 6817  2016.0                   Batman: The Killing Joke   3500000.0
#
#           REVENUE  IMDB SCORE
# 0      52287414.0         8.1
# 1      70136369.0         7.8
# 2     179800601.0         6.9
# 3      85160248.0         8.4
# 4      18564613.0         6.9
# ...           ...         ...
# 6808   14013564.0         6.5
# 6809    1016872.0         6.5
# 6811   19985196.0         6.1
# 6814   36874745.0         6.3
# 6817    3775000.0         6.5
#
# [4634 rows x 5 columns]

# %%
# Creating the '% BUDGET/REVENUE' column

movies_db['% BUDGET/REVENUE'] = round((movies_db['BUDGET'] / movies_db['REVENUE'] * 100), 1)

# %%
# Converting 'YEAR' column to 'int' type

movies_db['YEAR'] = movies_db['YEAR'].astype('str')
movies_db['YEAR'] = movies_db['YEAR'].apply(lambda x: x.split('.')[0])
movies_db['YEAR'] = movies_db['YEAR'].astype('int')

# %%
# Changing these 2 columns to be in millions
movies_db['BUDGET'] = round((movies_db['BUDGET'] / 1000000), 1)
movies_db['REVENUE'] = round((movies_db['REVENUE'] / 1000000), 1)

# %%
# Renaming columns to be in millions
movies_db.columns = ['YEAR', 'TITLE', 'BUDGET IN MILLIONS', 'REVENUE IN MILLIONS', 'IMDB SCORE', '% BUDGET/REVENUE']
movies_db.head()
# Out:
#    YEAR                     TITLE  BUDGET IN MILLIONS  REVENUE IN MILLIONS  \
# 0  1986               Stand by Me                 8.0                 52.3
# 1  1986  Ferris Bueller's Day Off                 6.0                 70.1
# 2  1986                   Top Gun                15.0                179.8
# 3  1986                    Aliens                18.5                 85.2
# 4  1986   Flight of the Navigator                 9.0                 18.6
#
#    IMDB SCORE  % BUDGET/REVENUE
# 0         8.1              15.3
# 1         7.8               8.6
# 2         6.9               8.3
# 3         8.4              21.7
# 4         6.9              48.5

# %%
# Final order
movies_db = movies_db[['YEAR', 'TITLE', 'BUDGET IN MILLIONS', 'REVENUE IN MILLIONS', '% BUDGET/REVENUE', 'IMDB SCORE']]

# %%
# Clean titles
movies_db['TITLE'] = movies_db['TITLE'].str.replace('-',' ').str.replace(',',' ').str.replace('.',' ').str.replace(':',' ').str.strip().str.title()
movies_db
# Out:
#       YEAR                                      TITLE  BUDGET IN MILLIONS  \
# 0     1986                                Stand By Me                 8.0
# 1     1986                   Ferris Bueller'S Day Off                 6.0
# 2     1986                                    Top Gun                15.0
# 3     1986                                     Aliens                18.5
# 4     1986                    Flight Of The Navigator                 9.0
# ...    ...                                        ...                 ...
# 6808  2016                          Love & Friendship                 3.0
# 6809  2016                                The Hollars                 3.8
# 6811  2016  Middle School  The Worst Years Of My Life                 8.5
# 6814  2016                                      Risen                20.0
# 6817  2016                   Batman  The Killing Joke                 3.5
#
#       REVENUE IN MILLIONS  % BUDGET/REVENUE  IMDB SCORE
# 0                    52.3              15.3         8.1
# 1                    70.1               8.6         7.8
# 2                   179.8               8.3         6.9
# 3                    85.2              21.7         8.4
# 4                    18.6              48.5         6.9
# ...                   ...               ...         ...
# 6808                 14.0              21.4         6.5
# 6809                  1.0             373.7         6.5
# 6811                 20.0              42.5         6.1
# 6814                 36.9              54.2         6.3
# 6817                  3.8              92.7         6.5
#
# [4634 rows x 6 columns]

# %% [markdown]
# ### Awards winning movies

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Academy_Award-winning_films'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# tag: tbody

table_body = soup.find_all('tbody')[0]
rows = [element.text for element in table_body.find_all('tr')]

clean_rows = [row.title().strip().replace('\n','  ').split('  ') for row in rows]

colnames = ['TITLE', 'YEAR', 'AWARDS', 'NOMINATIONS']
awards = pd.DataFrame(clean_rows[1:], columns = colnames)
awards.head()
# Out:
#                TITLE  YEAR AWARDS NOMINATIONS
# 0         Green Book  2018      3           5
# 1  Bohemian Rhapsody  2018      4           5
# 2               Roma  2018      3          10
# 3      Black Panther  2018      3           7
# 4      The Favourite  2018      1          10

# %%
# Like this it matches the movies' file year range
awards = awards[(awards['YEAR'] <= '2016') & (awards['YEAR'] >= '1986')]
awards['YEAR'] = awards['YEAR'].astype('int')

# %%
# Filter awards by len

awards['AWARDS'] = awards['AWARDS'].apply(lambda x: x.split(' ')[0])

# %%
# Resetting the index, as it was starting at 31
awards.reset_index()
awards_db = awards[['YEAR','TITLE', 'AWARDS', 'NOMINATIONS']]
awards_db.dtypes
# Out:
# YEAR            int64
# TITLE          object
# AWARDS         object
# NOMINATIONS    object
# dtype: object

# %%
all_db = pd.merge(movies_db, awards_db, on = 'TITLE', how = 'outer')

# %%
all_db = all_db.sort_values(['TITLE'])
all_db.reset_index()

#all_db[(all_db['AWARDS'] == '1')].head(50)
all_db.isnull().sum()
# Out:
# YEAR_x                  191
# TITLE                     9
# BUDGET IN MILLIONS      191
# REVENUE IN MILLIONS     191
# % BUDGET/REVENUE        191
# IMDB SCORE              191
# YEAR_y                 4374
# AWARDS                 4374
# NOMINATIONS            4374
# dtype: int64
