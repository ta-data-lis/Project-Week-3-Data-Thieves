# %%
import pandas as pd
import numpy as np
import requests
from pandas.io.json import json_normalize
from flatten_json import flatten
from datetime import date

# %% [markdown]
# # Requesting data

# %% [markdown]
# # Santiago

# %%
begin = date(2020,3,1)
end = date(2020,3,31)

api_string = "https://api.openaq.org/v1/measurements?city={city}&parameter={measure}&date_from={fromdate}&date_to={todate}&limit=5000"
city = "Santiago"
measure = "pm25"

response = requests.get(api_string.format(city=city,measure=measure,fromdate=begin,todate=end)).json()
response

dic_flatten = [flatten(d) for d in response['results']]
dic_flatten
santiago_3 = pd.DataFrame(dic_flatten).reset_index()
santiago_3.head()
santiago_3.shape
# Out:
# (721, 11)

# %%
begin = date(2020,2,1)
end = date(2020,2,29)

api_string = "https://api.openaq.org/v1/measurements?city={city}&parameter={measure}&date_from={fromdate}&date_to={todate}&limit=5000"
city = "Santiago"
measure = "pm25"

response = requests.get(api_string.format(city=city,measure=measure,fromdate=begin,todate=end)).json()
response

dic_flatten = [flatten(d) for d in response['results']]
dic_flatten
santiago_2 = pd.DataFrame(dic_flatten).reset_index()
santiago_2.head()
santiago_2.shape
# Out:
# (672, 11)

# %% [markdown]
# ## Madrid - ES

# %%
# Madrid
begin = date(2020,3,1)
end = date(2020,3,31)

api_string = "https://api.openaq.org/v1/measurements?city={city}&parameter={measure}&date_from={fromdate}&date_to={todate}&limit=5000"
city = "Madrid"
measure = "pm25"

response = requests.get(api_string.format(city=city,measure=measure,fromdate=begin,todate=end)).json()
response

dic_flatten = [flatten(d) for d in response['results']]
dic_flatten
madrid_3 = pd.DataFrame(dic_flatten).reset_index()
madrid_3.head()
# Out:
#    index    city  coordinates_latitude  coordinates_longitude country  \
# 0      0  Madrid              40.59333               -3.50306      ES
# 1      1  Madrid              40.63389               -4.01333      ES
# 2      2  Madrid              40.18528               -3.67972      ES
# 3      3  Madrid              40.43000               -3.54583      ES
# 4      4  Madrid              40.47917               -3.37778      ES
#
#                   date_local                  date_utc location parameter  \
# 0  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1838A      pm25
# 1  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1803A      pm25
# 2  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1809A      pm25
# 3  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1869A      pm25
# 4  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1563A      pm25
#
#     unit  value
# 0  µg/m³     25
# 1  µg/m³     13
# 2  µg/m³     10
# 3  µg/m³     35
# 4  µg/m³     18

# %%
madrid_3.shape
# Out:
# (5000, 11)

# %%
# Fevereiro
begin = date(2020,2,1)
end = date(2020,2,29)

api_string = "https://api.openaq.org/v1/measurements?city={city}&parameter={measure}&date_from={fromdate}&date_to={todate}&limit=5000"
city = "Madrid"
measure = "pm25"

response = requests.get(api_string.format(city=city,measure=measure,fromdate=begin,todate=end)).json()
response

dic_flatten = [flatten(d) for d in response['results']]
dic_flatten
madrid_2 = pd.DataFrame(dic_flatten).reset_index()
madrid_2.head()
# Out:
#    index    city  coordinates_latitude  coordinates_longitude country  \
# 0      0  Madrid              40.16722               -3.27667      ES
# 1      1  Madrid              40.34194               -3.83389      ES
# 2      2  Madrid              40.91028               -3.46667      ES
# 3      3  Madrid              40.25194               -4.27472      ES
# 4      4  Madrid              40.33972               -3.73583      ES
#
#                   date_local                  date_utc location parameter  \
# 0  2020-02-29T01:00:00+01:00  2020-02-29T00:00:00.000Z  ES1811A      pm25
# 1  2020-02-29T01:00:00+01:00  2020-02-29T00:00:00.000Z  ES1890A      pm25
# 2  2020-02-29T01:00:00+01:00  2020-02-29T00:00:00.000Z  ES1802A      pm25
# 3  2020-02-29T01:00:00+01:00  2020-02-29T00:00:00.000Z  ES1810A      pm25
# 4  2020-02-29T01:00:00+01:00  2020-02-29T00:00:00.000Z  ES1567A      pm25
#
#     unit  value
# 0  µg/m³     53
# 1  µg/m³     44
# 2  µg/m³     25
# 3  µg/m³     37
# 4  µg/m³     61

# %%
madrid_2.shape
# Out:
# (5000, 11)

# %% [markdown]
# ## Dheli - India

# %%
begin = date(2020,3,1)
end = date(2020,3,31)

api_string = "https://api.openaq.org/v1/measurements?city={city}&parameter={measure}&date_from={fromdate}&date_to={todate}&limit=5000"
city = "Delhi"
measure = "pm25"

response = requests.get(api_string.format(city=city,measure=measure,fromdate=begin,todate=end)).json()
response

dic_flatten = [flatten(d) for d in response['results']]
dic_flatten
delhi_3 = pd.DataFrame(dic_flatten).reset_index()
delhi_3.head()
# Out:
#    index   city  coordinates_latitude  coordinates_longitude country  \
# 0      0  Delhi             28.639645              77.146263      IN
# 1      1  Delhi             28.591825              77.227307      IN
# 2      2  Delhi             28.470691              77.109936      IN
# 3      3  Delhi             28.551201              77.273574      IN
# 4      4  Delhi             28.657381              77.158545      IN
#
#                   date_local                  date_utc  \
# 0  2020-03-31T05:30:00+05:30  2020-03-31T00:00:00.000Z
# 1  2020-03-31T05:30:00+05:30  2020-03-31T00:00:00.000Z
# 2  2020-03-31T05:30:00+05:30  2020-03-31T00:00:00.000Z
# 3  2020-03-31T05:30:00+05:30  2020-03-31T00:00:00.000Z
# 4  2020-03-31T05:30:00+05:30  2020-03-31T00:00:00.000Z
#
#                          location parameter   unit  value
# 0               Pusa, Delhi - IMD      pm25  µg/m³ -37.74
# 1         Lodhi Road, Delhi - IMD      pm25  µg/m³  24.58
# 2          Aya Nagar, Delhi - IMD      pm25  µg/m³  51.79
# 3  CRRI Mathura Road, Delhi - IMD      pm25  µg/m³  28.10
# 4   North Campus, DU, Delhi - IMD      pm25  µg/m³  13.61

# %%
begin = date(2020,2,1)
end = date(2020,2,29)

api_string = "https://api.openaq.org/v1/measurements?city={city}&parameter={measure}&date_from={fromdate}&date_to={todate}&limit=5000"
city = "Delhi"
measure = "pm25"

response = requests.get(api_string.format(city=city,measure=measure,fromdate=begin,todate=end)).json()
response

dic_flatten = [flatten(d) for d in response['results']]
dic_flatten
delhi_2 = pd.DataFrame(dic_flatten).reset_index()
delhi_2.head()
# Out:
#    index   city  coordinates_latitude  coordinates_longitude country  \
# 0      0  Delhi             28.470691              77.109936      IN
# 1      1  Delhi             28.562776              77.118005      IN
# 2      2  Delhi             28.551201              77.273574      IN
# 3      3  Delhi             28.657381              77.158545      IN
# 4      4  Delhi             28.681174              77.302523      IN
#
#                   date_local                  date_utc  \
# 0  2020-02-29T05:30:00+05:30  2020-02-29T00:00:00.000Z
# 1  2020-02-29T05:30:00+05:30  2020-02-29T00:00:00.000Z
# 2  2020-02-29T05:30:00+05:30  2020-02-29T00:00:00.000Z
# 3  2020-02-29T05:30:00+05:30  2020-02-29T00:00:00.000Z
# 4  2020-02-29T05:30:00+05:30  2020-02-29T00:00:00.000Z
#
#                               location parameter   unit  value
# 0               Aya Nagar, Delhi - IMD      pm25  µg/m³  40.25
# 1        IGI Airport (T3), Delhi - IMD      pm25  µg/m³  46.81
# 2       CRRI Mathura Road, Delhi - IMD      pm25  µg/m³  40.67
# 3        North Campus, DU, Delhi - IMD      pm25  µg/m³  79.36
# 4  IHBAS, Dilshad Garden, Delhi - CPCB      pm25  µg/m³  83.30

# %% [markdown]
# ## Lisbon - PT

# %%
begin = date(2020,3,1)
end = date(2020,3,31)

api_string = "https://api.openaq.org/v1/measurements?city={city}&parameter={measure}&date_from={fromdate}&date_to={todate}&limit=5000"
city = "Lisboa"
measure = "pm25"

response = requests.get(api_string.format(city=city,measure=measure,fromdate=begin,todate=end)).json()
response

dic_flatten = [flatten(d) for d in response['results']]
dic_flatten
lisbon_3 = pd.DataFrame(dic_flatten).reset_index()
lisbon_3.head()
# Out:
#    index    city  coordinates_latitude  coordinates_longitude country  \
# 0      0  Lisboa             38.785000              -9.347222      PT
# 1      1  Lisboa             38.785000              -9.347222      PT
# 2      2  Lisboa             38.768889              -9.108056      PT
# 3      3  Lisboa             38.785000              -9.347222      PT
# 4      4  Lisboa             38.785000              -9.347222      PT
#
#                   date_local                  date_utc location parameter  \
# 0  2020-03-30T20:00:00+01:00  2020-03-30T19:00:00.000Z  PT03089      pm25
# 1  2020-03-30T19:00:00+01:00  2020-03-30T18:00:00.000Z  PT03089      pm25
# 2  2020-03-30T19:00:00+01:00  2020-03-30T18:00:00.000Z  PT03071      pm25
# 3  2020-03-29T20:00:00+01:00  2020-03-29T19:00:00.000Z  PT03089      pm25
# 4  2020-03-29T14:00:00+01:00  2020-03-29T13:00:00.000Z  PT03089      pm25
#
#     unit  value
# 0  µg/m³   12.5
# 1  µg/m³   12.5
# 2  µg/m³   12.9
# 3  µg/m³    9.0
# 4  µg/m³    8.8

# %%
begin = date(2020,2,1)
end = date(2020,2,29)

api_string = "https://api.openaq.org/v1/measurements?city={city}&parameter={measure}&date_from={fromdate}&date_to={todate}&limit=5000"
city = "Lisboa"
measure = "pm25"

response = requests.get(api_string.format(city=city,measure=measure,fromdate=begin,todate=end)).json()
response

dic_flatten = [flatten(d) for d in response['results']]
dic_flatten
lisbon_2 = pd.DataFrame(dic_flatten).reset_index()
lisbon_2.head()
# Out:
#    index    city  coordinates_latitude  coordinates_longitude country  \
# 0      0  Lisboa             38.785000              -9.347222      PT
# 1      1  Lisboa             38.748611              -9.148889      PT
# 2      2  Lisboa             38.785000              -9.347222      PT
# 3      3  Lisboa             38.785000              -9.347222      PT
# 4      4  Lisboa             38.785000              -9.347222      PT
#
#                   date_local                  date_utc location parameter  \
# 0  2020-02-28T07:00:00+00:00  2020-02-28T07:00:00.000Z  PT03089      pm25
# 1  2020-02-26T13:00:00+00:00  2020-02-26T13:00:00.000Z  PT03072      pm25
# 2  2020-02-25T02:00:00+00:00  2020-02-25T02:00:00.000Z  PT03089      pm25
# 3  2020-02-25T01:00:00+00:00  2020-02-25T01:00:00.000Z  PT03089      pm25
# 4  2020-02-24T13:00:00+00:00  2020-02-24T13:00:00.000Z  PT03089      pm25
#
#     unit  value
# 0  µg/m³   26.3
# 1  µg/m³    6.6
# 2  µg/m³   10.2
# 3  µg/m³    9.8
# 4  µg/m³   31.0

# %% [markdown]
# ## New York - US

# %%
begin = date(2020,2,1)
end = date(2020,2,29)

api_string = "https://api.openaq.org/v1/measurements?city={city}&parameter={measure}&date_from={fromdate}&date_to={todate}&limit=5000"
city = "New York-Northern New Jersey-Long Island"
measure = "pm25"

response = requests.get(api_string.format(city=city,measure=measure,fromdate=begin,todate=end)).json()
response

dic_flatten = [flatten(d) for d in response['results']]
dic_flatten
new_york_2 = pd.DataFrame(dic_flatten).reset_index()
new_york_2.head()
new_york_2.shape

# %%
begin = date(2020,3,1)
end = date(2020,3,31)

api_string = "https://api.openaq.org/v1/measurements?city={city}&parameter={measure}&date_from={fromdate}&date_to={todate}&limit=5000"
city = "New York-Northern New Jersey-Long Island"
measure = "pm25"

response = requests.get(api_string.format(city=city,measure=measure,fromdate=begin,todate=end)).json()
response

dic_flatten = [flatten(d) for d in response['results']]
dic_flatten
new_york_3 = pd.DataFrame(dic_flatten).reset_index()
new_york_3.head()
new_york_3.shape

# %% [markdown]
# ## Concateneting

# %%
data = pd.concat([madrid_3,madrid_2, delhi_3, delhi_2, lisbon_3, lisbon_2,new_york_2, new_york_3, santiago_2, santiago_3])

# %%
data.head()

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-047ed65ff157> in <module>
# ----> 1 data.shape
#
# NameError: name 'data' is not defined

# %% [markdown]
# # Date

# %%
#  t = pd.tslib.Timestamp

# %%
# from datetime import datetime
data['datetime'] = pd.to_datetime(data['date_utc'])
data['date'] = data['datetime'].dt.strftime('%Y-%m-%d')
data['hour'] = data['datetime'].dt.strftime('%H:%M:%S')
# Out:
#    index    city  coordinates_latitude  coordinates_longitude country  \
# 0      0  Madrid              40.59333               -3.50306      ES
# 1      1  Madrid              40.63389               -4.01333      ES
# 2      2  Madrid              40.18528               -3.67972      ES
# 3      3  Madrid              40.43000               -3.54583      ES
# 4      4  Madrid              40.47917               -3.37778      ES
#
#                   date_local                  date_utc location parameter  \
# 0  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1838A      pm25
# 1  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1803A      pm25
# 2  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1809A      pm25
# 3  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1869A      pm25
# 4  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1563A      pm25
#
#     unit  value                  datetime        date      hour
# 0  µg/m³   25.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00
# 1  µg/m³   13.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00
# 2  µg/m³   10.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00
# 3  µg/m³   35.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00
# 4  µg/m³   18.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00

# %%
# Separar dia e mês
data['day'] = data['date'].apply(lambda x: str(x)[8:])
data['month'] = data['date'].apply(lambda x: str(x)[5:7])
data.head()
# Out:
#    index    city  coordinates_latitude  coordinates_longitude country  \
# 0      0  Madrid              40.59333               -3.50306      ES
# 1      1  Madrid              40.63389               -4.01333      ES
# 2      2  Madrid              40.18528               -3.67972      ES
# 3      3  Madrid              40.43000               -3.54583      ES
# 4      4  Madrid              40.47917               -3.37778      ES
#
#                   date_local                  date_utc location parameter  \
# 0  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1838A      pm25
# 1  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1803A      pm25
# 2  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1809A      pm25
# 3  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1869A      pm25
# 4  2020-03-30T03:00:00+02:00  2020-03-30T01:00:00.000Z  ES1563A      pm25
#
#     unit  value                  datetime        date      hour month day
# 0  µg/m³   25.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00    03  30
# 1  µg/m³   13.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00    03  30
# 2  µg/m³   10.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00    03  30
# 3  µg/m³   35.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00    03  30
# 4  µg/m³   18.0 2020-03-30 01:00:00+00:00  2020-03-30  01:00:00    03  30

# %%
data.to_csv('data/openaq_pm25.csv')

# %%
data = pd.read_csv('data/openaq_analysis.csv')
data.head()

# %%
data.month.unique()
# data = data.groupby(['CountryName'])['CountryName'].count()

# %%
# Removing columns
data.columns
data.drop(columns=['Unnamed: 0'], inplace =True)
data.columns

# %%
# Cleaning names
data['city'].replace(['New York-Northern New Jersey-Long Island'], 'New York', inplace = True)
data.city.unique()

# %%
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
msno.matrix(data)

# %%
data.isnull().sum()

# %%
# remove rows <400
data = data.where(data['value'] < 400)
data.sort_values(by="value").head()
data = data.dropna()
# data.shape (10395)

# value  > -400
data = data.where(data['value'] > -100)
data.sort_values(by="value").head()
data = data.dropna()
data.shape

# %%
pm25 = data.groupby(['city', 'month'])['value'].agg(['mean', 'min', 'max','median']).reset_index()
pm25.head(8)
# data.groupby(['city', 'month'])['value'].describe()

# %%
# # analise de corrrelação entre stringency index e mean de ar quality
# ax = sns.scatterplot(x="month", y="mean",palette="RdBu", hue = 'city', sizes=(10, 200),data=pm25)
# # 
#ao inves de mes fazer por semanas?

# %% [markdown]
# # Bogota

# %%
madrid = data.loc[data['city'] == 'Madrid']

fig, ax = plt.subplots(figsize=(8,6))
ax = sns.boxplot(x="month", y="value",
                  data=madrid, palette="Blues_d")

ax.set_xticklabels(['January', 'February', 'March'])
ax.set_xlabel(" Months ")
ax.set_ylabel(" PM 2.5")
ax.set_title('Quadratic x Exponencial')
   
plt.show()

# %% [markdown]
# # Dheli

# %%
dheli = data.loc[data['city'] == 'Delhi']
dheli.head()
fig, ax = plt.subplots(figsize=(8,6))
ax = sns.boxplot(x="month", y="value",
                  data=dheli, palette="Blues_d")

ax.set_xticklabels(['January', 'February', 'March'])
ax.set_xlabel(" Months ")
ax.set_ylabel(" PM 2.5")
ax.set_title('Pm 2.5 in Dheli')
   
plt.show()

# %% [markdown]
# # New York

# %%
ny = data.loc[data['city'] == 'New York']
ny.head()
fig, ax = plt.subplots(figsize=(8,6))
ax = sns.boxplot(x="month", y="value",
                  data=ny, palette="Blues_d")

ax.set_xticklabels(['January', 'February', 'March'])
ax.set_xlabel(" Months ")
ax.set_ylabel(" PM 2.5")
ax.set_title('Quadratic x Exponencial')
   
plt.show()

# %% [markdown]
# # Lisbon

# %%
lis = data.loc[data['city'] == 'Lisboa']
lis.head()
fig, ax = plt.subplots(figsize=(8,6))
ax = sns.boxplot(x="month", y="value",
                  data=lis, palette="Blues_d")

ax.set_xticklabels(['January', 'February', 'March'])
ax.set_xlabel(" Months ")
ax.set_ylabel(" PM 2.5")
ax.set_title('Quadratic x Exponencial')
   
plt.show()

# %%
plt(data)
sns.despine(left=True)
grid(axis='value')

# %%
# sns.set()
# sns.catplot(
#     data=data,
#     x='city',
#     y='value',
#     hue='month',
#     kind='box',
#     height=5, # make the plot 5 units high
#     aspect=3) # height should be three times width

# g = (g.set_axis_labels("City","PM 2.5").
# set(xlim=(0,10),ylim=(0,100)))

# %%
# requeste mais 2 parametros NO2, CO, O3
#  mapa.
# lineplots


# POp -> Index -> Disponibilidade 

# Southend-on-Sea - London, tem todos
