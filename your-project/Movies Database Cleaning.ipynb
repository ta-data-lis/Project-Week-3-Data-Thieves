# %% [markdown]
# # Movies Database Cleaning

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import fuzzy

# %%
original_movies_db = pd.read_excel('movies.xls')

# %%
movies_db = original_movies_db

# %%
# Filtering to just get 'USA' matches
#movies_db = movies_db[(movies_db['country'] == 'USA')]


# Filtering to just get 'BUDGET' not equal to 0.0
movies_db = movies_db[(movies_db['budget'] != 0.0)]

# %%
movies_db.loc[(movies_db['year'].isnull())]
# Out:
#           budget company country director genre  gross name rating released  \
# 199   18000000.0     J&M     NaN      NaN   NaN    NaN  NaN    NaN      NaN
# 1454   5000000.0     A&M     NaN      NaN   NaN    NaN  NaN    NaN      NaN
# 1714  12000000.0     A&M     NaN      NaN   NaN    NaN  NaN    NaN      NaN
# 4831   6000000.0     B&W     NaN      NaN   NaN    NaN  NaN    NaN      NaN
#
#       runtime  score star  votes writer  year
# 199       NaN    NaN  NaN    NaN    NaN   NaN
# 1454      NaN    NaN  NaN    NaN    NaN   NaN
# 1714      NaN    NaN  NaN    NaN    NaN   NaN
# 4831      NaN    NaN  NaN    NaN    NaN   NaN

# %%
# Exclude nan rows
movies_db['name'] = movies_db['name'].str.replace('&','and').str.replace("'",' ').str.replace('-','').str.replace(',','').str.replace('.','').str.replace(':','').str.strip().str.title()

movies_db = movies_db.dropna()
movies_db.isnull().sum()
# Out:
# /Users/marie/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# budget      0
# company     0
# country     0
# director    0
# genre       0
# gross       0
# name        0
# rating      0
# released    0
# runtime     0
# score       0
# star        0
# votes       0
# writer      0
# year        0
# dtype: int64

# %%
# Checking column names
movies_db.columns
# Out:
# Index(['budget', 'company', 'country', 'director', 'genre', 'gross', 'name',
#        'rating', 'released', 'runtime', 'score', 'star', 'votes', 'writer',
#        'year'],
#       dtype='object')

# %%
# Selecting the columns we want to keep
movies_db = movies_db[['name', 'budget', 'gross', 'score']]

# Renaming the columns
movies_db.columns = ['TITLE', 'BUDGET', 'REVENUE', 'IMDB SCORE']

movies_db
# Out:
#                                          TITLE      BUDGET      REVENUE  \
# 0                                  Stand By Me   8000000.0   52287414.0
# 1                     Ferris Bueller S Day Off   6000000.0   70136369.0
# 2                                      Top Gun  15000000.0  179800601.0
# 3                                       Aliens  18500000.0   85160248.0
# 4                      Flight Of The Navigator   9000000.0   18564613.0
# ...                                        ...         ...          ...
# 6808                       Love And Friendship   3000000.0   14013564.0
# 6809                               The Hollars   3800000.0    1016872.0
# 6811  Middle School The Worst Years Of My Life   8500000.0   19985196.0
# 6814                                     Risen  20000000.0   36874745.0
# 6817                   Batman The Killing Joke   3500000.0    3775000.0
#
#       IMDB SCORE
# 0            8.1
# 1            7.8
# 2            6.9
# 3            8.4
# 4            6.9
# ...          ...
# 6808         6.5
# 6809         6.5
# 6811         6.1
# 6814         6.3
# 6817         6.5
#
# [4625 rows x 4 columns]

# %%
# Creating the '% BUDGET/REVENUE' column

movies_db['% BUDGET/REVENUE'] = round((movies_db['BUDGET'] / movies_db['REVENUE'] * 100), 1)

# %%
# Converting 'YEAR' column to 'int' type

#movies_db['YEAR'] = movies_db['YEAR'].astype('str')
#movies_db['YEAR'] = movies_db['YEAR'].apply(lambda x: x.split('.')[0])
#movies_db['YEAR'] = movies_db['YEAR'].astype('int')

# %%
# Changing these 2 columns to be in millions
#movies_db['BUDGET'] = round((movies_db['BUDGET'] / 1000000), 1)
#movies_db['REVENUE'] = round((movies_db['REVENUE'] / 1000000), 1)


# Filtering to just get 'REVENUE' not equal to 0.0
#movies_db = movies_db[(movies_db['REVENUE'] != 0.0)]

# %%
# Renaming columns to be in millions
movies_db.columns = ['TITLE', 'BUDGET IN MILLIONS', 'REVENUE IN MILLIONS', 'IMDB SCORE', '% BUDGET/REVENUE']
movies_db.head()
# Out:
#                       TITLE  BUDGET IN MILLIONS  REVENUE IN MILLIONS  \
# 0               Stand By Me           8000000.0           52287414.0
# 1  Ferris Bueller S Day Off           6000000.0           70136369.0
# 2                   Top Gun          15000000.0          179800601.0
# 3                    Aliens          18500000.0           85160248.0
# 4   Flight Of The Navigator           9000000.0           18564613.0
#
#    IMDB SCORE  % BUDGET/REVENUE
# 0         8.1              15.3
# 1         7.8               8.6
# 2         6.9               8.3
# 3         8.4              21.7
# 4         6.9              48.5

# %%
# Final order
movies_db = movies_db[['TITLE', 'BUDGET IN MILLIONS', 'REVENUE IN MILLIONS', '% BUDGET/REVENUE', 'IMDB SCORE']]

# %%
movies_db.isnull().sum()
# Out:
# TITLE                  0
# BUDGET IN MILLIONS     0
# REVENUE IN MILLIONS    0
# % BUDGET/REVENUE       0
# IMDB SCORE             0
# dtype: int64

# %% [markdown]
# ### Awards winning movies

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Academy_Award-winning_films'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# tag: tbody

table_body = soup.find_all('tbody')[0]
rows = [element.text for element in table_body.find_all('tr')]

clean_rows = [row.strip().replace('\n','  ').split('  ') for row in rows]

colnames = ['TITLE', 'YEAR', 'AWARDS', 'NOMINATIONS']
awards = pd.DataFrame(clean_rows[1:], columns = colnames)
awards
# Out:
#                                                   TITLE  YEAR AWARDS  \
# 0                                            Green Book  2018      3
# 1                                     Bohemian Rhapsody  2018      4
# 2                                                  Roma  2018      3
# 3                                         Black Panther  2018      3
# 4                                         The Favourite  2018      1
# ...                                                 ...   ...    ...
# 1294                            The Yankee Doodle Mouse  1943      1
# 1295                                       The Yearling  1946      2
# 1296  Yesterday, Today and Tomorrow (Ieri, oggi, dom...  1964      1
# 1297                         You Can't Take It with You  1938      2
# 1298                    Zorba the Greek (Alexis Zorbas)  1964      3
#
#      NOMINATIONS
# 0              5
# 1              5
# 2             10
# 3              7
# 4             10
# ...          ...
# 1294           1
# 1295           7
# 1296           1
# 1297           7
# 1298           7
#
# [1299 rows x 4 columns]

# %%
#Clean movie title
awards['TITLE'] = awards['TITLE'].str.replace('&','and').str.replace("'",' ').str.replace('-','').str.replace(',','').str.replace('.','').str.replace(':','').str.strip().str.title()
awards['TITLE'] = awards['TITLE'].apply(lambda x: x.split('(')[0])
awards['TITLE'] = awards['TITLE'].str.strip()
awards['TITLE'].unique()
# Out:
# array(['Green Book', 'Bohemian Rhapsody', 'Roma', ...,
#        'Yesterday Today And Tomorrow', 'You Can T Take It With You',
#        'Zorba The Greek'], dtype=object)

# %%
# Like this it matches the movies' file year range
awards = awards[(awards['YEAR'] <= '2016') & (awards['YEAR'] >= '1986')]
awards['YEAR'] = awards['YEAR'].astype('int')
awards
# Out:
# /Users/marie/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                  TITLE  YEAR AWARDS NOMINATIONS
# 31                           Moonlight  2016      3           8
# 32                          La La Land  2016      6          14
# 33                       Hacksaw Ridge  2016      2           6
# 34               Manchester By The Sea  2016      2           6
# 35                             Arrival  2016      1           8
# ..                                 ...   ...    ...         ...
# 474            Down And Out In America  1986      1           1
# 475                            The Fly  1986      1           1
# 476                    A Greek Tragedy  1986      1           1
# 477                    Precious Images  1986      1           1
# 478  Women – For America For The World  1986      1           1
#
# [448 rows x 4 columns]

# %%
# Filter awards by len

awards['AWARDS'] = awards['AWARDS'].apply(lambda x: x.split(' ')[0])
# Out:
# /Users/marie/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Resetting the index, as it was starting at 31
awards.reset_index()
awards_db = awards[['TITLE', 'AWARDS', 'NOMINATIONS']]
awards_db.dtypes
# Out:
# TITLE          object
# AWARDS         object
# NOMINATIONS    object
# dtype: object

# %% [markdown]
# # Merge

# %%
all_db = pd.merge(movies_db, awards_db, on = 'TITLE', how = 'outer')
all_db
# Out:
#                                   TITLE  BUDGET IN MILLIONS  \
# 0                           Stand By Me           8000000.0
# 1              Ferris Bueller S Day Off           6000000.0
# 2                               Top Gun          15000000.0
# 3                                Aliens          18500000.0
# 4               Flight Of The Navigator           9000000.0
# ...                                 ...                 ...
# 4805                        The Assault                 NaN
# 4806            Down And Out In America                 NaN
# 4807                    A Greek Tragedy                 NaN
# 4808                    Precious Images                 NaN
# 4809  Women – For America For The World                 NaN
#
#       REVENUE IN MILLIONS  % BUDGET/REVENUE  IMDB SCORE AWARDS NOMINATIONS
# 0              52287414.0              15.3         8.1    NaN         NaN
# 1              70136369.0               8.6         7.8    NaN         NaN
# 2             179800601.0               8.3         6.9      1           4
# 3              85160248.0              21.7         8.4      2           7
# 4              18564613.0              48.5         6.9    NaN         NaN
# ...                   ...               ...         ...    ...         ...
# 4805                  NaN               NaN         NaN      1           1
# 4806                  NaN               NaN         NaN      1           1
# 4807                  NaN               NaN         NaN      1           1
# 4808                  NaN               NaN         NaN      1           1
# 4809                  NaN               NaN         NaN      1           1
#
# [4810 rows x 7 columns]

# %%
all_db = all_db.sort_values(['TITLE'])
all_db.reset_index()

all_db.isnull().sum()
# Out:
# TITLE                     0
# BUDGET IN MILLIONS      185
# REVENUE IN MILLIONS     185
# % BUDGET/REVENUE        185
# IMDB SCORE              185
# AWARDS                 4359
# NOMINATIONS            4359
# dtype: int64

# %%
all_db[['AWARDS', 'NOMINATIONS']] = all_db[['AWARDS', 'NOMINATIONS']].fillna(0)
all_db = all_db.reset_index()
all_db.isnull().sum()
# Out:
# index                    0
# TITLE                    0
# BUDGET IN MILLIONS     185
# REVENUE IN MILLIONS    185
# % BUDGET/REVENUE       185
# IMDB SCORE             185
# AWARDS                   0
# NOMINATIONS              0
# dtype: int64

# %%
all_db = all_db.dropna()
all_db.isnull().sum()
# Out:
# index                  0
# TITLE                  0
# BUDGET IN MILLIONS     0
# REVENUE IN MILLIONS    0
# % BUDGET/REVENUE       0
# IMDB SCORE             0
# AWARDS                 0
# NOMINATIONS            0
# dtype: int64

# %%
all_db = all_db[['TITLE', 'BUDGET IN MILLIONS', 'REVENUE IN MILLIONS','% BUDGET/REVENUE', 'IMDB SCORE', 'AWARDS', 'NOMINATIONS']]
all_db.head(50)
# Out:
#                          TITLE  BUDGET IN MILLIONS  REVENUE IN MILLIONS  \
# 0          10 Cloverfield Lane          15000000.0           71897215.0
# 1   10 Things I Hate About You          30000000.0           38176108.0
# 2                     10000 Bc         105000000.0           94784201.0
# 3               101 Dalmatians          75000000.0          136189294.0
# 4               102 Dalmatians          85000000.0           66957026.0
# 5     12 Horas Para Sobrevivir           9000000.0           71962800.0
# 6                    12 Rounds          22000000.0           12232937.0
# 7             12 Years A Slave          20000000.0           56671993.0
# 8                    127 Hours          18000000.0           18335230.0
# 9                 13 Assassins           6000000.0             802524.0
# 10              13 Going On 30          37000000.0           57231747.0
# 11                    13 Hours          50000000.0           52853219.0
# 12                     13 Sins           4000000.0               9134.0
# 13  1492 Conquista Del Paraìso          47000000.0            7191399.0
# 14                  15 Minutes          60000000.0           24403552.0
# 15                   16 Blocks          52000000.0           36883539.0
# 16                    17 Again          20000000.0           64167069.0
# 17            2 Fast 2 Furious          76000000.0          127154901.0
# 18                      2 Guns          61000000.0           75612460.0
# 20              200 Cigarettes           6000000.0            6851636.0
# 21          20Th Century Women           7000000.0            5663855.0
# 22                 21 And Over          13000000.0           25682380.0
# 23                    21 Grams          20000000.0           16248701.0
# 24              21 Jump Street          42000000.0          138447667.0
# 25              22 Jump Street          50000000.0          191719337.0
# 26                   25Th Hour           5000000.0           13060843.0
# 27                  27 Dresses          30000000.0           76808654.0
# 28                     28 Days          43000000.0           37170488.0
# 29               28 Days Later           8000000.0           45064915.0
# 30              28 Weeks Later          15000000.0           28638916.0
# 31              3 Days To Kill          28000000.0           30697999.0
# 32               3 Generations           5000000.0              66371.0
# 33            3 Men And A Baby          11000000.0          167780960.0
# 34                    3 Ninjas           6500000.0           29000301.0
# 35          3 Ninjas Kick Back          20000000.0           11784000.0
# 36            30 Days Of Night          32000000.0           39568996.0
# 37          30 Minutos O Menos          28000000.0           37053924.0
# 38       300 Rise Of An Empire         110000000.0          106580051.0
# 39     3000 Miles To Graceland          62000000.0           15738632.0
# 40                 310 To Yuma          55000000.0           53606916.0
# 41                       3Iron           1000000.0             238507.0
# 42       40 Days And 40 Nights          17000000.0           37950822.0
# 43                    47 Ronin         175000000.0           38362475.0
# 44              50 First Dates          75000000.0          120908074.0
# 45                       50/50           8000000.0           35014192.0
# 46          500 Days Of Summer           7500000.0           32391374.0
