# %% [markdown]
# # Movies Database Cleaning

# %%
import numpy as np
import pandas as pd

# %%
original_movies_db = pd.read_excel('movies.xls')
original_movies_db.head()
# Out:
#        budget                                 company country        director  \
# 0   8000000.0           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000.0                      Paramount Pictures     USA     John Hughes
# 2  15000000.0                      Paramount Pictures     USA      Tony Scott
# 3  18500000.0  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000.0                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating  \
# 0  Adventure   52287414.0               Stand by Me      R
# 1     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13
# 2     Action  179800601.0                   Top Gun     PG
# 3     Action   85160248.0                    Aliens      R
# 4  Adventure   18564613.0   Flight of the Navigator     PG
#
#               released  runtime  score               star     votes  \
# 0  1986-08-22 00:00:00     89.0    8.1        Wil Wheaton  299174.0
# 1  1986-06-11 00:00:00    103.0    7.8  Matthew Broderick  264740.0
# 2  1986-05-16 00:00:00    110.0    6.9         Tom Cruise  236909.0
# 3  1986-07-18 00:00:00    137.0    8.4   Sigourney Weaver  540152.0
# 4  1986-08-01 00:00:00     90.0    6.9        Joey Cramer   36636.0
#
#           writer    year
# 0   Stephen King  1986.0
# 1    John Hughes  1986.0
# 2       Jim Cash  1986.0
# 3  James Cameron  1986.0
# 4  Mark H. Baker  1986.0

# %%
movies_db = original_movies_db

# %%
# Filtering to just get 'USA' matches
movies_db = movies_db[(movies_db['country'] == 'USA')]


# Filtering to just get 'BUDGET' not equal to 0.0
movies_db = movies_db[(movies_db['budget'] != 0.0)]


movies_db.head()
# Out:
#        budget                                 company country        director  \
# 0   8000000.0           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000.0                      Paramount Pictures     USA     John Hughes
# 2  15000000.0                      Paramount Pictures     USA      Tony Scott
# 3  18500000.0  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000.0                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating  \
# 0  Adventure   52287414.0               Stand by Me      R
# 1     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13
# 2     Action  179800601.0                   Top Gun     PG
# 3     Action   85160248.0                    Aliens      R
# 4  Adventure   18564613.0   Flight of the Navigator     PG
#
#               released  runtime  score               star     votes  \
# 0  1986-08-22 00:00:00     89.0    8.1        Wil Wheaton  299174.0
# 1  1986-06-11 00:00:00    103.0    7.8  Matthew Broderick  264740.0
# 2  1986-05-16 00:00:00    110.0    6.9         Tom Cruise  236909.0
# 3  1986-07-18 00:00:00    137.0    8.4   Sigourney Weaver  540152.0
# 4  1986-08-01 00:00:00     90.0    6.9        Joey Cramer   36636.0
#
#           writer    year
# 0   Stephen King  1986.0
# 1    John Hughes  1986.0
# 2       Jim Cash  1986.0
# 3  James Cameron  1986.0
# 4  Mark H. Baker  1986.0

# %%
# Checking column names

movies_db.columns
# Out:
# Index(['budget', 'company', 'country', 'director', 'genre', 'gross', 'name',
#        'rating', 'released', 'runtime', 'score', 'star', 'votes', 'writer',
#        'year'],
#       dtype='object')

# %%
# Selecting the columns we want to keep
movies_db = movies_db[['year', 'name', 'budget', 'gross', 'score']]


# Renaming the columns
movies_db.columns = ['YEAR', 'NAME', 'BUDGET', 'REVENUE', 'IMDB SCORE']

movies_db
# Out:
#         YEAR                                       NAME      BUDGET  \
# 0     1986.0                                Stand by Me   8000000.0
# 1     1986.0                   Ferris Bueller's Day Off   6000000.0
# 2     1986.0                                    Top Gun  15000000.0
# 3     1986.0                                     Aliens  18500000.0
# 4     1986.0                    Flight of the Navigator   9000000.0
# ...      ...                                        ...         ...
# 6807  2016.0                               The Darkness   4000000.0
# 6809  2016.0                                The Hollars   3800000.0
# 6811  2016.0  Middle School: The Worst Years of My Life   8500000.0
# 6814  2016.0                                      Risen  20000000.0
# 6817  2016.0                   Batman: The Killing Joke   3500000.0
#
#           REVENUE  IMDB SCORE
# 0      52287414.0         8.1
# 1      70136369.0         7.8
# 2     179800601.0         6.9
# 3      85160248.0         8.4
# 4      18564613.0         6.9
# ...           ...         ...
# 6807   10732841.0         4.4
# 6809    1016872.0         6.5
# 6811   19985196.0         6.1
# 6814   36874745.0         6.3
# 6817    3775000.0         6.5
#
# [3723 rows x 5 columns]

# %%
# Creating the '% BUDGET/REVENUE' column

movies_db['% BUDGET/REVENUE'] = round((movies_db['BUDGET'] / movies_db['REVENUE'] * 100), 1)

#movies_db

# %%
# Converting 'YEAR' column to 'int' type

movies_db['YEAR'] = movies_db['YEAR'].astype(int)
movies_db.head()
# Out:
#    YEAR                      NAME      BUDGET      REVENUE  IMDB SCORE  \
# 0  1986               Stand by Me   8000000.0   52287414.0         8.1
# 1  1986  Ferris Bueller's Day Off   6000000.0   70136369.0         7.8
# 2  1986                   Top Gun  15000000.0  179800601.0         6.9
# 3  1986                    Aliens  18500000.0   85160248.0         8.4
# 4  1986   Flight of the Navigator   9000000.0   18564613.0         6.9
#
#    % BUDGET/REVENUE
# 0              15.3
# 1               8.6
# 2               8.3
# 3              21.7
# 4              48.5
